# %%
# import block
import json
from time import sleep
import requests
import lxml
from bs4 import BeautifulSoup
from selenium import webdriver
import sqlite3 as lite
import pandas as pd
from pymongo import MongoClient

# %% [markdown]
# # Vacation Homework

# %% [markdown]
# ## Q1. Python Basic, Web Scraping, RDBMS, SQL
#
# ### Q1-1
#
# `Ancient Egyptian multiplication`(one of two multiplication methods used by scribes, was a systematic method for multiplying two numbers that does not require the multiplication table, only the ability to multiply and divide by 2, and to add.) 을 Python 으로 구현하세요.
#
# example output)
#
# ```
# enter two numbers: 24 15
#   24      15 struck
#   12      30 struck
#    6      60 struck
#    3     120 keep
#    1     240 keep
# The result is 360
# ```

# %%
# Q1-1
def get_action_count(value:int) -> int:
    """Value 를 2 로 나누었을 때, 몫이 0 이 되기까지의 횟수를 찾는 함수.
    return count
    """
    count = 1
    while (True):
        value //= 2        
        count += 1
    
        if value == 1:
            break
            
    return count

a, b = map(int, input("enter two numbers: ").split())
count = get_action_count(a)
result = 0

text1 = "{0:>" + str(count) + "}"
text2 = "{0:>" + str(count) + "}"

# a 가 홀수라면 b 의 값을 더해주며, a 를 2로 더이상 나눌 수 없을 때까지 반복한다.
for _ in range(count):
    if a % 2 == 0:
        curr_status = "struck"
    else:
        curr_status = "keep"
        
    print(text1.format(a), "", text2.format(b), curr_status)
    
    if curr_status == "keep":
        result += b
        
    a //= 2
    b *= 2

print("The result is {}".format(result))
# Out:
# enter two numbers: 27 82
#    27     82 keep
#    13    164 keep
#     6    328 struck
#     3    656 keep
#     1   1312 keep
# The result is 2214

# %%
user_input = input("Enter Two Numbers: ")
[a, b] = [int(x) for x in user_input.split()]
kept_b = []

while a > 0:
    if a%2 == 1:
        status = "keep"
        kept_b.append(b)
    else:
        status = "struck"
        
    print("{a}{tab}{b}{tab}{status}".format(a=a, tab='\t', b=b, status=status))
    a //= 2
    b *= 2

result = sum([i for i in kept_b])
print("The result is {}".format(result))
# Out:
# Enter Two Numbers: 27 82
# 27	82	keep
# 13	164	keep
# 6	328	struck
# 3	656	keep
# 1	1312	keep
# The result is 2214

# %% [markdown]
# ### Q1-2
#
# Twitter의 `#asiancup` 에 대한 트윗 검색결과(https://twitter.com/search?q=%23asiancup)를 sqlite 를 활용한 database에 적재하세요.
# (10회 스크롤 했을 때의 트윗 본문 전체(이미지 제외))
#
# `Requirements: selenium, sqlite3`
#
# - **Caution** : https://twitter.com/robots.txt 의 지침을 따르세요.
#
# ```
# # Every bot that might possibly read and respect this file.
# User-agent: *
# Allow: /*?lang=
# Allow: /hashtag/*?src=
# Allow: /search?q=%23
# Disallow: /search/realtime
# Disallow: /search/users
# Disallow: /search/*/grid
#
# Disallow: /*?
# Disallow: /*/followers
# Disallow: /*/following
#
# Disallow: /account/not_my_account
# Disallow: /account/deactivated
# Disallow: /settings/deactivated
#
# Disallow: /oauth
# Disallow: /1/oauth
#
# Disallow: /i/streams
# Disallow: /i/hello
#
# # Wait 1 second between successive requests. See ONBOARD-2698 for details.
# Crawl-delay: 1
# ```

# %%
#Q1-2
ch_driver = webdriver.Chrome("C:\\Program Files (x86)\\chromedriver_win32\\chromedriver.exe")

ch_driver.get("https://twitter.com/search?q=%23asiancup")

# 스크롤 10번 아래로 넘기기
for _ in range(10):
    ch_driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(1)

# 스크랩핑 결과 dictionary 에 담기
twitter_search_list = ch_driver.find_element_by_id('stream-items-id')

li_list = twitter_search_list.find_elements_by_tag_name('li')
result = {}
index = 0

for li in li_list[:]:
    if li.get_attribute('data-item-type') == 'tweet':
        user_nickname = li.find_element_by_class_name('FullNameGroup').text.strip(' \n')
        user_name = li.find_element_by_class_name('username').text.strip(' \n')
        user_time_stamp = li.find_element_by_class_name('_timestamp').text.strip(' \n')
        user_content = li.find_element_by_class_name('js-tweet-text-container').find_element_by_tag_name('p').get_attribute('innerText').strip('\n\t').replace('\n', ' ').replace('"', "'")
        
        result[index] = dict((name, eval(name)) for name in ["user_nickname", "user_name", "user_time_stamp", "user_content"])
        index += 1

print(result[0])
# Out:
# {'user_nickname': 'korea dispatch', 'user_name': '@dispatchsns', 'user_time_stamp': '2월 2일', 'user_content': '그 이유는요?  #아시안컵 #ASIANCUP #일본 #일본대표팀 #라커룸 http://dispatch.co.kr/2004073\xa0'}

# %%
# 쿼리 문자열 만들기
query_string = ""

for k in result.keys():
#     if k >= 6 and k < 7:
    if k < len(result) - 1:
        query_string += '("{}", "{}", "{}", "{}"),'.format(result[k]['user_nickname'],
                                                  result[k]['user_name'],
                                                  result[k]['user_time_stamp'],
                                                  result[k]['user_content'])
    else:
        query_string += '("{}", "{}", "{}", "{}");'.format(result[k]['user_nickname'],
                                                  result[k]['user_name'],
                                                  result[k]['user_time_stamp'],
                                                  result[k]['user_content'])

# query_string = query_string[:len(query_string)-1] + ';'
# print(query_string)

# %%
try:
    conn = lite.connect('./products.db')
    
    # 테이블 드랍
    cursor = conn.cursor()

    sql = """
    drop table  Twitter;
    """

    cursor.execute(sql)
    cursor.close()

    # 테이블 생성
    cursor = conn.cursor()

    sql = """
    Create Table if not exists  Twitter
    (
        CONTENT_NUM INTEGER PRIMARY KEY AUTOINCREMENT,
        USER_NICKNAME NVARCHAR(20),
        USER_NAME CHAR(20),
        USER_TIME_STAMP CHAR(9),
        USER_CONTENT NVARCHAR(1000)
    );
    """

    cursor.execute(sql)
    cursor.close()
    
    # 데이터 삽입
    cursor = conn.cursor()

    sql = """
    INSERT INTO Twitter (USER_NICKNAME, USER_NAME, USER_TIME_STAMP, USER_CONTENT) VALUES 
    """ + query_string

    # print(sql)
    cursor.execute(sql)
    conn.commit()
except Exception as e:
    print("예외발생")
    conn.rollback()

# %%
# 데이터 확인
conn = lite.connect('./products.db')
cursor = conn.cursor()

sql = """
SELECT   *
FROM     Twitter--sqlite_master
;
"""

cursor = conn.cursor()
cursor.execute(sql)
print("============================")
print("         데이터 검증        ")
print(cursor.fetchall()[0])
print("============================")
# Out:
# ============================
#          데이터 검증
# (1, 'korea dispatch', '@dispatchsns', '2월 2일', '그 이유는요?  #아시안컵 #ASIANCUP #일본 #일본대표팀 #라커룸 http://dispatch.co.kr/2004073\xa0')
# ============================

# %% [markdown]
# ## Q2. SQL, RDBMS
#
# `products.db` 에 대하여 다음 문제를 해결하세요.
#
# ### Q2-1
#
# `products.db`에 존재하는 모든 `table`과 `column`을 조회하세요.

# %%
#Q2-1

# %%
conn = lite.connect('./products.db')
cursor = conn.cursor()

sql = """
SELECT   *
FROM     sqlite_master
;
"""

cursor = db.cursor()
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('table',
#   'Categories',
#   'Categories',
#   2,
#   'CREATE TABLE Categories(\n  "CategoryID" TEXT,\n  "CategoryName" TEXT,\n  "Description" TEXT\n)'),
#  ('table',
#   'Customers',
#   'Customers',
#   3,
#   'CREATE TABLE Customers(\n  "CustomerID" TEXT,\n  "CustomerName" TEXT,\n  "ContactName" TEXT,\n  "Address" TEXT,\n  "City" TEXT,\n  "PostalCode" TEXT,\n  "Country" TEXT\n)'),
#  ('table',
#   'Employees',
#   'Employees',
#   6,
#   'CREATE TABLE Employees(\n  "EmployeeID" TEXT,\n  "LastName" TEXT,\n  "FirstName" TEXT,\n  "BirthDate" TEXT,\n  "Photo" TEXT,\n  "Notes" TEXT\n)'),
#  ('table',
#   'Shippers',
#   'Shippers',
#   15,
#   'CREATE TABLE Shippers(\n  "ShipperID" TEXT,\n  "ShipperName" TEXT,\n  "Phone" TEXT\n)'),
#  ('table',
#   'Suppliers',
#   'Suppliers',
#   16,
#   'CREATE TABLE Suppliers(\n  "SupplierID" TEXT,\n  "SupplierName" TEXT,\n  "ContactName" TEXT,\n  "Address" TEXT,\n  "City" TEXT,\n  "PostalCode" TEXT,\n  "Country" TEXT,\n  "Phone" TEXT\n)'),
#  ('table',
#   'Orders',
#   'Orders',
#   11,
#   'CREATE TABLE Orders(\nOrderID integer,\nCustomerID integer,\nEmployeeID integer,\nOrderDate date,\nShipperID integer)'),
#  ('table',
#   'OrderDetails',
#   'OrderDetails',
#   7,
#   'CREATE TABLE OrderDetails(\nOrderDetailID integer,\nOrderID integer,\nProductID integer,\nQuantity integer)'),
#  ('table',
#   'Products',
#   'Products',
#   14,
#   'CREATE TABLE Products(\nProductID integer,\nProductName text,\nSupplierID integer,\nCategoryID integer,\nUnit text,\nPrice integer\n)'),
#  ('table',
#   'sqlite_sequence',
#   'sqlite_sequence',
#   17,
#   'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table',
#   'Twitter',
#   'Twitter',
#   8,
#   'CREATE TABLE Twitter\n    (\n        CONTENT_NUM INTEGER PRIMARY KEY AUTOINCREMENT,\n        USER_NICKNAME NVARCHAR(20),\n        USER_NAME CHAR(20),\n        USER_TIME_STAMP CHAR(9),\n        USER_CONTENT NVARCHAR(1000)\n    )')]

# %% [markdown]
# ### Q2-2
#
# `Customer`의 `Country`가 "Germany" 이거나 `City`가 "London" 인 모든 주문의 주문양(`Quantity`)의 합을 조회하세요.

# %%
#Q2-2
conn = lite.connect('./products.db')
cursor = conn.cursor()

sql = """
SELECT SUM(B.Quantity)
  FROM Orders A
 INNER JOIN OrderDetails B ON B.OrderID = A.OrderID
 WHERE 1 = 1
   AND CustomerID IN (
    SELECT CustomerID
      FROM Customers
     WHERE 1 = 1
       AND (Country = 'Germany' OR City = 'London')
   )
;
"""

cursor = db.cursor()
cursor.execute(sql)
cursor.fetchall()
# Out:
# [(2633,)]

# %% [markdown]
# ### Q2-3
#
# 월별 총 주문 횟수와 총 주문 갯수, 평균 주문 금액(소수점 2째 자리에서 반올림)을 조회하세요.
# (총 주문 횟수를 기준으로 내림차순 정렬)

# %%
#Q2-3
conn = lite.connect('./products.db')
cursor = conn.cursor()

sql = """
SELECT ORDER_MONTH
       --,ORDER_COUNT,ORDER_QTY,PRODUCT_PRICE
       ,COUNT(ORDER_COUNT) AS TOTAL_ORDER_CNT
       ,SUM(ORDER_QTY) AS TOTAL_ORDER_QTY
       ,ROUND(AVG(PRODUCT_PRICE), 2) AS PRODUCT_AVG_PRICE
  FROM
  (
    SELECT SUBSTR(A.OrderDate, 6, 2) AS ORDER_MONTH
           , A.OrderID AS ORDER_COUNT
           , B.Quantity AS ORDER_QTY
           , B.Quantity * C.Price AS PRODUCT_PRICE
      FROM Orders A
     INNER JOIN OrderDetails B ON B.OrderID = A.OrderID
     INNER JOIN Products C ON C.ProductID = B.ProductID
     WHERE 1 = 1
  )
 GROUP BY ORDER_MONTH
 ORDER BY TOTAL_ORDER_CNT DESC
;
"""

cursor = db.cursor()
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('01', 85, 2401, 981.18),
#  ('12', 81, 2200, 786.68),
#  ('10', 73, 1738, 705.87),
#  ('08', 69, 1322, 482.4),
#  ('11', 66, 1735, 941.88),
#  ('07', 59, 1462, 640.34),
#  ('09', 57, 1124, 606.41),
#  ('02', 28, 761, 713.53)]

# %% [markdown]
# ## Q3. noSQL, json, Web Scraping
#
# ### Q3-1
#
# 다음 금융 시가총액 페이지(http://finance.daum.net/domestic/market_cap) 에서 KOSPI200 상위 30개 종목에 대하여,
# 뉴스공시 탭의 종목뉴스 최신 100개를 가져와 mLab의 새로운 Collection을 생성하여 저장한 뒤, 모든 뉴스의 `title`, `keywords`, `createdAt` 값을 표현하세요.
#
# `Requirements: requests, json, pymongo`
#
# hint1:
# ```python
# headers = {"Host":"finance.daum.net"}
# requests.get(url, headers=headers)
# ```
#
# hint2: `some_collection.find(query, {'_id':0,'title':1,})`
#
# <img src="./daum-finance-news.png" width="300">

# %%
#Q3-1
# KOSPI200 상위 30개 종목의 코드ID 찾아오기
url = 'http://finance.daum.net/api/trend/market_capitalization?page=1&perPage=30&fieldName=marketCap&order=desc&market=KOSPI&pagination=true'

headers = {
    "Host": "finance.daum.net",
    "Connection": "keep-alive",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36",
    "Referer": "http://finance.daum.net/domestic/market_cap",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Cookie": "webid=7454ef8e5cbd43f2982fecb0c2962724; _ga=GA1.2.436371555.1549377563; _gid=GA1.2.5011209.1549377563; recentMenus=[{%22destination%22:%22news%22%2C%22title%22:%22%EB%89%B4%EC%8A%A4%C2%B7%EA%B3%B5%EC%8B%9C%22}]; KAKAO_STOCK_RECENT=[%22A000660%22%2C%22A005930%22]; PREMIUMCHK=""; PREMIUM=""; TIARA=ilUNkVaZ9j9cWB4_MrvBHTDauze5y85S59jCJ9Fvm-nvTzimbPFEWdcUT37wMKoWA57F5lZLQNis6U2MdNei-KxRS6ZzIeBO; webid_sync=1549378574331; _gat_gtag_UA_128578811_1=1; _dfs=bTFWTFRvQUlNTXNpckJ2blpTNXZEL1RHRGxLQ1o2NWo4eFFzTlRpZ25Ib3JEQ2p5ZEVkdzd1NzMxVitSMG5peTdEczVLN1Qvak9WVFdkbnlYdG5uSFE9PS0tbTFZVUtWSmRrOW15MXZZOGRRaTlUUT09--399a61113d5d64002a5a84501d0e77f2cefd07ef",
    "If-None-Match": 'W/"9d3f64f6ee97e66d4a16ed6076cac047"',
}

response = requests.get(url, headers=headers)
# print(response.text)

kospi_result = response.json()['data']
top_thirty_kospi_code_list = [kospi_result[i]['symbolCode'] for i in range(len(kospi_result))]

top_thirty_kospi_code_list
# Out:
# ['A005930',
#  'A000660',
#  'A005935',
#  'A068270',
#  'A005380',
#  'A051910',
#  'A207940',
#  'A005490',
#  'A028260',
#  'A015760',
#  'A012330',
#  'A017670',
#  'A055550',
#  'A035420',
#  'A105560',
#  'A051900',
#  'A034730',
#  'A032830',
#  'A018260',
#  'A096770',
#  'A006400',
#  'A000270',
#  'A033780',
#  'A000810',
#  'A003550',
#  'A086790',
#  'A010950',
#  'A066570',
#  'A036570',
#  'A251270']

# %%
# 뉴스 공시 정보를 담아두기 위한 준비
result = []
data_index = 0

# %%
# TOP 200 의 30개의 뉴스 공시 정보 긁어오기
url = "http://finance.daum.net/content/news?page=1&perPage=100&category=economy&searchType=all&pagination=true&keyword="

# for kospi_code in top_thirty_kospi_code_list[:3]:
# for kospi_code in top_thirty_kospi_code_list[3:5]:
# for kospi_code in top_thirty_kospi_code_list[5:7]:
# for kospi_code in top_thirty_kospi_code_list[7:9]:
for kospi_code in top_thirty_kospi_code_list[9:10]:

# 아래 소스를 바로 긁어버리면 이상하게 중간에 못가져옴 그래서 단위로 쪼개서 담아둠
# for kospi_code in top_thirty_kospi_code_list[:]:
    # url = "http://finance.daum.net/quotes/A005930#news/stock"
    url = url + kospi_code
    
    headers = {
        "Host": "finance.daum.net",
        "Connection": "keep-alive",
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "X-Requested-With": "XMLHttpRequest",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36",
        "Referer": "http://finance.daum.net/quotes/" + kospi_code,
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "Cookie": "webid=7454ef8e5cbd43f2982fecb0c2962724; _ga=GA1.2.436371555.1549377563; KAKAO_STOCK_RECENT=[%22A005930%22%2C%22A000660%22]; _gid=GA1.2.1894754651.1549547822; recentMenus=[{%22destination%22:%22news%22%2C%22title%22:%22%EB%89%B4%EC%8A%A4%C2%B7%EA%B3%B5%EC%8B%9C%22}]; TIARA=vS1N5wt96BfJVokSVCYPhYCJTvIm5X_ElkfR4ZttHgY.YzuSuLikdubZ45gT1u6oXhjAN9UktEkwbomjGKjzyZ5TnNa2S1Rr; webid_sync=1549548875405; _gat_gtag_UA_128578811_1=1; _dfs=L202NThObEJsUXNuczBCSWZ6UXpLckgwT1dZdW9ld2g3bktLcWEyZXFXSTNPR1VncXdsZHlxd0tldnZpY1RyMllYbytjTGFmMnFsc2IyWjhxZ3V4UUE9PS0tU0UyUU9DNXliT3VxQjFTa0tnVEl2dz09--fd7e2c28e5102b835f1aa67dba8e81d11dc1a9db",
        "If-None-Match": 'W/"8574b010bb86ac31a2cc130b2cb68d74"',
    }
    
    response = requests.get(url, headers=headers)
#     print(response.json())
    
    news_result = response.json()['data']
    print(kospi_code, len(news_result))
    
    for i in range(len(news_result)):
        code = kospi_code
        newsId = news_result[i]['newsId']
        title = news_result[i]['title']
        keywords = news_result[i]['keywords']
        cpKorName = news_result[i]['cpKorName']
        createdAt = news_result[i]['createdAt']
        updatedAt = news_result[i]['updatedAt']
        summary = news_result[i]['summary']
        imageUrl = news_result[i]['imageUrl']
        
        result.append(dict((name, eval(name)) for name in [
            "code",
            "newsId",
            "title",
            "keywords",
            "cpKorName",
            "createdAt",
            "updatedAt",
            "summary",
            "imageUrl",
         ]))
        
        data_index += 1

    print(data_index)

    # 스크래핑 기준에 맞추어 1초마다 데이터 가져오기
    sleep(1)

print(result)
# Out:
# A015760 100
# 1000
# [{'code': 'A005930', 'newsId': 'aZeM5B5C0q', 'title': "삼성전자 '2019년형 QLED 8K' 글로벌 본격 판매 시작", 'keywords': ['8k', 'qled', '삼성전자', '유럽', '삼성'], 'cpKorName': '뉴스1', 'createdAt': '2019-02-10 11:12:42', 'updatedAt': '2019-02-10 11:12:42', 'summary': "(서울=뉴스1) 류석우 기자 = 삼성전자가 시야각을 개선하고 HDMI 2.1을 탑재한 '2019년형 QLED 8K TV'를 글로벌 시장에 공개하고 본격 판매를 시작한다. 삼성전자는 오는 12일 유럽을 시작으로 서남아·중남미·중동 등 각 지역별로 거래선 초청 행사인 '삼성포럼'을 개최한다고 10일 밝혔다. 이 행사에서 삼성전자는 2019년형 QLED 8K", 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/NEWS1/20190210111242453wbge.jpg'}, {'code': 'A005930', 'newsId': 'af01tUO6HF', 'title': '삼성전자·SK하이닉스 강세에 올 들어 전기·전자업종 16%↑', 'keywords': ['삼성전자', 'sk하이닉스', '코스피', '지수', '전기전자'], 'cpKorName': '디지털타임스', 'createdAt': '2019-02-10 11:11:21', 'updatedAt': '2019-02-10 11:14:42', 'summary': '[디지털타임스 김민주 기자] 삼성전자와 SK하이닉스의 강세에 코스피시장에서 올 들어 전기·전자업종이 가장 많이 오른 것으로 나타났다. 10일 한국거래소에 따르면 연초 이후 이달 8일까지 코스피 전기전자 업종 지수는 15.74% 올랐다. 코스피의 17개 주요 업종 지수 중 가장 높은 상승률이다. 같은 기간 코스피는 7.33% 올랐다. 삼성전자와 SK하이닉스', 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/dt/20190210111122097mplm.jpg'}, {'code': 'A005930', 'newsId': 'aZ4JMeThNW', 'title': '[르포]삼성전자 QLED 8K TV 개발 현장 가보니', 'keywords': ['8k', '삼성전자', 'qled', '화질', '블랙'], 'cpKorName': '데일리안', 'createdAt': '2019-02-10 11:03:49', 'updatedAt': '2019-02-10 11:13:26', 'summary': '[수원(경기)=데일리안 이홍석 기자]TV 본산 경기도 수원 삼성디지털시티에서 8K 제품-기술 향상 노력 한창 “TV 시장이 전체적으로 정체돼 있지만 대형 시장은 꾸준히 성장하고 있습니다. 8K 제품으로 프리미엄 시장을 선도해 나갈 것입니다.” 8일 삼성전자 TV 본산인 경기도 수원 삼성디지털시티에서 만난 삼성전자 연구원은 8K가 TV 시장의 새로운 패러다임', 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/dailian/20190210110349175iiiq.jpg'}, {'code': 'A005930', 'newsId': 'aBICp0GwUh', 'title': "저화질 영상도 8K 고화질로 바꾸는 삼성의 '마술'은?", 'keywords': ['8k', '삼성', 'qled', '삼성전자', '퀀텀'], 'cpKorName': '노컷뉴스', 'createdAt': '2019-02-10 11:03:01', 'updatedAt': '2019-02-10 11:03:01', 'summary': "삼성전자는 경기도 수원에 위치한 삼성디지털시티에서 TV 시장 전망과 2019년형 삼성 'QLED 8K' 핵심 기술 설명회를 열고 본격적인 8K TV 시장 선점에 나선다고 10일 밝혔다.. 삼성 'QLED 8K'는 3,300만개의 화소를 가진 초고해상도 디스플레이와 퀀텀닷 기술을 접목한 TV로 최고 수준 밝기와 명암비, 실제와 같은 깊이감 있는 색상, 넓은", 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/nocut/20190210110301423ehud.jpg'}, {'code': 'A005930', 'newsId': 'adgYdxzYzC', 'title': '삼성의 8K TV 자신감.. "5G 기술이 8K 대중화 견인할 것"', 'keywords': ['8k', '콘텐츠', '5g', '삼성', '삼성전자'], 'cpKorName': '서울경제', 'createdAt': '2019-02-10 11:01:22', 'updatedAt': '2019-02-10 11:01:22', 'summary': '[서울경제] 올해 ‘8K 원년’을 선언한 삼성전자(005930)가 8K TV에 대한 자신감을 드러냈다. 아직 8K 콘텐츠가 부족하다는 이유로 8K TV에 대한 회의적인 시각이 많지만 5G 통신의 상용화와 맞물려 관련 콘텐츠도 폭증할 것이라는 긍정적인 전망도 제시됐다. 한종희 삼성전자 영상디스플레이사업부 사장은 8일 수원 삼성디지털시티에서 ‘QLED 8K’', 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/seouleconomy/20190210110123609ghum.jpg'}, {'code': 'A005930', 'newsId': 'aScmIMeaBr', 'title': '한종희 삼성전자 사장 "QLED 8K TV, 프리미엄 시장 두자릿수 점유율 목표"', 'keywords': ['8k', 'qled', '프리미엄', '한종희', '점유율'], 'cpKorName': '파이낸셜뉴스', 'createdAt': '2019-02-10 11:00:53', 'updatedAt': '2019-02-10 11:00:53', 'summary': '삼성전자 영상디스플레이사업부장 한종희 사장이 지난 8일 경기도 수원 삼성디지털시티에서 2019년형 QLED 8K로 올해 TV시장을 선도해 나가겠다는 비전을 발표하고 있다. /사진=삼성전자 제공    【수원(경기)=조지민 기자】삼성전자가 차세대 TV 제품인 초고해상도 8K 시장 선도에 박차를 가한다. 제품 모델을 확대하고, 전 세계에서 순차적으로', 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/fnnewsi/20190210110053994wtvv.jpg'}, {'code': 'A005930', 'newsId': 'adyKXVbFU3', 'title': "삼성전자 초고화질 '8K TV' 60여개국 판매..비싼 가격·콘텐츠 부족 극복할 수 있을까", 'keywords': ['8k', '콘텐츠', '삼성전자', '가격', '4k'], 'cpKorName': '경향신문', 'createdAt': '2019-02-10 11:00:50', 'updatedAt': '2019-02-10 11:00:50', 'summary': '[경향신문] 글로벌 TV 시장에서 13년째 1위를 달리고 있는 삼성전자가 ‘8K TV’를 올해 60여개 국가에서 판매한다. 점점 화면 크기가 커지고 있는 TV 시장에서 화질이 주요 경쟁 포인트로 부상한 가운데 공격적인 마케팅으로 시장 수요를 창출하겠다는 전략이다. 그러나 대당 1000만원을 넘나드는 고가에 초고화질 콘텐츠가 부족하고, 가성비 좋은 경쟁사들의', 'imageUrl': 'https://t1.daumcdn.net/news/201902/10/khan/20190210110051049urom.jpg'}, {'code': 'A005930', 'newsId': 'aeVC3DUUD0', 'title': 'TV강국 흔들리나..한국 LCD TV, 중국에 따라잡혀', 'keywords': ['중국', '한국', '점유율', '삼성전자', 'lg전자'], 'cpKorName': '서울경제', 'createdAt': '2019-02-10 11:00:34', 'updatedAt': '2019-02-10 11:00:34', 'summary': '[서울경 ...

# %%
mongo_uri = "mongodb://admin:admin1234@ds021994.mlab.com:21994/mydbinstance"
client = MongoClient(mongo_uri)
db = client.mydbinstance
kospi_collection = db.financekospi

# 데이터 NoSQL 적재
kospi_collection.insert_many(result)

# 최종 데이터 확인
query = {
}

list(kospi_collection.find(query, {'_id': 0, 'title': 1, 'keywords': 1, 'createdAt': 1}))
# Out:
# [{'title': "한국전력기술 '부패방지 시책평가' 최우수",
#   'keywords': ['시책평가', '한전기술', '공공기관', '2018년', '국민권익위원회'],
#   'createdAt': '2019-02-03 06:00:47'},
#  {'title': '"일회용 컵 NO" 김종갑 한전사장 \'플라스틱 프리 챌린지\'에 동참',
#   'keywords': ['김종갑', '일회용컵', '한전사장', '김영록', '전남지사'],
#   'createdAt': '2019-02-02 11:46:24'},
#  {'title': '국민연금, 대한항공 경영 참여하려면 100억 토해내야',
#   'keywords': ['경영', '100억', '한진칼', '행사', '국민연금지분율'],
#   'createdAt': '2019-02-02 03:09:55'},
#  {'title': '코스피, 개인·기관 매도 공세에 하락 마감',
#   'keywords': ['코스피', '하락', '무역협상', '중국', '지수'],
#   'createdAt': '2019-02-01 16:15:00'},
#  {'title': '[코스피 마감]외국인 러브콜에도 2거래일째 약보합',
#   'keywords': ['코스피', '하락', '지수', '마켓포인트', '미국'],
#   'createdAt': '2019-02-01 15:47:50'},
#  {'title': '[마감 시황] 코스피 전일 대비 1.39p 하락한 2203.46p에 마감',
#   'keywords': ['코스피', '하락', '보합세', '하락세', '한국경제tv'],
#   'createdAt': '2019-02-01 15:35:53'},
#  {'title': '[이 시각 코스피] 코스피 현재 2205.93p 상승세 지속',
#   'keywords': ['코스피', '보이', '하락', '보합세', '하락세'],
#   'createdAt': '2019-02-01 14:01:01'},
#  {'title': '중소기업계 "중소기업 전용 전기요금제 마련 촉구"',
#   'keywords': ['중소기업', '중기중앙회', '전기요금', '요금제', '산업용전기요금'],
#   'createdAt': '2019-02-07 12:00:06'},
#  {'title': '중기업계 "中企 전용 전기요금제 마련돼야" 촉구',
#   'keywords': ['중소기업', '요금제', '전기요금', '조정', '한국전력'],
#   'createdAt': '2019-02-07 11:59:18'},
#  {'title': '숨고르기에 들어갔나..코스피, 보합권 등락',
#   'keywords': ['코스피', '하락', '보이', '시가총액', '혼조세'],
#   'createdAt': '2019-02-07 11:34:24'},
#  {'title': '공기업 체험형 인턴 7500여명 선발.. LH 1000명',
#   'keywords': ['인턴', '공기업', 'lh', '공공기관', '채용'],
#   'createdAt': '2019-02-07 10:05:33'},
#  {'title': "[fn오전시황]코스피, 기관 '팔자'에 2200선 횡보",
#   'keywords': ['코스피', '순매도', '보이', '혼조세', '화학'],
#   'createdAt': '2019-02-07 09:44:04'},
#  {'title': '공기업 체험형 인턴 7천500여명 선발..LH 1천명·한전 900명',
#   'keywords': ['인턴', '공기업', 'lh', '인턴채용', 'mbc'],
#   'createdAt': '2019-02-07 09:42:03'},
#  {'title': '올해 공공기관 체험형 인턴 "7531명 뽑는다"',
#   'keywords': ['인턴', '공공기관', '상반기', '취업포털', '잡코리아'],
#   'createdAt': '2019-02-07 09:39:54'},
#  {'title': '[국고처 최승욱] 종목상담 - 한국전력(015760)',
#   'keywords': ['한국전력', '최승욱', '국민주식고충처리반', '대한민국', '증권방송'],
#   'createdAt': '2019-02-07 09:27:51'},
#  {'title': '2차 북미 정상회담 소식에 코스피·코스닥 상승세',
#   'keywords': ['코스피', '코스닥', '북미정상회담', '보이', '지수'],
#   'createdAt': '2019-02-07 09:22:09'},
#  {'title': '코스피, 연휴 끝내고 상승 출발..무역협상 타결 기대감',
#   'keywords': ['코스피', '무역협상', '하락', '지수', '시가총액'],
#   'createdAt': '2019-02-07 09:17:29'},
#  {'title': '공기업 체험형 인턴 7천500여명 선발..LH 1천명·한전 900명',
#   'keywords': ['인턴', '공기업', 'lh', '공공기관', '채용'],
#   'createdAt': '2019-02-07 09:10:36'},
#  {'title': 'LH 1,000명·한전 900명..공기업 체험형 인턴 7,500여명 선발',
#   'keywords': ['인턴', 'lh', '공기업', '잡코리아', '공공기관'],
#   'createdAt': '2019-02-07 08:53:26'},
#  {'title': 'LH 1천명·한전 900명..공기업 체험형 인턴 7500명 선발',
#   'keywords': ['인턴', 'lh', '공기업', '공공기관', '채용'],
#   'createdAt': '2019-02-07 08:38:09'},
#  {'title': '공기업 체험형 인턴 7500여명 선발..LH가 가장 많아',
#   'keywords': ['공기업', '인턴', 'lh', '공공기관', '인턴채용'],
#   'createdAt': '2019-02-07 08:09:00'},
#  {'title': '공기업 체험형 인턴 7천500여명 선발..LH 1천명·한전 900명',
#   'keywords': ['인턴', '공기업', 'lh', '잡코리아', '공공기관'],
#   'createdAt': '2019-02-07 07:57:38'},
#  {'title': "'2200명의 김용균' 정규직으로 고용할 공공기관.. 설립 방식·여전한 상하 관계 해결이 최대 난제",
#   'keywords': ['공공기관', '김용균', '정규직', '환경설비', '하청업체'],
#   'createdAt': '2019-02-07 04:03:59'},
#  {'title': '외국인 투자자 1월에 코스피 4조원 사들여',
#   'keywords': ['코스피', '무역협상', '외국인순매수', '한국거래소', '증시급락'],
#   'createdAt': '2019-02-07 03:09:12'},
#  {'title': "발전설비 운전인력 2,200명 직고용.. '위험 외주화' 근본 해결책 될까",
#   'keywords': ['외주화', '발전설비', '발전공기업', '김용균', '한전산업개발'],
#   'createdAt': '2019-02-06 18:42:16'},
#  {'title': '작년 원전 이용률 37년 만에 최저',
#   'keywords': ['원전', '유틸리티', '원전정책', '2017년', '2018년'],
#   'createdAt': '2019-02-06 18:35:02'},
#  {'title': "'바이코리아' 열풍, 연초 증시 반등 이끈다",
#   'keywords': ['증시', '바이코리아', '중국', '코스피', '한국'],
#   'createdAt': '2019-02-06 18:02:55'},
#  {'title': "發電공기업에 파견된 2200명 직접고용..민간업체 일감·인력 '박탈'",
#   'keywords': ['공기업', '직접고용', '정규직', '협력업체', '발전공기업'],
#   'createdAt': '2019-02-06 17:40:01'},
#  {'title': '외국인 1월 코스피 4조원 사들여, 45개월 만에 최대',
#   'keywords': ['코스피', '외국인순매수', '지수', '증시', '한국증시'],
#   'createdAt': '2019-02-06 16:15:01'},
#  {'title': "외국인 1월 코스피 4조원 '쇼핑'..45개월 만에 최대(종합)",
#   'keywords': ['코스피', '쇼핑', '증시', '지수', '정책'],
#   'createdAt': '2019-02-06 15:07:13'},
#  {'title': '정비 마친 원전 속속 복귀, 올해 원전 이용률 80% 웃돈다',
#   'keywords': ['원전', '복귀', '웃돈', '2018년', '신고리'],
#   'createdAt': '2019-02-06 14:43:56'},
#  {'title': '지난해 원전이용률 37년 만에 최저치..올해에는 급등할 듯',
#   'keywords': ['원전', '2018년', '신고리', '2017년', '한수원'],
#   'createdAt': '2019-02-06 10:09:56'},
#  {'title': '외국인 코스피 4조원 순매수.. 45개월 만에 최대',
#   'keywords': ['코스피', '한국증시', '하반기', '한국거래소', '지수'],
#   'createdAt': '2019-02-06 09:49:46'},
#  {'title': '작년 원전 이용률 37년만에 최저..올해는 급반등 전망',
#   'keywords': ['원전', '2018년', '유틸리티', '신고리', '문재인정부'],
#   'createdAt': '2019-02-06 08:01:05'},
#  {'title': "외국인 1월 코스피 4조원 '쇼핑'..45개월 만에 최대",
#   'keywords': ['코스피', '쇼핑', '증시', '지수', '정책'],
#   'createdAt': '2019-02-06 06:05:05'},
#  {'title': '올해도 취업 한파 지속..구조적인 일자리 감소, 장기화 우려',
#   'keywords': ['취업', '채용', '한파', '블라인드채용', '상반기'],
#   'createdAt': '2019-02-06 05:12:00'},
#  {'title': "한밤중 전신주에서 '펑'..부산에서 461가구 정전후 복구",
#   'keywords': ['부산', '전신주', '복구', '정전', '부산진구'],
#   'createdAt': '2019-02-05 07:55:43'},
#  {'title': '에너지株주, 4분기 실적보다 유가 걱정',
#   'keywords': ['유가', '에너지', '한국전력', '지수', '코스피'],
#   'createdAt': '2019-02-04 12:33:09'},
#  {'title': 'LG화학, 368,000원에 거래 시작',
#   'keywords': ['한국경제tv'],
#   'createdAt': '2019-02-07 09:01:21'},
#  {'title': '"삼성물산 404만주 6개월 내 추가 매각해라"..공정위, 삼성에 공식 통보',
#   'keywords': ['삼성물산', '공정위', '순환출자', '가이드라인', '합병'],
#   'createdAt': '2018-02-26 12:06:05'},
#  {'title': '美, 한국 세탁기 이어 철강까지 관세 폭탄 예고..업계 "수출하지 말라는 것" 우려',
#   'keywords': ['관세', '철강', '권고안', '미국상무부', '트럼프'],
#   'createdAt': '2018-02-18 10:57:47'},
#  {'title': "[마켓인]설 지나고 회사채 만기 돌아오는데..건설업 투자심리 '냉랭'",
#   'keywords': ['회사채', '삼성물산', '현대건설', '신용등급', '포스코건설'],
#   'createdAt': '2018-02-14 16:35:53'},
#  {'title': '조여오는 삼성 지배구조 압박..이재용의 선택은',
#   'keywords': ['삼성전자', '순환출자', '삼성', '삼성물산', '삼성생명'],
#   'createdAt': '2018-02-08 06:00:57'},
#  {'title': '삼성전자 액면분할에..삼성그룹주펀드도 볕드나',
#   'keywords': ['삼성전자', '삼성그룹주펀드', '액면분할', '수익률', '주가부양의지'],
#   'createdAt': '2018-01-31 17:51:11'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #증권주 #가상화폐 관련주 #삼성물산 #스튜디오드래곤 #내일 #톱픽은?',
#   'keywords': ['특징주', '삼성물산', '오늘증시', '가상화폐', '증권주'],
#   'createdAt': '2018-01-29 18:30:06'},
#  {'title': '[그것이 사고 싶다] 실적 턴어라운드 원년 전망 <에이디테크놀로지> 外',
#   'keywords': ['사도', '코스닥', '박스권', '파운드리', '정치적이슈'],
#   'createdAt': '2018-01-25 18:09:45'},
#  {'title': '[마켓리더에게 듣는다]윤희도 한투證 센터장 "코스피 상승 여력 있다"',
#   'keywords': ['바이오주', '코스피', '코스닥', '지수', '경기민감주'],
#   'createdAt': '2018-01-25 16:47:23'},
#  {'title': '[그것이 사고 싶다] 순이자마진 개선세 지속 <하나금융지주> 外',
#   'keywords': ['바이오', '사도', '박스권', '철강', '우리산업'],
#   'createdAt': '2018-01-23 16:16:52'},
#  {'title': "'유리천장' 깼다..삼성전자 여성 첫 '최고기술자', 롯데 첫 여성 CEO 등장",
#   'keywords': ['퀀텀닷', '삼성전자', '임원인사', 'lg전자', '종합기술원'],
#   'createdAt': '2018-01-16 06:00:51'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #증권주 #SPC삼립 #엔씨소프트 #POSCO #톱픽은?',
#   'keywords': ['특징주', 'spc삼립', '오늘증시', '철강', '엔씨소프트'],
#   'createdAt': '2018-01-12 17:47:53'},
#  {'title': "[투자보고서 REAL] 철강주, 2018 주도주로 나서나? 'POSCO'",
#   'keywords': ['폴더블', '박스권', '이지환', '스마트폰', '리얼'],
#   'createdAt': '2018-01-05 18:13:34'},
#  {'title': "'김상조 효과' 지배구조 서두르는 재계..속도 못 내는 현대차",
#   'keywords': ['순환출자', '효성', '합병', '현대자동차', '태광그룹'],
#   'createdAt': '2018-01-04 10:40:15'},
#  {'title': "[이 종목은 왜?] 지금은 '바겐세일' 중? '롯데지주' & 박스권 뚫고 더? 'POSCO'",
#   'keywords': ['박스권', '특징주', '매도전략', '호텔롯데', '오늘증시'],
#   'createdAt': '2018-01-03 17:54:17'},
#  {'title': '삼성에 칼 겨눈 김상조 "삼성물산 404만주 더 팔아라"',
#   'keywords': ['공정위', '삼성sdi', '합병', '삼성물산', '매각'],
#   'createdAt': '2017-12-21 16:36:42'},
#  {'title': '\'적폐 청산\' 나선 공정위 "삼성물산 404만주 더 팔아라"',
#   'keywords': ['공정위', '삼성sdi', '삼성물산', '합병', '매각'],
#   'createdAt': '2017-12-21 12:00:19'},
#  {'title': '찬바람 불땐 배당株..배당주펀드가 투자한 종목은',
#   'keywords': ['배당주펀드', '삼성전자', '포트폴리오', '고배당주', 'sk텔레콤'],
#   'createdAt': '2017-11-21 16:24:51'},
#  {'title': "[그것이 사고 싶다] '툴젠'과 면역항암제 공동개발 기대 <녹십자셀> 外",
#   'keywords': ['박스권', '사도', '바이오', '지주사전환', '비에이치'],
#   'createdAt': '2017-11-09 17:14:30'},
#  {'title': "[내일장 멘토링] 삼성전자 지분 가치 재부각! 관심주 '삼성물산'",
#   'keywords': ['etf', '특징주', '현대중공업', '오늘증시', '현대미포조선'],
#   'createdAt': '2017-11-01 17:06:56'},
#  {'title': "[이 종목은 왜?] 오늘의 특징주! 기대되는 4Q 실적 'LG화학' & 구조적으로 진화 'POSCO'",
#   'keywords': ['특징주', '철강', '매도전략', '오늘증시', '영업이익'],
#   'createdAt': '2017-10-27 17:59:56'},
#  {'title': '[그것이 사고 싶다] SLP 시장 확대 최대 수혜주 <심텍> 外',
#   'keywords': ['동화약품', '사도', '인쇄회로기판', '삼성에스디에스', '서울반도체'],
#   'createdAt': '2017-10-20 17:06:43'},
#  {'title': '[투자보고서 REAL] 오늘, 합병 무효 소송 1심 선고.. 파장은? <삼성물산>',
#   'keywords': ['컨센서스', '합병', '조정', '영업익', '펀더멘탈'],
#   'createdAt': '2017-10-19 16:45:10'},
#  {'title': "[이 종목은 왜?] 오늘의 특징주! 종목 선별이 필요 '화장품주' & 상승 기류를 타다 'POSCO'",
#   'keywords': ['한국콜마', '특징주', '매도전략', '유상증자', '밸류에이션'],
#   'createdAt': '2017-10-16 18:07:45'},
#  {'title': "[내일장 멘토링] 상승 추세는 이어진다! 관심주 '삼성물산'",
#   'keywords': ['etf', '특징주', '인간배아', '오늘증시', '홈캐스트'],
#   'createdAt': '2017-09-19 17:12:38'},
#  {'title': "[이 종목은 왜?] 北 핵실험 증시 '급습'.. 방위산업주 vs 철강주, 주가 방향은?",
#   'keywords': ['국방비', 'lig넥스원', '특징주', '북핵', '분할매수'],
#   'createdAt': '2017-09-04 16:59:24'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주 집중분석! 넷마블게임즈, LG화학, POSCO',
#   'keywords': ['특징주', '분할매수', '철강', 'lg화학', '넷마블게임즈'],
#   'createdAt': '2017-07-20 17:07:31'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주 집중분석! POSCO, 나노스, 지엔코',
#   'keywords': ['특징주', '지엔코', '제조업체', '나노스', '스프레드'],
#   'createdAt': '2017-07-17 16:55:36'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주 집중분석! 보험주, POSCO, 카카오',
#   'keywords': ['특징주', '카카오', '사이클', '오늘증시', '철강'],
#   'createdAt': '2017-07-11 16:48:48'},
#  {'title': "[내일장 멘토링] 내일 투자 '중요 체크' & 관심주 '한화투자증권'",
#   'keywords': ['포인트', 'etf', '오늘증시', '삼성물산', '케이블방송'],
#   'createdAt': '2017-06-29 16:37:20'},
#  {'title': "[27일 주요 크레딧 공시]포스코건설 'A·안정적'",
#   'keywords': ['우발채무', '손실위험', '조정'],
#   'createdAt': '2017-06-28 08:32:13'},
#  {'title': "[내일장 멘토링] 내일 투자 '중요 체크' & 관심주 '삼성물산'",
#   'keywords': ['포인트', 'etf', '심리적지지선', '오늘증시', '삼성물산'],
#   'createdAt': '2017-06-26 17:00:37'},
#  {'title': '[마감시황]코스피, 사흘 만에 2,370선 회복',
#   'keywords': ['지수', '운수창고', '음식료품', '도시바', '건설업'],
#   'createdAt': '2017-06-22 16:03:32'},
#  {'title': '[마켓뷰] 하루만에 등돌린 외국인..미리 발 빼나',
#   'keywords': ['삼성전자', '유가증권시장', '조정', '코스피', '순매수'],
#   'createdAt': '2017-06-21 16:41:02'},
#  {'title': '[마켓뷰] 기관·외국인 쌍끌이 매도에 휘청이는 코스피',
#   'keywords': ['국제유가', '삼성전자', '순매수', '한국증시', 'msci'],
#   'createdAt': '2017-06-21 11:30:05'},
#  {'title': '[中 MSCI 편입]외국인자금 빠지겠지만.."정유·소매·철강株는 선방할듯"',
#   'keywords': ['msci', '유출', '현대자동차', '자동차', '지수'],
#   'createdAt': '2017-06-21 11:20:31'},
#  {'title': "코스피, 중국 msci 편입 영향으로 후퇴..코스닥지수도 '하락'",
#   'keywords': ['중국a주', '유가', 'msci', '하락세', '지수'],
#   'createdAt': '2017-06-21 09:31:58'},
#  {'title': "최태원 SK회장, '밴 플리트' 상 받는다..국내 첫 父子 수상 영예",
#   'keywords': ['밴플리트상', 'sk그룹', '한국고등교육재단', '밴플리트', '코리아소사이어티'],
#   'createdAt': '2017-06-11 11:01:33'},
#  {'title': '[마켓뷰] 코스피 2340선 붕괴..대세 상승장 꺾이나',
#   'keywords': ['조정', '코스피', '하락세', '현대중공업', '교보증권'],
#   'createdAt': '2017-05-30 11:08:38'},
#  {'title': '[그것이 사고 싶다] 지금 사도 될까? POSCO, 현대위아, 한미사이언스',
#   'keywords': ['사도', '현대위아', '한미사이언스', 'posco', '전문가'],
#   'createdAt': '2017-05-29 17:18:24'},
#  {'title': '[그것이 사고 싶다] 지금 사도 될까? 케이엠더블유, 카카오, POSCO, 텔레칩스, 테스나 外',
#   'keywords': ['사도', '케이엠더블유', '035720', '투자포인트', '텔레칩스'],
#   'createdAt': '2017-05-26 16:57:25'},
#  {'title': '[마감 전략 A+ 2부] 7인의 관심 종목 대공개! 현대제철& 롯데케미칼',
#   'keywords': ['김용덕', '현대제철', 'etf', '이화공영', '동양철관'],
#   'createdAt': '2017-05-22 16:53:47'},
#  {'title': '지주사 포기한 삼성, 남은 숙제 순환출자 해소 어떻게 할까',
#   'keywords': ['순환출자', '삼성물산', '삼성', '삼성전자', '삼성그룹'],
#   'createdAt': '2017-04-28 13:16:45'},
#  {'title': "글로벌 불황 이긴 '어닝 서프라이즈' 행렬..경쟁력 강화노력 통했다",
#   'keywords': ['영업이익', '어닝서프라이즈', '철강업계', '삼성전자', '디스플레이'],
#   'createdAt': '2017-04-27 17:29:39'},
#  {'title': "[마켓뷰] 여전히 어려운 2100 넘기..내수우량주 '통신주' 강세",
#   'keywords': ['5g', 'sk텔레콤', 'lg유플러스', 'g20', '4차산업혁명'],
#   'createdAt': '2017-03-08 11:20:57'},
#  {'title': "대기업 신용평가, 국내선 '최고'..해외선 '바닥'",
#   'keywords': ['신용등급', '무디스', 'aaa', '공기업', 'moody'],
#   'createdAt': '2017-02-22 09:31:39'},
#  {'title': "[자본시장 개혁 3.0]③ '오너 위해' 계열사 붙이고 쪼개고..계속 불거지는 재벌문제",
#   'keywords': ['지주회사', '합병', '지배주주', 'sk', '제일모직'],
#   'createdAt': '2017-02-07 08:30:30'},
#  {'title': '삼성전자 날자, 삼성그룹주 펀드 \'꿈틀\'..비중 확대는 "글쎄"',
#   'keywords': ['삼성전자', '삼성그룹주펀드', '수익률', '영업이익', 'etf'],
#   'createdAt': '2017-01-09 10:09:01'},
#  {'title': '삼성전자 훨훨 나는데.. 삼성그룹주 펀드 수난사는 이어진다',
#   'keywords': ['삼성그룹주펀드', '삼성전자', '수익률', '펀드매니저', '삼성그룹'],
#   'createdAt': '2017-01-03 17:34:43'},
#  {'title': '[빅데이터MSI유망주]포스코 "철강가격 상승은 호재..구조조정 순조롭게 진행"',
#   'keywords': ['포스코', '권오준', '구조조정', '광양제철소', 'sentiment'],
#   'createdAt': '2016-12-14 16:00:01'},
#  {'title': "[머니+] 내년 증시 뜨겁게 달굴 '지배구조 재편' 수혜주는",
#   'keywords': ['삼성그룹', '삼성전자', '인적분할', '지주회사', '현대글로비스'],
#   'createdAt': '2016-12-04 09:58:46'},
#  {'title': '[월간 채권 워치]지난달 회사채 발행 11%나 줄어든 2.7조',
#   'keywords': ['회사채', '신용등급', '채권금리', '한국신용평가', '한신평'],
#   'createdAt': '2016-11-01 17:35:29'},
#  {'title': "미국 기준금리 인상 영향권 진입..'AA+' 우량 회사채도 5년물은 미달 발생",
#   'keywords': ['회사채', '수요예측', '유효수요', '신용스프레드', '현대산업'],
#   'createdAt': '2016-10-28 17:13:46'},
#  {'title': "대한항공 전량 미달에 AA급도 일부 미매각..채권시장 벌써 '연말 효과'",
#   'keywords': ['회사채', '신용스프레드', '수요예측', '신용등급', '유효수요'],
#   'createdAt': '2016-10-18 17:36:39'},
#  {'title': '포스코, 기후변화 대응능력 세계 최고 평가..친환경 노력 성과',
#   'keywords': ['포스코', '에너지원단위', '온실가스', '글로벌기업', 'dupont'],
#   'createdAt': '2016-10-12 10:00:20'},
#  {'title': "[펀드와치]'엘리엇 효과'에 삼성그룹株 펀드 '훨훨'",
#   'keywords': ['수익률', '삼성전자', '주식형펀드', '엘리엇', '지주회사'],
#   'createdAt': '2016-10-09 07:33:17'},
#  {'title': "업계 자율로 산업구조조정? 들여다 보니 곳곳서 '논란 예고'",
#   'keywords': ['공급과잉', '석유화학', '포스코', '산업부', '사회주의국가'],
#   'createdAt': '2016-09-29 16:48:01'},
#  {'title': "'A급+건설업' 핸디캡에도.. 대림산업 회사채 흥행 성공",
#   'keywords': ['회사채', '대림산업', '수요예측', '건설업', '신용등급'],
#   'createdAt': '2016-09-29 12:30:50'},
#  {'title': '"상장기업 77% 지배구조 취약"',
#   'keywords': ['기업지배구조', '남양유업', '한국금융지주', '신일산업', '대림그룹'],
#   'createdAt': '2016-09-02 18:40:14'},
#  {'title': "삼성그룹 지배구조 변환에 '물산·생명·전자·SDS' 수혜-하이투자증권",
#   'keywords': ['삼성물산', '삼성그룹', '삼성전자', '삼성sds', '삼성생명'],
#   'createdAt': '2016-08-19 08:26:55'},
#  {'title': '재도약 베트남 건설시장,국내 중기 진출박차',
#   'keywords': ['베트남', '호치민', '동화기업', '인프라공사', '중소기업중앙회'],
#   'createdAt': '2016-08-12 06:50:28'},
#  {'title': '[@공시]삼성물산, Samsung Display Vietnam Co.Ltd.와 9,294.1억 규모',
#   'keywords': ['vietnam', '공사수주', '삼성물산', '유지하'],
#   'createdAt': '2016-06-30 16:36:07'},
#  {'title': '삼성전자 주가 날아도 맥못추는 삼성그룹株 펀드',
#   'keywords': ['삼성전자', '삼성그룹주펀드', '수익률', '글로벌금융위기', '삼성물산'],
#   'createdAt': '2016-06-22 06:50:10'},
#  {'title': '삼성전자, 자회사간 시총 괴리 커져.. 인적분할 적기-교보',
#   'keywords': ['삼성전자', '인적분할', '현물출자', '삼성sdi', '레버리지'],
#   'createdAt': '2016-06-20 09:04:54'},
#  {'title': '[이데일리ON] 주신 김찬우의 주식 이야기 - 6월 15일 개장전 시황',
#   'keywords': ['전환사채', '임시주주총회', '미국상무부', '조정', '미국'],
#   'createdAt': '2016-06-15 10:17:03'},
#  {'title': '코스피지수 브렉시트 우려에 닷새째 하락..외인·기관 순매도',
#   'keywords': ['코스피', '혼조세', '지에스인스트루', '신흥국', '한진해운'],
#   'createdAt': '2016-06-15 09:41:03'},
#  {'title': '코스피 올랐는데..개인 매수 상위 종목 20개 중 13개 하락',
#   'keywords': ['코스피', '하락', '개인매수', '개', '순매수상위'],
#   'createdAt': '2019-02-10 08:03:04'},
#  {'title': '"자회사 통한 정규직 전환은 노동자 기만 행위"',
#   'keywords': ['정규직전환', '노동자', '갈등', '9일', '직접고용'],
#   'createdAt': '2019-02-09 13:00:11'},
#  {'title': '올들어 외국인 4.7조 순매수..어떤 종목 샀나',
#   'keywords': ['코스피', '주식시장', '삼성전자', 'sk하이닉스', '미중무역전쟁'],
#   'createdAt': '2019-02-09 05:03:00'},
#  {'title': '전기차·수소차 충전 사업, 다음주 규제 샌드박스 첫 승인',
#   'keywords': ['규제샌드박스', '전기차', '수소차', '규제', '문대통령'],
#   'createdAt': '2019-02-09 04:42:31'},
#  {'title': "코스피, 미중 무역분쟁 우려에 2200선 '붕괴'",
#   'keywords': ['코스피', '무역분쟁', '붕괴', '지수', '시간이흐르면'],
#   'createdAt': '2019-02-08 16:33:24'},
#  {'title': "[마켓뷰] 외인 '사자' 행렬에 제동..코스피 2170대로 후퇴",
#   'keywords': ['코스피', '지수', '무역협상', '시간이흐르면', '외국인순매수'],
#   'createdAt': '2019-02-08 16:31:07'},
#  {'title': '미중 정상회담 무산에 코스피 하락..2,200선 붕괴',
#   'keywords': ['미중정상회담', '코스피하락', '붕괴', '코스피', '지수'],
#   'createdAt': '2019-02-08 16:28:40'},
#  {'title': '[마감시황]코스피, 美中 정상회담 무산 소식에 2170선 후퇴',
#   'keywords': ['코스피', '미중정상회담', '하락세', '하락', '무역협상'],
#   'createdAt': '2019-02-08 16:21:55'},
#  {'title': '코스피, 닷새만에 2200선 내줘..美中 정상회담 무산 여파',
#   'keywords': ['코스피', '코스닥', '지수', '중국', '하락세'],
#   'createdAt': '2019-02-08 16:16:36'},
#  {'title': '코스피 닷새 만에 2,200 내줘..외인 매도에 2,170대 후퇴(종합2보)',
#   'keywords': ['코스피', '서울', '지수', '삼성전자', '시간이흐르면'],
#   'createdAt': '2019-02-08 16:13:33'},
#  {'title': '[마감] 코스피, G2 무역분쟁 우려·外人 매도에 2170선 후퇴',
#   'keywords': ['코스피', '무역분쟁', 'g2', '하락', '코스닥'],
#   'createdAt': '2019-02-08 16:10:22'},
#  {'title': '미중 리스크에 돌아선 외국인..코스피, 2170선 하락',
#   'keywords': ['하락', '코스피', '리스크', '무역협상', '증시'],
#   'createdAt': '2019-02-08 16:09:00'},
#  {'title': '코스피 닷새 만에 2,200 내줘..외인 매도에 2,170대 후퇴(종합)',
#   'keywords': ['코스피', '지수', '삼성전자', '서울', '시간이흐르면'],
#   'createdAt': '2019-02-08 15:59:40'},
#  {'title': '[코스피 마감]무역협상 불확실성 부각..4거래일만에 2200선 붕괴',
#   'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락'],
#   'createdAt': '2019-02-08 15:56:06'},
#  {'title': '[시황종합] 다시 미·중 무역분쟁..코스피, 2170선 후퇴',
#   'keywords': ['무역분쟁', '코스피', '코스닥', '하락', '환율'],
#   'createdAt': '2019-02-08 15:48:47'},
#  {'title': '[마감 시황] 코스피 0p 보합 마감',
#   'keywords': ['코스피', '하락', '보합세', '한국경제tv', '상장'],
#   'createdAt': '2019-02-08 15:36:03'},
#  {'title': '"판 주식이 올랐네" 반등장서 소외된 개미 울상',
#   'keywords': ['개미', '개', '삼성전자', 'sk하이닉스', '행진'],
#   'createdAt': '2019-02-08 15:33:04'},
#  {'title': '[이 시각 코스피] 코스피 현재 2178.07p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 15:01:14'},
#  {'title': '[이 시각 코스피] 코스피 현재 2176.72p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 14:01:43'},
#  {'title': "[1시 주식시장은] 미중 정상회담 불발.. 코스피 '쉬어가기?'",
#   'keywords': ['코스피', '미중정상회담', '지수', '하락', '순매도'],
#   'createdAt': '2019-02-08 13:17:52'},
#  {'title': '[이 시각 코스피] 코스피 현재 2179.42p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 13:01:17'},
#  {'title': "'덮어놓고 공기업化' 정책에 민간기업은 '공중분해' 위기",
#   'keywords': ['공기업', '위기', '정책', '한전산업개발', '7년'],
#   'createdAt': '2019-02-08 12:20:13'},
#  {'title': '지역난방공사, 권익위 부패방지 시책평가 7년 연속 최고등급',
#   'keywords': ['7년', '시책평가', '청렴도평가', '공공기관', '김형욱'],
#   'createdAt': '2019-02-08 12:17:05'},
#  {'title': '[이 시각 코스피] 코스피 현재 2177.83p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 12:01:52'},
#  {'title': "코스피, 외인·기관 동반 순매도에 1% 이상 '하락'..미·중 불확실성",
#   'keywords': ['코스피', '순매도', '하락', '동반', '불확실성'],
#   'createdAt': '2019-02-08 11:23:06'},
#  {'title': '[이 시각 코스피] 코스피 현재 2178.62p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 11:01:39'},
#  {'title': "코스피, 1% 이상 하락..美中 무역협상 불확실성 '한파'",
#   'keywords': ['하락', '코스피', '무역협상', '불확실성', '한파'],
#   'createdAt': '2019-02-08 10:56:41'},
#  {'title': '[시황점검] 10시 15분 코스피 -1% 대 하락폭 기록 - 외인 순매도(-765억원)',
#   'keywords': ['코스피', '15분', '순매도', '하락', '보이'],
#   'createdAt': '2019-02-08 10:17:01'},
#  {'title': '[이 시각 코스피] 코스피 현재 2187.58p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 10:01:41'},
#  {'title': "[오전시황] 미중 정상회담 불발.. 코스피 '쉬어가기?'",
#   'keywords': ['코스피', '미중정상회담', '지수', '하락', '무역협상'],
#   'createdAt': '2019-02-08 09:42:52'},
#  {'title': '미중 정상회담 무산에 코스피 하락 출발..2190선 붕괴',
#   'keywords': ['미중정상회담', '코스피하락', '붕괴', '무역협상', '증시'],
#   'createdAt': '2019-02-08 09:36:02'},
#  {'title': '코스피, 미·중 무역협상 불확실성에 2200선 하회',
#   'keywords': ['코스피', '무역협상', '불확실성', '하락', '순매도'],
#   'createdAt': '2019-02-08 09:23:37'},
#  {'title': '[출발 시황] 코스피 전일 대비 11.41p 내린 2192.01p에 개장',
#   'keywords': ['코스피', '개장', '하락', '보이', '하락세'],
#   'createdAt': '2019-02-08 09:06:11'},
#  {'title': '엔텔스, 5G 신규수요로 매출성장성 부각될 것-하이',
#   'keywords': ['5g', '엔텔스', '하이', '매출', '사물인터넷'],
#   'createdAt': '2019-02-08 08:27:24'},
#  {'title': '공공기관 체험형 인턴, 올해 7500명 채용하기로',
#   'keywords': ['인턴', '공공기관', '잡코리아', '하반기', '집계결과'],
#   'createdAt': '2019-02-08 03:11:03'},
#  {'title': '[포토]동서발전, 설연휴기간 사업장 안전점검 나서',
#   'keywords': ['동서발전', '설연휴기간', '김형욱', '세종', '발전설비'],
#   'createdAt': '2019-02-07 20:43:13'},
#  {'title': "결국 '개미 핥기'?.. 반도체株 손절매때 外人 저점매수로 수익 챙겼다",
#   'keywords': ['개미핥기', '손절매', '삼성전자', 'sk하이닉스', '개미'],
#   'createdAt': '2019-02-07 18:35:33'},
#  {'title': '통계엔 취업자로 잡히는 인턴, 세금으로 더 늘려',
#   'keywords': ['인턴', '세금', '채용', 'lh', '꼼수'],
#   'createdAt': '2019-02-07 18:35:27'},
#  {'title': "울진 원자력마이스터고 '저력있네'..탈원전 정책에도 취업률 97%",
#   'keywords': ['탈원전', '경쟁률', '졸업', '취업', '탈원전정책'],
#   'createdAt': '2019-02-07 18:19:45'},
#  {'title': '[마켓뷰] IT부품이 달군 코스닥..코스피는 숨고르기',
#   'keywords': ['코스닥', '코스피', 'it', '지수', '미국'],
#   'createdAt': '2019-02-07 17:14:57'},
#  {'title': "결국 '개미핥기'?..외국인 주도 '삼성전자 V자 반등' 미스터리",
#   'keywords': ['삼성전자', '개미핥기', 'sk하이닉스', '개미', '국내증시'],
#   'createdAt': '2019-02-07 16:54:47'},
#  {'title': "코스피, 기관 '팔자'에 약보합 마감..2200선 턱걸이",
#   'keywords': ['코스피', '턱걸이', '지수', '약보합세', '시가총액상위종목'],
#   'createdAt': '2019-02-07 16:09:19'},
#  {'title': '코스피, 기관 매도 공세에 보합 마감',
#   'keywords': ['코스피', '지수', '트럼프대통령', '무역협상', '코스닥'],
#   'createdAt': '2019-02-07 16:06:01'},
#  {'title': '[코스피 마감]숨고르기 돌입..3거래일 연속 약보합',
#   'keywords': ['코스피', '지수', '국내증시', '시가총액', '혼조세'],
#   'createdAt': '2019-02-07 15:59:36'},
#  {'title': '코스피, 차익실현 매물에 \'보합\'.."코스닥은 제넥신 덕에 \'급등\'"',
#   'keywords': ['제넥신', '코스피', '코스닥', '하락', '모건스탠리'],
#   'createdAt': '2019-02-07 15:55:01'},
#  {'title': '[시황종합] 코스피, 보합 마감..나흘째 2200선 지켜',
#   'keywords': ['코스피', '코스닥', '무역협상', '북미정상회담', '보이'],
#   'createdAt': '2019-02-07 15:49:55'},
#  {'title': '이창식 한국남동발전 제28대 삼천포발전본부장 취임',
#   'keywords': ['김동민', '취임사', '직장', '한국전력공사', 'image'],
#   'createdAt': '2019-02-07 15:23:30'},
#  {'title': '"중기전용 전기요금제 만들어달라"',
#   'keywords': ['중소기업', '전기요금', '요금제', '중기중앙회', '대기업'],
#   'createdAt': '2019-02-07 15:12:01'},
#  {'title': '중기중앙회 "中企 전용 전기요금 만들어야"',
#   'keywords': ['전기요금', '중소기업', '중기중앙회', '요금제', '국회'],
#   'createdAt': '2019-02-07 15:11:26'},
#  {'title': '"중기 96% 전기료 부담.. 전용 요금제 도입해 달라"',
#   'keywords': ['요금제', '중소기업', '전기요금', '조정', '중기중앙회'],
#   'createdAt': '2019-02-07 14:27:43'},
#  {'title': '공기업 체험형 인턴 7500여명 선발..상반기 집중',
#   'keywords': ['인턴', '공기업', '상반기', '채용', '잡코리아'],
#   'createdAt': '2019-02-07 14:02:04'},
#  {'title': '[1시 주식시장은]이어지는 외국인 매수세..코스피 강세',
#   'keywords': ['코스피', '증시', '지수', '북미정상회담', '미국증시'],
#   'createdAt': '2019-02-07 13:47:04'},
#  {'title': '중기업계 "대기업과 동일한 전기요금제 고쳐야"',
#   'keywords': ['중소기업', '대기업', '요금제', '전기요금', '중기중앙회'],
#   'createdAt': '2019-02-07 13:46:04'},
#  {'title': '중기중앙회 "중소기업 전용 전기요금제 만들어달라"',
#   'keywords': ['중소기업', '중기중앙회', '전기요금', '요금제', '한국전력'],
#   'createdAt': '2019-02-07 13:40:34'},
#  {'title': '"내가 던진 주식, 외국인이 사니 오르네"..거꾸로 가는 개미들',
#   'keywords': ['삼성전자', 'sk하이닉스', '국내증시', '개', '개미'],
#   'createdAt': '2019-02-07 13:35:48'},
#  {'title': '"대기업보다 전기요금 16% 비싸"..중기업계, 전용 요금제 마련 촉구',
#   'keywords': ['전기요금', '요금제', '중소기업', '전력', '중기중앙회'],
#   'createdAt': '2019-02-07 12:01:01'},
#  {'title': '중기중앙회, 중소기업 전용 전기요금제 마련 촉구',
#   'keywords': ['중소기업', '중기중앙회', '요금제', '전기요금', '로드맵'],
#   'createdAt': '2019-02-07 12:00:32'},
#  {'title': '중기중앙회 "전기요금 부담 덜어달라" 전용 요금제 촉구',
#   'keywords': ['전기요금', '요금제', '중기중앙회', '중소기업', '대기업'],
#   'createdAt': '2019-02-07 12:00:31'},
#  {'title': '"대기업보다 전기료 16%더 비싸"..中企 전용요금제 촉구',
#   'keywords': ['중소기업', '전기요금', '요금제', '중기중앙회', '조정'],
#   'createdAt': '2019-02-07 12:00:29'},
#  {'title': '중기중앙회, 중기 전용 전기 요금제 신설 촉구',
#   'keywords': ['요금제', '중기중앙회', '중소기업', '전기요금', '로드맵'],
#   'createdAt': '2019-02-07 12:00:17'},
#  {'title': '중소기업계 "中企 전용 전기요금제 도입해달라"',
#   'keywords': ['중소기업', '요금제', '전기요금', '중기중앙회', '국회'],
#   'createdAt': '2019-02-07 12:00:17'},
#  {'title': '中企 96% "전기료 부담 커"..전용 요금제 마련 촉구',
#   'keywords': ['요금제', '전기요금', '중소기업', '중기중앙회', '조정'],
#   'createdAt': '2019-02-07 12:00:13'},
#  {'title': '셀트리온헬스케어, 1,000원(-1.35%) 내린 73,300원에 거래 마감',
#   'keywords': ['셀트리온헬스케어', '한국경제tv'],
#   'createdAt': '2019-02-08 15:31:18'},
#  {'title': '셀트리온, 1,000원(0.47%) 오른 215,000원에 거래 마감',
#   'keywords': ['셀트리온', '한국경제tv'],
#   'createdAt': '2019-02-08 15:31:18'},
#  {'title': '[증시라인 - 하태민의 증시돋보기] 외국인들의 코스닥 5천억 쇼핑, 의미는?',
#   'keywords': ['하태민', '코스닥', '쇼핑', '미래', '순매도'],
#   'createdAt': '2019-02-08 15:05:16'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 729.19p 상승 반전',
#   'keywords': ['코스닥', '반전', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 15:01:15'},
#  {'title': '[이 시각 코스피] 코스피 현재 2178.07p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 15:01:14'},
#  {'title': '[ET투자뉴스]바이오주 테마 vs CCTV관련주 테마',
#   'keywords': ['바이오주', 'cctv관련주', '로봇', 'et', '하락세'],
#   'createdAt': '2019-02-08 14:30:11'},
#  {'title': '[돈 잘버는 증권맨에게 듣는다] 곽영훈 부장 "정부정책 수혜 전기차는 트렌드, 수소차는 테마..탑픽은 포스코켐텍"',
#   'keywords': ['포스코켐텍', '곽영훈', '정부정책', '전기차', '트렌드'],
#   'createdAt': '2019-02-08 14:06:34'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 727.91p 하락세 지속',
#   'keywords': ['코스닥', '하락세', '하락', '보이', 'it'],
#   'createdAt': '2019-02-08 14:01:44'},
#  {'title': '[이 시각 코스피] 코스피 현재 2176.72p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 14:01:43'},
#  {'title': "[1시 주식시장은] 미중 정상회담 불발.. 코스피 '쉬어가기?'",
#   'keywords': ['코스피', '미중정상회담', '지수', '하락', '순매도'],
#   'createdAt': '2019-02-08 13:17:52'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 727.96p 하락세 지속',
#   'keywords': ['코스닥', '하락세', '하락', '보이', 'it'],
#   'createdAt': '2019-02-08 13:01:18'},
#  {'title': '[이 시각 코스피] 코스피 현재 2179.42p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 13:01:17'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 726.65p 하락세 지속',
#   'keywords': ['코스닥', '하락세', '하락', '보이', 'it'],
#   'createdAt': '2019-02-08 12:01:52'},
#  {'title': '[이 시각 코스피] 코스피 현재 2177.83p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 12:01:52'},
#  {'title': "코스피, 외인·기관 동반 순매도에 1% 이상 '하락'..미·중 불확실성",
#   'keywords': ['코스피', '순매도', '하락', '동반', '불확실성'],
#   'createdAt': '2019-02-08 11:23:06'},
#  {'title': "코스피, 외국인 매도에 1%대 '하락'..2200선 '붕괴'",
#   'keywords': ['하락', '코스피', '붕괴', '순매도', '유가증권시장'],
#   'createdAt': '2019-02-08 11:01:40'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 727.58p 하락세 지속',
#   'keywords': ['코스닥', '하락세', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 11:01:40'},
#  {'title': '[이 시각 코스피] 코스피 현재 2178.62p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv'],
#   'createdAt': '2019-02-08 11:01:39'},
#  {'title': "코스피, 1% 이상 하락..美中 무역협상 불확실성 '한파'",
#   'keywords': ['하락', '코스피', '무역협상', '불확실성', '한파'],
#   'createdAt': '2019-02-08 10:56:41'},
#  {'title': '[시황점검] 10시 15분 코스피 -1% 대 하락폭 기록 - 외인 순매도(-765억원)',
#   'keywords': ['코스피', '15분', '순매도', '하락', '보이'],
#   'createdAt': '2019-02-08 10:17:01'},
#  {'title': '코스피 하락 출발..외인 매도에 장중 2,180대 후퇴(종합2보)',
#   'keywords': ['코스피하락', '지수', '코스피', '서울', '하락'],
#   'createdAt': '2019-02-08 10:08:36'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 727.16p 하락세 지속',
#   'keywords': ['코스닥', '하락세', '하락', '보이', 'it'],
#   'createdAt': '2019-02-08 10:01:41'},
#  {'title': '[이 시각 코스피] 코스피 현재 2187.58p 하락세 지속',
#   'keywords': ['코스피', '하락세', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 10:01:41'},
#  {'title': '셀트리온헬스케어(091990) 종목알파고 분석, 외국인/기관 실시간 수급과 추가 매수 확률은?',
#   'keywords': ['셀트리온헬스케어', '알파고', '한국경제tv', '2019년', '미국'],
#   'createdAt': '2019-02-08 09:57:40'},
#  {'title': "'팔자'로 돌아선 외국인..코스피 2200선 밑돌며 출발",
#   'keywords': ['코스피', '코스닥', '하락', '경영권', '지수'],
#   'createdAt': '2019-02-08 09:44:16'},
#  {'title': "[오전시황] 미중 정상회담 불발.. 코스피 '쉬어가기?'",
#   'keywords': ['코스피', '미중정상회담', '지수', '하락', '무역협상'],
#   'createdAt': '2019-02-08 09:42:52'},
#  {'title': '[ET투자뉴스]셀트리온_오늘 시장에서 선두로 나가면서 현재 +2.1%',
#   'keywords': ['셀트리온', '500원', '순매도', '유한양행', '한미약품'],
#   'createdAt': '2019-02-08 09:42:03'},
#  {'title': '셀트리온(068270) 종목알파고 분석, 외국인/기관 실시간 수급과 추가 매수 확률은?',
#   'keywords': ['셀트리온', '알파고', '한국경제tv', '램시마', '2019년'],
#   'createdAt': '2019-02-08 09:41:38'},
#  {'title': '[ET투자뉴스]한미약품_상장주식수 대비 거래량은 0.25%로 적정수준',
#   'keywords': ['한미약품', '500원', '수익률', '셀트리온', '삼성바이오로직스'],
#   'createdAt': '2019-02-08 09:38:04'},
#  {'title': '미중 정상회담 무산에 코스피 하락 출발..2190선 붕괴',
#   'keywords': ['미중정상회담', '코스피하락', '붕괴', '무역협상', '증시'],
#   'createdAt': '2019-02-08 09:36:02'},
#  {'title': '코스피 하락 출발..장중 2,180선 후퇴(종합)',
#   'keywords': ['코스피하락', '지수', '코스피', '서울', '하락'],
#   'createdAt': '2019-02-08 09:27:28'},
#  {'title': '코스피, 미·중 무역협상 불확실성에 2200선 하회',
#   'keywords': ['코스피', '무역협상', '불확실성', '하락', '순매도'],
#   'createdAt': '2019-02-08 09:23:37'},
#  {'title': '코스닥, 미·중 2월 정상회담 무산에 하락 출발',
#   'keywords': ['하락', '코스닥', '순매도', '경남제약', '보이'],
#   'createdAt': '2019-02-08 09:18:40'},
#  {'title': '코스피, 미중 무역협상 불확실성에 2200선 붕괴',
#   'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락'],
#   'createdAt': '2019-02-08 09:10:51'},
#  {'title': '[출발 시황] 코스닥 전일 대비 2.39p 내린 726.4p에 개장',
#   'keywords': ['코스닥', '개장', '하락', '보이', '보합세'],
#   'createdAt': '2019-02-08 09:06:12'},
#  {'title': '[출발 시황] 코스피 전일 대비 11.41p 내린 2192.01p에 개장',
#   'keywords': ['코스피', '개장', '하락', '보이', '하락세'],
#   'createdAt': '2019-02-08 09:06:11'},
#  {'title': '셀트리온헬스케어, 300원(-0.4%) 내린 74,000원에 거래 시작',
#   'keywords': ['셀트리온헬스케어', '한국경제tv'],
#   'createdAt': '2019-02-08 09:01:26'},
#  {'title': '셀트리온, 500원(-0.23%) 내린 213,500원에 거래 시작',
#   'keywords': ['500원', '셀트리온', '한국경제tv'],
#   'createdAt': '2019-02-08 09:01:25'},
#  {'title': '장 마감 후 주요 공시-7일',
#   'keywords': ['매출액', '영업이익', '매출', '영업손실', '조회공시'],
#   'createdAt': '2019-02-08 08:50:43'},
#  {'title': '[한경로보뉴스] 전일, 코스닥 외국인 순매수상위에 IT부품 업종 5종목',
#   'keywords': ['코스닥', '순매수상위', '포스코켐텍', '바이로메드', '셀트리온헬스케어'],
#   'createdAt': '2019-02-08 08:32:03'},
#  {'title': '[한경로보뉴스] 전일, 기관 코스닥에서 포스코켐텍(+6.17%), 와이지엔터테인먼트(+5.41%) 등 순매수',
#   'keywords': ['포스코켐텍', '와이지엔터테인먼트', '코스닥', '기관투자자', '순매수상위'],
#   'createdAt': '2019-02-08 08:32:02'},
#  {'title': "美 내년부터 제약사 리베이트 금지..셀트리온·삼성 '청신호'",
#   'keywords': ['리베이트', '셀트리온', '미국', '삼성', '바이오시밀러'],
#   'createdAt': '2019-02-08 07:50:07'},
#  {'title': '이틀간 2,200억..코스닥에도 지갑 연 外人',
#   'keywords': ['코스닥', 'it', '지갑', '바이오', '지수'],
#   'createdAt': '2019-02-07 17:18:57'},
#  {'title': "코스닥 외인 매수에 1.66% 상승..코스피는 '제자리'(종합2보)",
#   'keywords': ['코스피', '코스닥', '북미정상회담', '달러환율', '서울'],
#   'createdAt': '2019-02-07 16:50:30'},
#  {'title': "코스닥, 외인 매수에 석달만에 최고치..코스피는 '제자리'",
#   'keywords': ['코스닥', '코스피', '시가총액', '한국경제tv', '종가'],
#   'createdAt': '2019-02-07 16:46:26'},
#  {'title': "코스닥 외인 매수에 1.66% 상승..코스피는 '제자리'(종합)",
#   'keywords': ['코스닥', '코스피', '지수', '서울', '종가'],
#   'createdAt': '2019-02-07 16:17:12'},
#  {'title': '셀트리온, 990억 규모 자기주식 취득',
#   'keywords': ['셀트리온', '자기주식', '11월', '서진욱', '저작권'],
#   'createdAt': '2019-02-07 16:12:07'},
#  {'title': '[마감시황]코스피, 2200선 약보합 마감..코스닥은 1.66% 상승',
#   'keywords': ['코스피', '코스닥', '지수', '하락', '무역협상'],
#   'createdAt': '2019-02-07 16:08:54'},
#  {'title': '[코스피 마감]숨고르기 돌입..3거래일 연속 약보합',
#   'keywords': ['코스피', '지수', '국내증시', '시가총액', '혼조세'],
#   'createdAt': '2019-02-07 15:59:36'},
#  {'title': '[마감] 코스닥, 외인·기관 쌍끌이 매수에 1%대 급등',
#   'keywords': ['코스닥', '셀트리온헬스케어', 'cjenm', '바이로메드', '포스코켐텍'],
#   'createdAt': '2019-02-07 15:57:46'},
#  {'title': '코스피, 차익실현 매물에 \'보합\'.."코스닥은 제넥신 덕에 \'급등\'"',
#   'keywords': ['제넥신', '코스피', '코스닥', '하락', '모건스탠리'],
#   'createdAt': '2019-02-07 15:55:01'},
#  {'title': "[마감] 연휴 마친 코스피, '눈치보기'에 보합",
#   'keywords': ['코스피', '코스닥', '바이오주', '설연휴', '개장'],
#   'createdAt': '2019-02-07 15:52:49'},
#  {'title': '[마감 시황] 코스닥 전일 대비 11.87p 상승한 728.79p에 마감',
#   'keywords': ['코스닥', '보합세', 'it', 'w', '한국경제tv'],
#   'createdAt': '2019-02-07 15:36:07'},
#  {'title': '[마감 시황] 코스피 전일 대비 0.04p 하락한 2203.42p에 마감',
#   'keywords': ['코스피', '하락', '보합세', '하락세', '한국경제tv'],
#   'createdAt': '2019-02-07 15:36:06'},
#  {'title': '셀트리온헬스케어, 1,200원(1.64%) 오른 74,300원에 거래 마감',
#   'keywords': ['셀트리온헬스케어', '한국경제tv'],
#   'createdAt': '2019-02-07 15:31:29'},
#  {'title': '셀트리온, 500원(-0.23%) 내린 214,000원에 거래 마감',
#   'keywords': ['500원', '셀트리온', '한국경제tv', '33'],
#   'createdAt': '2019-02-07 15:31:29'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 728.1p 상승세 지속',
#   'keywords': ['코스닥', '보이', 'it', 'w', '33'],
#   'createdAt': '2019-02-07 15:01:23'},
#  {'title': '[이 시각 코스피] 코스피 현재 2208.63p 상승세 지속',
#   'keywords': ['코스피', '보이', '하락', '보합세', '한국경제tv'],
#   'createdAt': '2019-02-07 15:01:22'},
#  {'title': '1월 코스닥 공매도 1등 셀트리온헬스케어, 대장주 운명은',
#   'keywords': ['공매도', '셀트리온헬스케어', '대장주', '코스닥', '매출액'],
#   'createdAt': '2019-02-07 14:09:00'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 727.15p 상승세 지속',
#   'keywords': ['코스닥', '보이', 'it', 'w', '한국경제tv'],
#   'createdAt': '2019-02-07 14:01:52'},
#  {'title': '[이 시각 코스피] 코스피 현재 2207.55p 상승세 지속',
#   'keywords': ['코스피', '보이', '하락', '보합세', '한국경제tv'],
#   'createdAt': '2019-02-07 14:01:10'},
#  {'title': '바이오리더스, 자궁경부전암 치료제 임상 2상 마무리 단계.."신약 개발 박차"',
#   'keywords': ['신약개발', '바이오리더스', '유산균', '앵커', '미국'],
#   'createdAt': '2019-02-07 13:51:58'},
#  {'title': '대웅제약, 제약업종 Top-pick 유지',
#   'keywords': ['미국', 'top', '셀트리온', 'nh투자증권', '램시마'],
#   'createdAt': '2019-02-07 13:45:32'},
#  {'title': '[ET투자뉴스]대웅제약, "제약업종 Top-p.." BUY(유지)-NH투자증권',
#   'keywords': ['nh투자증권', 'top', '미국', '제시한', '컨센서스'],
#   'createdAt': '2019-02-07 13:36:03'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 726.31p 상승세 지속',
#   'keywords': ['코스닥', '보이', '33', 'it', 'w'],
#   'createdAt': '2019-02-07 13:01:44'},
#  {'title': '[이 시각 코스피] 코스피 현재 2209.74p 상승세 지속',
#   'keywords': ['코스피', '보이', '보합세', '하락세', '한국경제tv'],
#   'createdAt': '2019-02-07 13:01:43'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 726.58p 상승세 지속',
#   'keywords': ['코스닥', 'it', 'w', '한국경제tv', '하락'],
#   'createdAt': '2019-02-07 12:02:02'},
#  {'title': '[이 시각 코스피] 코스피 현재 2209.52p 상승세 지속',
#   'keywords': ['코스피', '보이', '하락세', '한국경제tv', '하락'],
#   'createdAt': '2019-02-07 12:01:15'},
#  {'title': '[시황] 코스닥, 1%대 급등.. 콘텐츠·게임 업종 강세',
#   'keywords': ['콘텐츠', '게임', '코스닥', 'cjenm', '펄어비스'],
#   'createdAt': '2019-02-07 11:10:57'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 724.89p 상승세 지속',
#   'keywords': ['코스닥', '보이', 'it', 'w', '33'],
#   'createdAt': '2019-02-07 11:01:20'},
#  {'title': '[이 시각 코스피] 코스피 현재 2208.24p 상승세 지속',
#   'keywords': ['코스피', '보이', '보합세', '하락세', '한국경제tv'],
#   'createdAt': '2019-02-07 11:01:20'},
#  {'title': "코스피, 외국인·개인 매수에 '상승'..코스닥은 1%↑",
#   'keywords': ['코스피', '개인매수', '코스닥', '보이', '하락'],
#   'createdAt': '2019-02-07 10:56:02'},
#  {'title': '[시황점검] 10시 44분 코스닥 1% 대 상승폭 기록 - 외인 순매수(610억원)',
#   'keywords': ['코스닥', '보이', 'it', 'w', '한국경제tv'],
#   'createdAt': '2019-02-07 10:45:32'},
#  {'title': '코스피 상승 출발 후 혼조세..장중 2,190대 후퇴(종합2보)',
#   'keywords': ['코스피', '혼조세', '지수', '국내증시', '시가총액'],
#   'createdAt': '2019-02-07 10:44:26'},
#  {'title': '바이오리더스 "자궁경부전암 치료제 임상 2상 마무리 단계"',
#   'keywords': ['바이오리더스', '신약개발', '유산균', '앵커', '미국'],
#   'createdAt': '2019-02-07 10:42:38'},
#  {'title': '[ET투자뉴스]휴젤_상대적인 하락폭 더욱 커 현재 -2.93%',
#   'keywords': ['셀트리온제약', '메디톡스', '코미팜'],
#   'createdAt': '2019-02-07 10:06:04'},
#  {'title': '[이 시각 코스닥] 코스닥 현재 722.41p 상승세 지속',
#   'keywords': ['코스닥', '보이', 'it', 'w', '한국경제tv'],
#   'createdAt': '2019-02-07 10:01:54'},
#  {'title': "'J노믹스' 2기 경제정책 핵심은 대규모 토목사업",
#   'keywords': ['soc', 'j노믹스', '경제정책', '토목사업', '부산'],
#   'createdAt': '2019-01-28 15:21:24'},
#  {'title': "증시는 오르는데..공매도 몰리는 종목은 '몸살'",
#   'keywords': ['공매도', '셀트리온', '증시', '삼성전기', '하락'],
#   'createdAt': '2019-01-21 05:10:08'},
#  {'title': "'신차 효과' 기대감..현대차 시총 3위 탈환",
#   'keywords': ['셀트리온', '신차효과', '팰리세이드', '신형쏘나타', '시가총액'],
#   'createdAt': '2019-01-15 17:30:53'},
#  {'title': "[마켓인]한기평, 현대트랜시스 신용등급 'AA-'로 상향",
#   'keywords': ['한기평', '현대자동차', '현대다이모스', '005380', '한국기업평가'],
#   'createdAt': '2019-01-08 16:56:38'},
#  {'title': '[CES 8일 개막]"성장 잭팟 찾아라"..국내 CEO 총집결',
#   'keywords': ['ces', '삼성전자', 'it', '자율주행', '현대자동차'],
#   'createdAt': '2019-01-06 16:35:57'},
#  {'title': '[머니+ 포트포리오 리모델링] 증시 먹구름 꼈지만.."반도체·조선·건설·車 역발상 투자"',
#   'keywords': ['sk하이닉스', 'lng선', '반도체', '수주', '성장률'],
#   'createdAt': '2019-01-05 08:10:50'},
#  {'title': "[마켓인]현대다이모스 'AA-'로 상향..큰 폭 실적 증가",
#   'keywords': ['현대파워텍', '자동변속기', '최중기', '기업평가', '현대다이모스'],
#   'createdAt': '2019-01-02 18:35:47'},
#  {'title': '[장중 기업공시]1월 2일',
#   'keywords': ['알루미늄', '포스코', '한국철도공사', '유진테크', '특허취득'],
#   'createdAt': '2019-01-02 17:31:37'},
#  {'title': "'경제 컨트럴타워' 기재부 공무원들이 걱정하는 올해 최대 악재는?",
#   'keywords': ['최저임금', '갈등', '리스크', '반도체', '일자리'],
#   'createdAt': '2019-01-02 06:00:50'},
#  {'title': '미래기술 발굴하러..특명받은 CES 참관단',
#   'keywords': ['ces', '글로벌기업', '5g', '전시회', '미래'],
#   'createdAt': '2019-01-02 05:00:19'},
#  {'title': '기업공시[12월28일]',
#   'keywords': ['수주', '공사수주', '고속도로', '동부건설', '새만금'],
#   'createdAt': '2018-12-30 10:19:45'},
#  {'title': '계속되는 최저임금 논란..이번에도 막판 땜질 대책만',
#   'keywords': ['최저임금', '주휴수당', '일자리안정자금', '근로자', '연착륙'],
#   'createdAt': '2018-12-26 17:20:33'},
#  {'title': '[2019 경제정책] "내년 경기·고용 부진"..투자활성화 \'올인\'',
#   'keywords': ['탄력근로제', '성장률', '최저임금', 'soc', '결정구조'],
#   'createdAt': '2018-12-17 11:41:11'},
#  {'title': '광주형 일자리, 새로운 시도지만 우려도 존재-IBK',
#   'keywords': ['현대자동차', '광주형일자리', '폭스바겐', '지역갈등', '갈등'],
#   'createdAt': '2018-12-05 09:15:28'},
#  {'title': '글로벌서 품질 인정받는 현대·기아차',
#   'keywords': ['기아자동차', '코나', '현대자동차', '제네시스g70', '북미'],
#   'createdAt': '2018-12-01 10:30:01'},
#  {'title': '[장대표의 패턴매매로 산다!] 장영한이 포착한 시스템 매매 유망주는? <더블유게임즈(192080)> 外',
#   'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미'],
#   'createdAt': '2018-11-23 17:56:51'},
#  {'title': "'비실비실' 현대차..9년만에 10만원대 아래로(종합)",
#   'keywords': ['현대자동차', '기아자동차', '신용등급', '영업이익률', '전기차'],
#   'createdAt': '2018-11-20 16:06:10'},
#  {'title': "힘 못쓰는 현대차..'부정적' 전망에 10만원대 아래로",
#   'keywords': ['현대자동차', '기아자동차', '신용등급', '현대모비스', '무디스'],
#   'createdAt': '2018-11-20 15:17:34'},
#  {'title': '[장대표의 패턴매매로 산다!] 장영한이 포착한 시스템 매매 유망주는? <현대차(005380)> 外',
#   'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미'],
#   'createdAt': '2018-11-16 16:50:05'},
#  {'title': "[28th SRE][Worst]팽팽한 상·하향..우량기업 수위권 '눈길'(종합)",
#   'keywords': ['롯데쇼핑', '호텔롯데', '기아자동차', '신용등급', '한기평'],
#   'createdAt': '2018-11-16 11:00:19'},
#  {'title': '[특징주]현대차·기아차, 잇따른 신용등급 하향조정에 하락세',
#   'keywords': ['현대자동차', '기아자동차', '신용등급', '한국신용평가', '약세기조'],
#   'createdAt': '2018-11-13 09:14:29'},
#  {'title': '"제약·바이오株, 실적 기반 접근 필요..최선호 대웅제약·삼성바이오"',
#   'keywords': ['바이오', '삼성바이오로직스', 'nh투자증권', '바이로메드', '임상결과'],
#   'createdAt': '2018-11-13 08:42:20'},
#  {'title': '[마켓인]한신평, 현기차·현대캐피탈·현대카드 등급전망↓(종합2보)',
#   'keywords': ['신용등급', '기아자동차', '현대카드', '현대자동차', '현대캐피탈'],
#   'createdAt': '2018-11-12 19:16:34'},
#  {'title': '후진하는 현대차 10만원 깨지나',
#   'keywords': ['현대자동차', '영업이익', '신용등급', '배당수익률', '무디스'],
#   'createdAt': '2018-11-12 17:22:16'},
#  {'title': "3분기 상장사 37% '어닝쇼크'..반도체 고점 논란 4분기가 더 문제",
#   'keywords': ['어닝쇼크', '영업이익', '상장사', '컨센서스', '반도체'],
#   'createdAt': '2018-11-07 06:10:37'},
#  {'title': '현대차 하락세..신용등급 하향 조정 여파 여전',
#   'keywords': ['신용등급', '현대자동차', '조정', '005380', '하락세'],
#   'createdAt': '2018-11-05 10:07:30'},
#  {'title': '[특징주]현대·기아차, 글로벌 수요 부진 우려에 동반 하락',
#   'keywords': ['기아자동차', '현대자동차', '사이크', '무디스', '005380'],
#   'createdAt': '2018-11-05 09:58:16'},
#  {'title': '"현대·기아차, 실적부진 지속시 등급 하향 가능성 높아"-삼성',
#   'keywords': ['신용등급', '현대자동차', '기아자동차', '삼성증권', '무디스'],
#   'createdAt': '2018-11-02 08:25:18'},
#  {'title': '현대·기아차 신용등급 하향..2~3차 벤더 영향 우려-SK',
#   'keywords': ['신용등급', '현대자동차', '기아자동차', '벤더', 's&p'],
#   'createdAt': '2018-11-02 07:51:44'},
#  {'title': "美, 대기업 '방북사업 보고' 돌연 취소",
#   'keywords': ['컨퍼런스콜', '대북제재', '재무부', '한국정부', '최근북한'],
#   'createdAt': '2018-11-01 17:57:28'},
#  {'title': "[마켓인]S&P 이어 무디스도..현대차·기아차 신용등급 '흔들'(종합)",
#   'keywords': ['현대자동차', '신용등급', '기아자동차', '조정', '현대모비스'],
#   'createdAt': '2018-11-01 14:46:48'},
#  {'title': "[마켓인]S&P 이어 무디스도..현대차·기아차 신용등급 '흔들'(종합)",
#   'keywords': ['현대자동차', '신용등급', '기아자동차', '조정', '현대모비스'],
#   'createdAt': '2018-11-01 14:46:47'},
#  {'title': '현대차·기아차·현대모비스, S&P 신용등급 하향에 장 초반 동반하락',
#   'keywords': ['현대자동차', '기아자동차', '현대모비스', 's&p', '신용등급'],
#   'createdAt': '2018-11-01 09:40:10'},
#  {'title': 'S&P, 현대·기아차·모비스 등급 4년만에 BBB+로 내려',
#   'keywords': ['신용등급', 's&p', '현대자동차', '기아자동차', '적자'],
#   'createdAt': '2018-10-31 23:21:11'},
#  {'title': '[마켓인]파워텍 흡수하는 현대다이모스, 상향검토대상 올려-나이스',
#   'keywords': ['현대다이모스', '현대파워텍', '자동변속기', '005380', '변속기'],
#   'createdAt': '2018-10-22 15:33:21'},
#  {'title': '[현대차 체코공장 가보니]노사 10년째 無파업..생산성 한국의 2배',
#   'keywords': ['현대자동차', '생산성', '부품', '품질경영', '임금협상'],
#   'createdAt': '2018-10-09 16:35:18'},
#  {'title': "[파리모터쇼 4일 개막] 덩치 키우고 스피드 높이고..스포츠 세단·SUV '신차들의 향연'",
#   'keywords': ['파리모터쇼', '모델', '현대자동차', '벤츠', '전기차'],
#   'createdAt': '2018-09-30 17:29:57'},
#  {'title': '[마켓뷰] MSCI EM지수 편입 비중 조정에 韓·中 엇갈려',
#   'keywords': ['msci', '중국a주', '지수', '의약품', '코스닥'],
#   'createdAt': '2018-09-28 16:37:26'},
#  {'title': '[시그널 단독] 車개발 설계시스템 전면개편..현대차, 품질경영 업그레이드',
#   'keywords': ['현대자동차', '설계', '소형차', '아반떼', '남양연구소'],
#   'createdAt': '2018-09-12 17:02:03'},
#  {'title': '[빅데이터MSI]시장심리 톱5, LG이노텍·LG디스플레이·LS산전·한국토지신탁·SK이노베이션',
#   'keywords': ['현대자동차', '메르스', '대한항공', '한샘', 'sk이노베이션'],
#   'createdAt': '2018-09-11 09:00:11'},
#  {'title': "코스피, 파월의 '비둘기'에도 2300 문턱서 횡보",
#   'keywords': ['파월', '폼페이오', '순매도', 'sk하이닉스', '지수'],
#   'createdAt': '2018-08-27 09:58:49'},
#  {'title': '[ET투자뉴스]셀트리온, "흔들릴 이유 없다.." BUY(유지)-NH투자증권',
#   'keywords': ['nh투자증권', '제시한', '매출액', '영업이익', '트룩시마'],
#   'createdAt': '2018-08-09 13:08:05'},
#  {'title': '셀트리온, 하반기 모멘텀 기대 - NH',
#   'keywords': ['매출액', '영업이익', '셀트리온', '기업광고', '영업이익률'],
#   'createdAt': '2018-08-09 08:44:39'},
#  {'title': '"거봐, 버티자고 했지?"..코스피는 \'삼바\' 축제중',
#   'keywords': ['삼바', '바이오', '삼성전자', '삼성바이오로직스', '신수종'],
#   'createdAt': '2018-08-09 07:48:51'},
#  {'title': '안정성 부각되는 실적호전株, 하락장에도 선방',
#   'keywords': ['바이오주', '내수', '코스닥', 'stx엔진', '마켓포인트'],
#   'createdAt': '2018-07-02 14:45:44'},
#  {'title': '[주간증시전망]오락가락 대북정책에도 꿋꿋한 외국인..안도랠리 이어질까',
#   'keywords': ['북미정상회담', '지수', '코스피', '국채금리', '유가'],
#   'createdAt': '2018-05-27 08:30:08'},
#  {'title': "[미리보는 이데일리신문]'사회적 대화' 테이블 걷어찬 민주노총",
#   'keywords': ['이데일리신문'],
#   'createdAt': '2018-05-22 22:56:02'},
#  {'title': '[마켓뷰] 5만원 밑으로 떨어진 삼성전자..코스피, 중국발 악재에 흔들',
#   'keywords': ['바이오', '코스피', '신흥국', '셀트리온', '중국a주'],
#   'createdAt': '2018-05-15 17:13:43'},
#  {'title': '[제27회 SRE]"사업전망 불확실..AAA 현대차 등급 낮춰라"',
#   'keywords': ['현대자동차', '롯데그룹', '신용등급', '조정', '롯데쇼핑'],
#   'createdAt': '2018-05-15 06:01:44'},
#  {'title': '정의선 "흔들리지 않겠다"..엘리엇 "반대 투표할 것"(종합)',
#   'keywords': ['엘리엇', '현대모비스', '합병', '모비스', '지주회사'],
#   'createdAt': '2018-05-11 11:44:35'},
#  {'title': '정의선 "현대차 미래, 모비스에 달려..지배구조 개편 흔들리지 않겠다"',
#   'keywords': ['모비스', '현대모비스', '현대자동차', '제네시스', '자사주소각'],
#   'createdAt': '2018-05-11 10:53:35'},
#  {'title': '엘리엇, 현대차에 선전포고.."지배구조 개편안 반대투표"(종합)',
#   'keywords': ['엘리엇', '합병', '현대모비스', '삼성물산', '현대차그룹'],
#   'createdAt': '2018-05-11 10:15:38'},
#  {'title': "주행성능·안전성 높인 '2018 쏘나타 뉴라이즈 택시' 출시",
#   'keywords': ['택시', '쏘나타', '쏘나타뉴라이즈', '자동변속기', '변속기'],
#   'createdAt': '2018-05-09 16:28:55'},
#  {'title': "바이오주 또 급락..중소형주펀드 엇갈리는 '희비'",
#   'keywords': ['바이오주', '수익률', '보건의료', '밸류에이션', '휠라코리아'],
#   'createdAt': '2018-05-08 17:35:57'},
#  {'title': '코스피, 4거래일 만에 상승..삼성전자 복귀 2일만에 강세',
#   'keywords': ['삼성전자', '삼성바이오로직스', '액면분할', '순매도', '분식회계'],
#   'createdAt': '2018-05-08 10:00:17'},
#  {'title': '[다름의 성공학]세상에 없는 컴퓨터만 만든다..여의시스템',
#   'keywords': ['부품', '컴퓨터사업', '4차산업혁명', '애프터서비스', '컴퓨터사양'],
#   'createdAt': '2018-05-04 04:56:35'},
#  {'title': '거리로 뛰쳐나온 개미들..공매도 손질 이끌어내나',
#   'keywords': ['공매도', '소액주주', '셀트리온', '삼성증권', '주총'],
#   'createdAt': '2018-04-22 13:13:24'},
#  {'title': '현대차, 1Q 영업익 전년비 23% 감소한 9,670억원.."내년까지 경쟁력 판가름"-미래에셋대우',
#   'keywords': ['영업이익', '현대자동차', '싼타페', '005380', '넥쏘'],
#   'createdAt': '2018-04-19 08:53:41'},
#  {'title': '[투자보고서 REAL] 부진의 긴 터널, 드디어 끝이 보인다? 현대차',
#   'keywords': ['내수', '싼타페', '신차효과', '기저효과', '신흥국'],
#   'createdAt': '2018-04-17 16:00:28'},
#  {'title': '현대차그룹 지배구조 개선 요구한 엘리엇..SRI펀드, 빛볼까',
#   'keywords': ['행동주의', '엘리엇', '주주환원정책', '컴투스', 'kb자산운용'],
#   'createdAt': '2018-04-04 16:47:40'},
#  {'title': "현대차 '여직원 술자리 동행 강요' 논란 여성임원, 결국 사임",
#   'keywords': ['현대자동차', '술자리', '005380', '현대오토에버', '현대차그룹'],
#   'createdAt': '2018-04-03 14:43:03'},
#  {'title': "현대모비스·글로비스 '봄날' 오나",
#   'keywords': ['현대글로비스', '현대모비스', '조정', '에프앤가이드', '스탠더드앤드푸어스'],
#   'createdAt': '2018-04-01 16:50:30'},
#  {'title': '[마켓인]S&P "현대모비스, 사업 분할해도 신용도 영향 無"',
#   'keywords': ['현대모비스', 'ebitda', 's&p', '신용등급', '현대자동차그룹'],
#   'createdAt': '2018-03-30 16:23:06'},
#  {'title': '[그것이 사고 싶다] 생산기지 이전..제품믹스 효과 기대 <제이에스코퍼레이션> 外',
#   'keywords': ['사도', '액면분할', '현대글로비스', '박스권', '밸류에이션'],
#   'createdAt': '2018-03-29 17:04:18'},
#  {'title': "현대·기아차 점유율 83% '사상 최대', 왜?",
#   'keywords': ['기아자동차', '현대자동차', '신차', '싼타페', '한국gm'],
#   'createdAt': '2018-03-15 16:36:39'},
#  {'title': "변동성장엔 장사없네..액티브·인덱스펀드 수익률 '지지부진'",
#   'keywords': ['수익률', '인덱스펀드', '코스닥', '주식형펀드', '셀트리온'],
#   'createdAt': '2018-03-12 16:13:57'},
#  {'title': '[그것이 사고 싶다] 국내 1위 채소종자 전문기업 <농우바이오> 外',
#   'keywords': ['사도', '코스피200지수', '기술적반등', '종자', '영업익'],
#   'createdAt': '2018-03-09 17:27:50'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #삼성전자 #셀트리온 #스튜디오드래곤 #내일 #톱픽은?',
#   'keywords': ['특징주', '삼성전자', '오늘증시', '셀트리온', '코스피200지수'],
#   'createdAt': '2018-03-05 17:13:26'},
#  {'title': '[그것이 사고 싶다] 넷플릭스 콘텐츠 제공 기대 <스튜디오드래곤> 外',
#   'keywords': ['사도', '박스권', '영업이익', '셀트리온', '120'],
#   'createdAt': '2018-03-05 17:08:46'},
#  {'title': '취약업종 또 부진한 4Q 실적..신용도 우려 지속된다',
#   'keywords': ['한국항공우주', 'ebitda', '스프레드', '영업이익률', 'nh투자증권'],
#   'createdAt': '2018-02-26 08:57:10'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #현대차 #OLED 관련주 #아모레퍼시픽 #예림당 #내일 #톱픽은?',
#   'keywords': ['특징주', '아모레퍼시픽', '오늘증시', '현대자동차', '예림당'],
#   'createdAt': '2018-02-21 17:53:48'},
#  {'title': '[리포트 인터뷰] 엄여진 "셀트리온만 볼 필요 없어요. 예쁜 바이오 종목 많아요"',
#   'keywords': ['바이오', '파이프라인', '부광약품', '제넥신', '오픈이노베이션'],
#   'createdAt': '2018-02-17 11:00:17'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #셀트리온 #삼성전자 #아모레퍼시픽 #에스피지 #내일 #톱픽은?',
#   'keywords': ['특징주', '에스피지', '오늘증시', '삼성전자', '셀트리온'],
#   'createdAt': '2018-02-12 17:55:34'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #셀트리온 #대우건설 #엔씨소프트 #두산밥캣 #내일 #톱픽은?',
#   'keywords': ['특징주', '두산밥캣', '오늘증시', '셀트리온', '엔씨소프트'],
#   'createdAt': '2018-02-08 17:24:29'},
#  {'title': '조여오는 삼성 지배구조 압박..이재용의 선택은',
#   'keywords': ['삼성전자', '순환출자', '삼성', '삼성물산', '삼성생명'],
#   'createdAt': '2018-02-08 06:00:57'},
#  {'title': '㈜셀트리온, 9일 코스피 상장',
#   'keywords': ['상장법인', '셀트리온', '코스닥', '유가증권시장본부', '오알켐'],
#   'createdAt': '2018-02-07 17:55:47'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #삼성전자 #OCI #현대차 #손오공 #내일 #톱픽은?',
#   'keywords': ['특징주', '현대자동차', '오늘증시', '005380', '삼성전자'],
#   'createdAt': '2018-02-06 17:58:19'},
#  {'title': '[산업현장, 숙련공이 사라진다]늙어가는 정규직에 막혀..2030 숙련기술 못살리고 일용직 전전',
#   'keywords': ['사내하청', '조선업', '일자리', '정규직', '정비업무'],
#   'createdAt': '2018-01-30 17:11:25'},
#  {'title': '[그것이 사고 싶다] 실적 턴어라운드 원년 전망 <에이디테크놀로지> 外',
#   'keywords': ['사도', '코스닥', '박스권', '파운드리', '정치적이슈'],
#   'createdAt': '2018-01-25 18:09:45'},
#  {'title': '[마켓리더에게 듣는다]윤희도 한투證 센터장 "코스피 상승 여력 있다"',
#   'keywords': ['바이오주', '코스피', '코스닥', '지수', '경기민감주'],
#   'createdAt': '2018-01-25 16:47:23'},
#  {'title': '[투자보고서 REAL] 현대차, 최악 실적 전망에도 외국인 왜 살까?',
#   'keywords': ['임단협', '광군절', '영업이익률', '영업이익', '분석'],
#   'createdAt': '2018-01-24 15:59:49'},
#  {'title': '"외국인 추가 선물매도 가능성에 무게" - NH',
#   'keywords': ['순매도', '코스피200', '중국a주', '선물계약', 'msci'],
#   'createdAt': '2018-01-23 08:19:46'},
#  {'title': '셀트리온 이전상장해도 코스닥150 급락은 없다',
#   'keywords': ['코스닥', '셀트리온', '지수', 'etf', '폭락'],
#   'createdAt': '2018-01-22 17:17:37'},
#  {'title': '[이슈&마켓]"주가 올리자" 임상실험에도 참여하는 \'셀빠\'(셀트리온 극렬주주)',
#   'keywords': ['셀트리온', '임상시험', '문자폭탄', '노무라증권', '유가증권시장'],
#   'createdAt': '2018-01-21 16:37:33'},
#  {'title': '\'JP모건 헬스케어\' 참가한 제약사들, "이젠 당당한 주인공"',
#   'keywords': ['jp모건', '헬스케어', 'sk바이오팜', '콘퍼런스', 'lg화학'],
#   'createdAt': '2018-01-13 16:10:35'},
#  {'title': '막내린 JP모건 헬스케어 컨퍼런스, 국내 기업 성과는?',
#   'keywords': ['jp모건', 'lg화학', '셀트리온', '헬스케어', '아스트라제네카'],
#   'createdAt': '2018-01-12 13:17:45'},
#  {'title': "'신기술 격전지' CES 개막..자율주행차·5G·AI 등 관련株 주목",
#   'keywords': ['ces', '삼성전자', '인공지능', '5g', '4차산업혁명'],
#   'createdAt': '2018-01-09 19:16:41'},
#  {'title': '[CES 2018]집엔 로봇집사, 거리엔 자율차 질주',
#   'keywords': ['ces', 'ai', '삼성전자', '로봇', '현대자동차'],
#   'createdAt': '2018-01-09 05:00:46'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! #셀트리온 #신라젠 #롯데케미칼 #내일 #탑픽은?',
#   'keywords': ['특징주', '오늘증시', '035420', '셀트리온', 'lg전자'],
#   'createdAt': '2018-01-08 17:55:04'},
#  {'title': "2년만에 다보스포럼 찾는 최태원 SK 회장..'한국의 밤'도 다시 열려",
#   'keywords': ['다보스포럼', '신동빈', 'fractured', 'sk그룹', '세계경제포럼'],
#   'createdAt': '2018-01-08 10:31:01'},
#  {'title': '[이 종목은 왜?] 오늘의 특징주! 시장 변동성의 중심 \'셀트리온\' & "지주사 그뤠잇!" 주가는? \'효성\'',
#   'keywords': ['특징주', '효성', '분식회계', '인적분할', '오늘증시'],
#   'createdAt': '2018-01-04 18:01:01'},
#  {'title': "'김상조 효과' 지배구조 서두르는 재계..속도 못 내는 현대차",
#   'keywords': ['순환출자', '효성', '합병', '현대자동차', '태광그룹'],
#   'createdAt': '2018-01-04 10:40:15'},
#  {'title': '삼성에 칼 겨눈 김상조 "삼성물산 404만주 더 팔아라"',
#   'keywords': ['공정위', '삼성sdi', '합병', '삼성물산', '매각'],
#   'createdAt': '2017-12-21 16:36:42'},
#  {'title': '[그것이 사고 싶다] 풍력·ESS·도시재생 사업 가속화 전망 <SK디앤디> 外 등',
#   'keywords': ['사도', '박스권', '현대미포조선', '도시재생사업', '문재인정부'],
#   'createdAt': '2017-12-06 17:57:28'},
#  {'title': '준(準)재벌된 SM, 순환출자고리 148개로 1위..공정위, 해소 압박',
#   'keywords': ['순환출자', '대기업집단', '공정위', 'sm그룹', '건설업'],
#   'createdAt': '2017-11-30 12:01:04'},
#  {'title': '[마켓인][26th SRE][WORST]먹구름 드리운 현대·기아차 왕국',
# ...
#   'keywords': ['사모전환사채', 'sk하이닉스', '사외이사', '특허취득', '키움증권'],
#   'createdAt': '2018-11-16 06:00:05'},
#  {'title': '[장중 기업공시]11월 15일',
#   'keywords': ['sk하이닉스', '사외이사', '특허취득', '폴란드', 'cj'],
#   'createdAt': '2018-11-15 16:30:13'},
#  {'title': '[투자노트] 전쟁터에서도 부자는 나온다',
#   'keywords': ['연기금', '미·중무역전쟁', '무역전쟁', '하나', '금리인상'],
#   'createdAt': '2018-10-31 07:34:52'},
#  {'title': '[마켓뷰] MSCI EM지수 편입 비중 조정에 韓·中 엇갈려',
#   'keywords': ['msci', '중국a주', '지수', '의약품', '코스닥'],
#   'createdAt': '2018-09-28 16:37:26'},
#  {'title': "코스피, 파월의 '비둘기'에도 2300 문턱서 횡보",
#   'keywords': ['파월', '폼페이오', '순매도', 'sk하이닉스', '지수'],
#   'createdAt': '2018-08-27 09:58:49'},
#  {'title': '중국A주 MSCI 추가편입되지만.."韓증시 영향 적을것"',
#   'keywords': ['msci', '중국a주', '지수', 'lg유플러스', '삼성중공업'],
#   'createdAt': '2018-08-15 17:16:04'},
#  {'title': '러셀 루빈 WD이사 "차량용메모리, 韓 완성차·티어1 공급"',
#   'keywords': ['웨스턴디지털', '루빈', '낸드플래시', 'd램', '삼성전자'],
#   'createdAt': '2018-07-20 05:00:06'},
#  {'title': "운용사 대표펀드, 상반기 성적표는 '흐림'",
#   'keywords': ['수익률', '주식형펀드', '지수', '벤치마크', '유출'],
#   'createdAt': '2018-06-04 16:43:21'},
#  {'title': "[펀드와치]IT株 살아나자 국내주식형 펀드도 '방긋'",
#   'keywords': ['주식형펀드', '수익률', '채권형펀드', '신흥국', 'sk하이닉스'],
#   'createdAt': '2018-05-27 09:00:26'},
#  {'title': '[주간증시전망]오락가락 대북정책에도 꿋꿋한 외국인..안도랠리 이어질까',
#   'keywords': ['북미정상회담', '지수', '코스피', '국채금리', '유가'],
#   'createdAt': '2018-05-27 08:30:08'},
#  {'title': '코스피, 외인·기관 쌍끌이 매수에도 약보합세',
#   'keywords': ['중국a주', 'msci', '관망심리', '뉴욕증권거래소', '철강금속'],
#   'createdAt': '2018-05-14 09:58:35'},
#  {'title': '코스피, 4거래일 만에 상승..삼성전자 복귀 2일만에 강세',
#   'keywords': ['삼성전자', '삼성바이오로직스', '액면분할', '순매도', '분식회계'],
#   'createdAt': '2018-05-08 10:00:17'},
#  {'title': '"한국 증시, 3중고 몰려온다"..당분간 관망세 유지를',
#   'keywords': ['국내증시', '골드만삭스', '신흥국', '지수', '대신증권'],
#   'createdAt': '2018-04-16 17:29:02'},
#  {'title': "유연근무제에도 '줄야근'..난감한 대기업들",
#   'keywords': ['유연근무제', '퇴근', '근무시간', '전자업계', '시차출퇴근제'],
#   'createdAt': '2018-03-21 06:00:56'},
#  {'title': '[CES 2018]집엔 로봇집사, 거리엔 자율차 질주',
#   'keywords': ['ces', 'ai', '삼성전자', '로봇', '현대자동차'],
#   'createdAt': '2018-01-09 05:00:46'},
#  {'title': "[펀드와치]IT株 부진에 국내 주식형펀드도 '미끌'",
#   'keywords': ['수익률', '주식형펀드', '채권형펀드', '삼성전자', 'sk하이닉스'],
#   'createdAt': '2017-12-03 09:09:00'},
#  {'title': '"SK머티리얼즈, 실적 개선세 주목해야..목표주가 상향" - 신한',
#   'keywords': ['영업이익', '유기발광다이오드', 'oledtv', 'oled', '밸류에이션'],
#   'createdAt': '2017-12-01 08:55:53'},
#  {'title': "힘 받는 소비재株..부진했던 '액티브펀드' 부활하나",
#   'keywords': ['수익률', '삼성전자', '화장품', '인덱스펀드', '사드'],
#   'createdAt': '2017-11-29 17:33:36'},
#  {'title': "[KRX250 미리보기②]'연기금 지수'에 로엔·메디톡스 등 편입 예상",
#   'keywords': ['코스닥', '지수', '코스닥종목', '한국거래소', '영업이익'],
#   'createdAt': '2017-11-22 17:42:46'},
#  {'title': '찬바람 불땐 배당株..배당주펀드가 투자한 종목은',
#   'keywords': ['배당주펀드', '삼성전자', '포트폴리오', '고배당주', 'sk텔레콤'],
#   'createdAt': '2017-11-21 16:24:51'},
#  {'title': '\'코스닥 불구경\'에 멈춰선 코스피.."12월 반등, 내년 2900 간다"',
#   'keywords': ['코스피', 'it', '한국투자증권', '삼성전자', '헬스케어'],
#   'createdAt': '2017-11-15 17:14:59'},
#  {'title': '[1시 주식시장은]6거래일 연속세 코스피, 숨고르기 장세 진입',
#   'keywords': ['지수', '코스닥', '다우존스산업평균지수', 'sk하이닉스', 'lg화학'],
#   'createdAt': '2017-10-18 13:15:24'},
#  {'title': '[오전시황]코스피, 다시 장 중 최고가 경신',
#   'keywords': ['코스닥', '유럽증시', '핵전쟁', '순매도', '삼성전자우'],
#   'createdAt': '2017-10-18 09:22:49'},
#  {'title': '검은 금요일',
#   'keywords': ['금리인상', '연준', 's&p', '삼성전자', '지수'],
#   'createdAt': '2017-09-23 09:10:56'},
#  {'title': '검은 금요일',
#   'keywords': ['금리인상', '연준', 's&p', '삼성전자', '지수'],
#   'createdAt': '2017-09-22 17:47:23'},
#  {'title': '[마켓뷰] 중소형주 선방에도 코스피 울상',
#   'keywords': ['잭슨홀', '삼성전자', '한미약품', '제약주', '조정'],
#   'createdAt': '2017-08-28 16:42:52'},
#  {'title': '[팩트체크]반등한다더니..한국경제 회복세 벌써 약해졌나?(종합)',
#   'keywords': ['세계경제', '한국은행', 'gdp', '리스크', '반도체'],
#   'createdAt': '2017-08-14 15:49:20'},
#  {'title': "'IT 조정·北 미사일' 잇단 돌발 악재..코스피 상승세 흔들리나",
#   'keywords': ['지수', '조정', 'it', '삼성전자', 'sk하이닉스'],
#   'createdAt': '2017-07-05 17:44:27'},
#  {'title': "반도체-디스플레이 대기업, '협력사 키우기'로 주도권 다진다",
#   'keywords': ['sk하이닉스', '디스플레이', '반도체', '삼성전자', '생태계'],
#   'createdAt': '2017-07-05 06:00:24'},
#  {'title': '[오후시황]코스피, 개인 매수 속 상승세',
#   'keywords': ['지수', '음식료품', '도시바', '전기전자', '건설업'],
#   'createdAt': '2017-06-22 13:37:32'},
#  {'title': '[오전시황]코스피, 바닥 친 국제유가에 보합권 등락',
#   'keywords': ['wti', '지수', '도시바', '코노코필립스', '우선협상대상자'],
#   'createdAt': '2017-06-22 09:44:02'},
#  {'title': '[마켓뷰] 하루만에 등돌린 외국인..미리 발 빼나',
#   'keywords': ['삼성전자', '유가증권시장', '조정', '코스피', '순매수'],
#   'createdAt': '2017-06-21 16:41:02'},
#  {'title': "코스피, 중국 msci 편입 영향으로 후퇴..코스닥지수도 '하락'",
#   'keywords': ['중국a주', '유가', 'msci', '하락세', '지수'],
#   'createdAt': '2017-06-21 09:31:58'},
#  {'title': '[마켓뷰] 코스피, 기관 매도에 등락 거듭..대장주들은 강세',
#   'keywords': ['sk하이닉스', '삼성전자', '셀트리온', '영업이익', '순매수'],
#   'createdAt': '2017-06-20 11:51:51'},
#  {'title': '[마켓뷰] 코스피, 외국인 떠나도 끄떡없어',
#   'keywords': ['msci지수', '유가증권시장', '코스피', '철강', '비차익'],
#   'createdAt': '2017-06-16 16:51:50'},
#  {'title': '[마켓뷰] 코스피 2340선 붕괴..대세 상승장 꺾이나',
#   'keywords': ['조정', '코스피', '하락세', '현대중공업', '교보증권'],
#   'createdAt': '2017-05-30 11:08:38'},
#  {'title': '[해외 투자도 붐]② 시총은 애플의 1/3, 삼성전자..주가는 더 빛났다',
#   'keywords': ['삼성전자', '수익률', 'sk하이닉스', 'lg전자', '주가상승률'],
#   'createdAt': '2017-05-25 10:01:02'},
#  {'title': '코스피, 美증시·국제유가 불안에 하락 출발',
#   'keywords': ['opec', '국제유가', '인텔', '나스닥지수', '감산합의'],
#   'createdAt': '2017-05-17 09:15:33'},
#  {'title': '기업들 쪼개고 붙이고..재계는 변신중',
#   'keywords': ['현대중공업', '지주회사', '순환출자', '파운드리', 'sk하이닉스'],
#   'createdAt': '2017-04-30 08:00:23'},
#  {'title': '[마켓뷰] 코스피지수 등락..삼성전자 독주 이어져',
#   'keywords': ['삼성전자', 'lg전자', '영업이익', '눈길', '순매도상위종목'],
#   'createdAt': '2017-04-28 11:26:41'},
#  {'title': "올해 1분기 투자 바보는 '인도' 놓친 펀드",
#   'keywords': ['수익률', 'etf', 'it', '인도', '주식형펀드'],
#   'createdAt': '2017-04-06 07:23:55'},
#  {'title': '전자업계, 전통적 비수기 1분기에 최고 실적 냈다',
#   'keywords': ['영업이익', '삼성전자', 'sk하이닉스', 'lg전자', 'g6'],
#   'createdAt': '2017-04-06 06:02:24'},
#  {'title': "대기업 신용평가, 국내선 '최고'..해외선 '바닥'",
#   'keywords': ['신용등급', '무디스', 'aaa', '공기업', 'moody'],
#   'createdAt': '2017-02-22 09:31:39'},
#  {'title': "코스피 年고점에도 죽쑨 대형펀드들 '망신살'",
#   'keywords': ['코스피', '수익률', '삼성전자', '브렉시트', '실물자산펀드'],
#   'createdAt': '2016-09-07 15:31:09'},
#  {'title': "환율·사드 후폭풍에..수출·中 소비주, 3분기 '어닝쇼크' 우려",
#   'keywords': ['환율', '영업이익', '사드', '호텔', '디스플레이'],
#   'createdAt': '2016-08-14 17:24:37'},
#  {'title': '환율 하락에 자동차 등 수출기업 초비상..항공업계는 반색',
#   'keywords': ['수출', '환율', '원달러환율', '가격경쟁력', '자동차산업'],
#   'createdAt': '2016-08-11 14:13:06'},
#  {'title': '코스피지수 브렉시트 우려에 닷새째 하락..외인·기관 순매도',
#   'keywords': ['코스피', '혼조세', '지에스인스트루', '신흥국', '한진해운'],
#   'createdAt': '2016-06-15 09:41:03'},
#  {'title': '[투자의맥]내주 증시, MSCI 수급 이벤트에 따른 관망세 지속될 듯',
#   'keywords': ['리밸런싱', 'nh투자증권', '이벤트', '브렉시트', '디아이'],
#   'createdAt': '2016-05-27 08:00:55'},
#  {'title': "중국의 전방위적 산업인력 스카웃 '위험수위'",
#   'keywords': ['중국', '반도체산업', '반도체', '조선업계', '고용'],
#   'createdAt': '2016-01-05 06:00:45'},
#  {'title': '중소형주펀드 엇갈린 수익률',
#   'keywords': ['수익률', '평균수익률', '삼성전자', '한미약품', 'sk하이닉스'],
#   'createdAt': '2015-12-01 17:55:11'},
#  {'title': '코스피지수, 美·유럽 지표 개선과 신용등급 상향 힘입어 2% 가까이 상승',
#   'keywords': ['코스피', '무역흑자', '경제지표', '신용등급', '미국'],
#   'createdAt': '2015-09-16 15:30:06'},
#  {'title': '코스피지수, 中 MSCI 진입 불발에도 나흘째 하락..외국인·기관 매도',
#   'keywords': ['코스피', '중국', '삼성물산'],
#   'createdAt': '2015-06-10 15:33:33'},
#  {'title': '코스피 지수 사흘 만에 상승..외국인 순매수 전환',
#   'keywords': ['코스피', '외국인순매수', '현대상사'],
#   'createdAt': '2015-05-28 15:55:17'},
#  {'title': '코스피지수 1.68% 하락 마감..2100선 위태',
#   'keywords': ['제일모직', '경제지표', '코스피'],
#   'createdAt': '2015-05-27 15:42:16'},
#  {'title': '삼성은 반도체, LG는 스마트폰에서 희망을 봤다',
#   'keywords': [],
#   'createdAt': '2015-01-30 06:58:05'},
#  {'title': '[issue] 작지만 강한 배당주펀드, 수익률 앞서네',
#   'keywords': [],
#   'createdAt': '2014-12-03 16:16:08'},
#  {'title': 'SK하이닉스, 두툼해진 지갑 연다..체질 개선 본격화',
#   'keywords': ['이미지센서'],
#   'createdAt': '2014-08-11 02:41:03'},
#  {'title': '[issue] 증시 강세장, 엇갈리는 그룹주 펀드',
#   'keywords': ['한국투자증권'],
#   'createdAt': '2014-08-10 10:38:06'},
#  {'title': "[IR클럽]①SK하이닉스, 공격적 투자·M&A로 '성장날개' 펼친다",
#   'keywords': ['당기순이익', '아이서플라이', '반도체 산업'],
#   'createdAt': '2014-08-05 06:31:06'},
#  {'title': 'SK하이닉스, 낸드플래시 사업 강화 이유는?',
#   'keywords': ['아이서플라이', '비메모리 반도체'],
#   'createdAt': '2014-06-05 15:28:07'},
#  {'title': '[issue] 네이버 덕분에 IT펀드 수익률은 승승장구',
#   'keywords': ['페이스북', '증권거래위원회', '나스닥', '비즈니스 모델', '기업공개', '주식형 펀드'],
#   'createdAt': '2014-05-20 15:56:11'},
#  {'title': '[마감]코스피, 1940마저 내줘..기술株 부진',
#   'keywords': ['아메리칸 인터내셔널 그룹', '페이스북', '강보합세'],
#   'createdAt': '2014-05-07 15:16:14'},
#  {'title': 'SRI펀드, 해외는 웃고 국내는 울고',
#   'keywords': ['주식형펀드', '대체에너지'],
#   'createdAt': '2014-03-17 15:00:12'},
#  {'title': '[한민엽의 5% 공략주] 인터파크INT(108790) (영상)',
#   'keywords': ['페이스북'],
#   'createdAt': '2014-03-11 13:39:06'},
#  {'title': '삼성전자·구글 특허 공유 왜?',
#   'keywords': ['크로스 라이선스', '샌디스크', '마이크로소프트'],
#   'createdAt': '2014-01-27 09:54:07'},
#  {'title': '[한민엽의 5% 공략주] 서원인텍(093920)',
#   'keywords': ['페이스북', '밸류에이션'],
#   'createdAt': '2013-12-26 10:33:06'},
#  {'title': '[한민엽의 5% 공략주] 롯데케미칼(011170)',
#   'keywords': ['부타디엔', '페이스북'],
#   'createdAt': '2013-12-19 10:30:17'},
#  {'title': 'SK하이닉스, 국내 최초 CDP 명예의 전당 입성',
#   'keywords': ['리더스 클럽'],
#   'createdAt': '2013-10-31 16:01:05'},
#  {'title': '[마감]코스피, 글로벌 경기우려 1%대 급락..1900선 턱걸이',
#   'keywords': ['강보합세',
#    '포스코',
#    '기아차',
#    '현대차',
#    '뱅크오브아메리카',
#    '한솔제지',
#    '현대모비스',
#    '한국전력',
#    '신한지주',
#    '삼성전자'],
#   'createdAt': '2013-04-18 15:49:13'},
#  {'title': "[마감]코스피, 1920선 '털썩'..경기민감업종 줄줄이 ↓",
#   'keywords': ['아이패드 미니',
#    '한국가스공사',
#    '현대중공업',
#    '현대차',
#    '뉴욕증시',
#    '기아차',
#    '포스코',
#    '한국전력',
#    '신한지주',
#    '현대모비스'],
#   'createdAt': '2012-10-23 15:24:11'},
#  {'title': '반도체 가격 하락세..삼성전자 투자의견 하향?',
#   'keywords': ['포스코', '삼성전자', '대우조선', '현대제철', '윈도8', '규모의 경제', '애널리스트'],
#   'createdAt': '2012-10-02 11:55:09'},
#  {'title': "[마감]웅크렸던 코스피, ECB 호재에 '날았다'",
#   'keywords': ['국가신용등급',
#    '스페인',
#    '현대차',
#    '삼성전자',
#    '한국 신용등급',
#    '기준금리',
#    '현대중공업',
#    '신한지주',
#    '유럽중앙은행',
#    '프로그램 매매'],
#   'createdAt': '2012-09-07 15:29:14'},
#  {'title': '피치 "日 수출 부진, 환율·韓업체 경쟁이 원인"',
#   'keywords': ['엔화 강세', '005380', '김유정', '기아차', '현대차', '삼성전자'],
#   'createdAt': '2012-08-03 14:40:07'},
#  {'title': '美 정책 기대..코스피지수 1900선 재등정',
#   'keywords': ['코스피지수',
#    '경기 부양책',
#    '오퍼레이션 트위스트',
#    '공개시장위원회',
#    '하이닉스반도체',
#    '엔씨소프트',
#    '한국투자증권',
#    '유럽연합'],
#   'createdAt': '2012-06-20 15:37:15'},
#  {'title': '[마감]코스피, 경기부양 기대감에 1900선 회복',
#   'keywords': ['현대산업', '연방공개시장위원회', '경기부양책'],
#   'createdAt': '2012-06-20 15:25:19'},
#  {'title': '[특징주] IT주 큰 폭으로 하락..매도상위목록엔 외국계 증권사',
#   'keywords': ['하이닉스반도체', '씨티그룹', '코스피지수'],
#   'createdAt': '2012-05-16 13:46:07'},
#  {'title': '증시 2000 목전..펀드 환매 늘어',
#   'keywords': ['코스피지수', '하이닉스반도체', '주식형 펀드', '현대중공업'],
#   'createdAt': '2012-01-26 16:55:09'},
#  {'title': '[2011 증시마감] 외국인 8조원 넘게 순매도, 연기금이 증시주도',
#   'keywords': ['한국거래소',
#    '035720',
#    '케이피케미칼',
#    '한국외환은행',
#    '에스에프에이',
#    'CJ오쇼핑',
#    '자기자본비율',
#    '하나금융지주',
#    '하이닉스반도체',
#    '우리금융'],
#   'createdAt': '2011-12-29 17:43:11'},
#  {'title': '"정화조 괜히 뺐어"..IT 갈아탄 운용사 \'울상\'',
#   'keywords': ['자산운용사', '하이닉스', '현대중공업'],
#   'createdAt': '2011-10-14 15:13:09'},
#  {'title': '[issue!] 기관-외국인, 환율급등에 다시 車·IT·화학에 눈독',
#   'keywords': ['005380', '금호석유', '유진투자증권', '하이닉스반도체', '현대자동차'],
#   'createdAt': '2011-09-21 17:23:18'},
#  {'title': "[마감]코스피, 하루만에 반등..'이탈리아 비켜'",
#   'keywords': ['코스피 지수', '005380', '스탠더드 앤드 푸어스', '하이닉스', '현대중공업', '뉴욕증시'],
#   'createdAt': '2011-09-20 15:16:32'},
#  {'title': '한국지멘스 "5년 후 매출, 두 배 성장할 것"',
#   'keywords': ['헬스케어', '김종갑', '하이닉스반도체'],
#   'createdAt': '2011-07-21 14:22:12'},
#  {'title': '증시, 투자자 차익실현 나섰나? 하락전환',
#   'keywords': ['코스피지수', '혼조세', '벤 버냉키', '미국 연방준비제도이사회', '하이닉스반도체'],
#   'createdAt': '2011-04-28 13:25:17'},
#  {'title': "<생생코스피>반도체株 하극상..삼성전자는 '숏' 하이닉스는 '롱'?",
#   'keywords': ['하이닉스',
#    '하극상',
#    '서부텍사스중질유(wti)',
#    '액정표시장치',
#    '스마트폰',
#    '유상 증자',
#    '국제 유가'],
#   'createdAt': '2011-04-08 10:54:22'},
#  {'title': '증시, 외국인 매수세가 건설업 루머 이겨..2056.39(0.11%)',
#   'keywords': ['코스피지수', '법정관리', '하이닉스반도체', '신한지주'],
#   'createdAt': '2011-03-28 15:16:32'},
#  {'title': '[업종돋보기] 주도주 비상 꿈꾼 전기전자株, 기대만큼 실망도 커',
#   'keywords': ['태블릿 pc',
#    '하이닉스반도체',
#    '이머징시장',
#    '가처분소득',
#    '약보합세',
#    '액정표시장치',
#    '나스닥 지수',
#    '이코노미스트',
#    '아이패드'],
#   'createdAt': '2011-03-10 16:20:28'},
#  {'title': '증시, 네마녀의 날 부담+전기전자株 연일 약세..2000선 내줘',
#   'keywords': ['네 마녀의 날',
#    '선물 만기일',
#    '오클라호마주',
#    '이트레이드증권',
#    '브렌트유',
#    '코스피200지수',
#    '무아마르 카다피'],
#   'createdAt': '2011-03-10 09:16:07'},
#  {'title': '증시, 갤럭시 재고 증가 루머에 1990선 초반으로 털썩',
#   'keywords': ['코스피지수', '하이닉스반도체', '아이패드', '현대자동차'],
#   'createdAt': '2011-03-07 11:51:36'},
#  {'title': '올 마감 준비할 때..車-화학-IT 늘리고 M&A테마 뒷정리',
#   'keywords': ['우리금융', '현대상선', '헤지펀드', '미래에셋증권', '하이닉스'],
#   'createdAt': '2010-11-17 09:48:08'},
#  {'title': '급등주의 조건은 세력과 재료를 보유해야 한다!',
#   'keywords': ['하이패스'],
#   'createdAt': '2010-11-11 11:01:59'},
#  {'title': '(VOD)마켓 Q&A..신성ENG, 실적 호조 지속될 것',
#   'keywords': ['하이닉스'],
#   'createdAt': '2010-10-01 12:42:07'},
#  {'title': '(VOD)마켓 Q&A..피에스케이, 실적 모멘텀 지속될 것',
#   'keywords': ['피에스케이', '실적 모멘텀', '하이닉스'],
#   'createdAt': '2010-05-18 10:27:12'},
#  {'title': '삼성전자·SK하이닉스 강세에 올 들어 전기·전자업종 16%↑',
#   'keywords': ['삼성전자', 'sk하이닉스', '코스피', '지수', '전기전자'],
#   'createdAt': '2019-02-10 11:11:21'},
#  {'title': '20년간 반복된 연기금의 2월 투자 패턴',
#   'keywords': ['기관투자자', '코스닥', '증시', '조정', '순매수상위'],
#   'createdAt': '2019-02-10 08:00:16'},
#  {'title': '三電·SK하이닉스 반등에 전기전자 업종 지수 상승률 1위',
#   'keywords': ['지수', 'sk하이닉스', '전기전자', '코스피', '삼성전자'],
#   'createdAt': '2019-02-10 06:03:14'},
#  {'title': "이범수 대표 맡은 '셀트리온엔터테인먼트'는 어떤 회사?",
#   'keywords': ['이범수', '엄복동', '셀트리온', 'm', '일제강점기'],
#   'createdAt': '2019-02-09 14:28:54'},
#  {'title': '[한주 증시 돌아보기]설 연휴 이후 무역분쟁 우려에 2200선 하회',
#   'keywords': ['설연휴', '무역분쟁', '코스닥', '지수', '증시'],
#   'createdAt': '2019-02-09 09:42:29'},
#  {'title': "[머니+ 김동하 머니테인먼트]대기업 중심의 '영화유통'에 수익 쏠려..성장 뒤처지는 창작진영",
#   'keywords': ['대기업', '한국', '수수료', '창의성', '미국'],
#   'createdAt': '2019-02-09 08:07:33'},
#  {'title': '코스닥 랠리에 개미들 오랜만에 싱글벙글',
#   'keywords': ['코스닥', '지수', '수익률', '파라다이스', '에스엠'],
#   'createdAt': '2019-02-08 17:42:54'},
#  {'title': "코스피, 미중 무역분쟁 우려에 2200선 '붕괴'",
#   'keywords': ['코스피', '무역분쟁', '붕괴', '지수', '시간이흐르면'],
#   'createdAt': '2019-02-08 16:33:24'},
#  {'title': "[마켓뷰] 외인 '사자' 행렬에 제동..코스피 2170대로 후퇴",
#   'keywords': ['코스피', '지수', '무역협상', '시간이흐르면', '외국인순매수'],
#   'createdAt': '2019-02-08 16:31:07'},
#  {'title': '미중 정상회담 무산에 코스피 하락..2,200선 붕괴',
#   'keywords': ['미중정상회담', '코스피하락', '붕괴', '코스피', '지수'],
#   'createdAt': '2019-02-08 16:28:40'},
#  {'title': '[마감시황]코스피, 美中 정상회담 무산 소식에 2170선 후퇴',
#   'keywords': ['코스피', '미중정상회담', '하락세', '하락', '무역협상'],
#   'createdAt': '2019-02-08 16:21:55'},
#  {'title': '코스피, 닷새만에 2200선 내줘..美中 정상회담 무산 여파',
#   'keywords': ['코스피', '코스닥', '지수', '중국', '하락세'],
#   'createdAt': '2019-02-08 16:16:36'},
#  {'title': '코스피 닷새 만에 2,200 내줘..외인 매도에 2,170대 후퇴(종합2보)',
#   'keywords': ['코스피', '서울', '지수', '삼성전자', '시간이흐르면'],
#   'createdAt': '2019-02-08 16:13:33'},
#  {'title': '[마감] 코스피, G2 무역분쟁 우려·外人 매도에 2170선 후퇴',
#   'keywords': ['코스피', '무역분쟁', 'g2', '하락', '코스닥'],
#   'createdAt': '2019-02-08 16:10:22'},
#  {'title': '미중 리스크에 돌아선 외국인..코스피, 2170선 하락',
#   'keywords': ['하락', '코스피', '리스크', '무역협상', '증시'],
#   'createdAt': '2019-02-08 16:09:00'},
#  {'title': '[코스닥 마감]5거래일 만에 하락 전환..기관 순매도',
#   'keywords': ['하락', '코스닥', '순매도', '방송서비스', '정밀기기'],
#   'createdAt': '2019-02-08 16:07:02'},
#  {'title': '코스피 닷새 만에 2,200 내줘..외인 매도에 2,170대 후퇴(종합)',
#   'keywords': ['코스피', '지수', '삼성전자', '서울', '시간이흐르면'],
#   'createdAt': '2019-02-08 15:59:40'},
#  {'title': "코스피, 외인·기관 동반 순매도에 2170선으로 '후퇴'",
#   'keywords': ['코스피', '순매도', '동반', '시가총액', '상한가'],
#   'createdAt': '2019-02-08 15:59:21'},
#  {'title': '[코스피 마감]무역협상 불확실성 부각..4거래일만에 2200선 붕괴',
#   'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락'],
#   'createdAt': '2019-02-08 15:56:06'},
#  {'title': '코스피, 미중 정상회담 불발에 2170선까지 밀려',
#   'keywords': ['코스피', '미중정상회담', '하락', '무역협상', '도널드트럼프'],
#   'createdAt': '2019-02-08 15:52:01'},
#  {'title': '[시황종합] 다시 미·중 무역분쟁..코스피, 2170선 후퇴',
#   'keywords': ['무역분쟁', '코스피', '코스닥', '하락', '환율'],
#   'createdAt': '2019-02-08 15:48:47'},
#  {'title': '[마감 시황] 코스닥 전일 대비 0.05p 하락한 728.74p에 마감',
#   'keywords': ['코스닥', '하락', 'it', 'w', '한국경제tv'],
#   'createdAt': '2019-02-08 15:36:04'},
#  {'title': '[마감 시황] 코스피 0p 보합 마감',
#   'keywords': ['코스피', '하락', '보합세', '한국경제tv', '상장'],
#   'createdAt': '2019-02-08 15:36:03'}]

# %% [markdown]
# ### Q3-2
# 위(mLab Collection)에서 종목별 각 뉴스들의 키워드(`"code"`, `"news"`)를 가져오세요.
#
# `Requirements: json, pymongo`
#
# ex)
# ```python
# python
# quotes=[
#     {'code': 'A005930',
#      'news': [{'keywords': ['게임주', '증시테마', '동반', '인공강우', '중국']},
#           {'keywords': ['5g', '4차산업혁명', '5g스마트폰', '애플', '화웨이']},
#           {'keywords': ['스마트폰', 'mwc', '폴더블폰', '갤럭시s10', '삼성전자']},
#           {'keywords': ['sk하이닉스', '상반기', '어닝쇼크', '삼성전자', 'd램']},
#           {'keywords': ['전자업계', '중국', '삼성전자', '삼성', '아시아경제']},
#           {'keywords': ['엑스레이', '후지필름', '2017년', '매출액', '유럽']},
#           {'keywords': ['삼성전자', '손', 'ssd', '삼성ssd', '게임']},
#           {'keywords': ['카풀', '택시업계', '택시', '신현상', '갈등']},
#           {'keywords': ['조선업계', '자동차', '수주', '중국', '미국']},
#           {'keywords': ['코스닥', '지수', '증시', '바이코리아', '코스피']},
#           {'keywords': ['삼성', '스마트팩토리', '경제적자유', '삼성전자', '전문가']},
#           {'keywords': ['펀드수익률', '수익률', '금리', '지수', '미국']},
#           {'keywords': ['바이코리아', '수익률', '성과', '삼성전자', 'sk하이닉스']},
#           {'keywords': ['남북경협', '주식시장', '남북경협주', '대기업', '증시']},
#           {'keywords': ['에어컨', 'ai', 'lg', '삼성', '위니아']},
#           {'keywords': ['폴더블폰', '스마트폰', '삼성', '다음', '삼성전자']},
#           {'keywords': ['sk하이닉스', '적자', '환골탈태', '빅딜', '하이닉스']},
#           {'keywords': ['중견련', '사내벤처', '연임', 'ces2019', '삼성전자']},
#           {'keywords': ['코스피', '지수', '종가', '미국', '무역협상']},
#           {'keywords': ['삼성sdi', '기업공시', '삼성전자', '인수', '삼성중공업']}]
#     },
# ...
# ]
# ```

# %%
#Q3-2
mongo_uri = "mongodb://admin:admin1234@ds021994.mlab.com:21994/mydbinstance"
client = MongoClient(mongo_uri)
db = client.mydbinstance
kospi_collection = db.financekospi

query = {
    
}

query_result = list(kospi_collection.find(query, {'_id': 0, 'code': 1, 'keywords': 1}))
query_result
# Out:
# [{'code': 'A015760', 'keywords': ['시책평가', '한전기술', '공공기관', '2018년', '국민권익위원회']},
#  {'code': 'A015760', 'keywords': ['김종갑', '일회용컵', '한전사장', '김영록', '전남지사']},
#  {'code': 'A015760', 'keywords': ['경영', '100억', '한진칼', '행사', '국민연금지분율']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락', '무역협상', '중국', '지수']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락', '지수', '마켓포인트', '미국']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A015760', 'keywords': ['코스피', '보이', '하락', '보합세', '하락세']},
#  {'code': 'A015760', 'keywords': ['중소기업', '중기중앙회', '전기요금', '요금제', '산업용전기요금']},
#  {'code': 'A015760', 'keywords': ['중소기업', '요금제', '전기요금', '조정', '한국전력']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락', '보이', '시가총액', '혼조세']},
#  {'code': 'A015760', 'keywords': ['인턴', '공기업', 'lh', '공공기관', '채용']},
#  {'code': 'A015760', 'keywords': ['코스피', '순매도', '보이', '혼조세', '화학']},
#  {'code': 'A015760', 'keywords': ['인턴', '공기업', 'lh', '인턴채용', 'mbc']},
#  {'code': 'A015760', 'keywords': ['인턴', '공공기관', '상반기', '취업포털', '잡코리아']},
#  {'code': 'A015760', 'keywords': ['한국전력', '최승욱', '국민주식고충처리반', '대한민국', '증권방송']},
#  {'code': 'A015760', 'keywords': ['코스피', '코스닥', '북미정상회담', '보이', '지수']},
#  {'code': 'A015760', 'keywords': ['코스피', '무역협상', '하락', '지수', '시가총액']},
#  {'code': 'A015760', 'keywords': ['인턴', '공기업', 'lh', '공공기관', '채용']},
#  {'code': 'A015760', 'keywords': ['인턴', 'lh', '공기업', '잡코리아', '공공기관']},
#  {'code': 'A015760', 'keywords': ['인턴', 'lh', '공기업', '공공기관', '채용']},
#  {'code': 'A015760', 'keywords': ['공기업', '인턴', 'lh', '공공기관', '인턴채용']},
#  {'code': 'A015760', 'keywords': ['인턴', '공기업', 'lh', '잡코리아', '공공기관']},
#  {'code': 'A015760', 'keywords': ['공공기관', '김용균', '정규직', '환경설비', '하청업체']},
#  {'code': 'A015760', 'keywords': ['코스피', '무역협상', '외국인순매수', '한국거래소', '증시급락']},
#  {'code': 'A015760', 'keywords': ['외주화', '발전설비', '발전공기업', '김용균', '한전산업개발']},
#  {'code': 'A015760', 'keywords': ['원전', '유틸리티', '원전정책', '2017년', '2018년']},
#  {'code': 'A015760', 'keywords': ['증시', '바이코리아', '중국', '코스피', '한국']},
#  {'code': 'A015760', 'keywords': ['공기업', '직접고용', '정규직', '협력업체', '발전공기업']},
#  {'code': 'A015760', 'keywords': ['코스피', '외국인순매수', '지수', '증시', '한국증시']},
#  {'code': 'A015760', 'keywords': ['코스피', '쇼핑', '증시', '지수', '정책']},
#  {'code': 'A015760', 'keywords': ['원전', '복귀', '웃돈', '2018년', '신고리']},
#  {'code': 'A015760', 'keywords': ['원전', '2018년', '신고리', '2017년', '한수원']},
#  {'code': 'A015760', 'keywords': ['코스피', '한국증시', '하반기', '한국거래소', '지수']},
#  {'code': 'A015760', 'keywords': ['원전', '2018년', '유틸리티', '신고리', '문재인정부']},
#  {'code': 'A015760', 'keywords': ['코스피', '쇼핑', '증시', '지수', '정책']},
#  {'code': 'A015760', 'keywords': ['취업', '채용', '한파', '블라인드채용', '상반기']},
#  {'code': 'A015760', 'keywords': ['부산', '전신주', '복구', '정전', '부산진구']},
#  {'code': 'A015760', 'keywords': ['유가', '에너지', '한국전력', '지수', '코스피']},
#  {'code': 'A051910', 'keywords': ['한국경제tv']},
#  {'code': 'A028260', 'keywords': ['삼성물산', '공정위', '순환출자', '가이드라인', '합병']},
#  {'code': 'A028260', 'keywords': ['관세', '철강', '권고안', '미국상무부', '트럼프']},
#  {'code': 'A028260', 'keywords': ['회사채', '삼성물산', '현대건설', '신용등급', '포스코건설']},
#  {'code': 'A028260', 'keywords': ['삼성전자', '순환출자', '삼성', '삼성물산', '삼성생명']},
#  {'code': 'A028260', 'keywords': ['삼성전자', '삼성그룹주펀드', '액면분할', '수익률', '주가부양의지']},
#  {'code': 'A028260', 'keywords': ['특징주', '삼성물산', '오늘증시', '가상화폐', '증권주']},
#  {'code': 'A028260', 'keywords': ['사도', '코스닥', '박스권', '파운드리', '정치적이슈']},
#  {'code': 'A028260', 'keywords': ['바이오주', '코스피', '코스닥', '지수', '경기민감주']},
#  {'code': 'A028260', 'keywords': ['바이오', '사도', '박스권', '철강', '우리산업']},
#  {'code': 'A028260', 'keywords': ['퀀텀닷', '삼성전자', '임원인사', 'lg전자', '종합기술원']},
#  {'code': 'A028260', 'keywords': ['특징주', 'spc삼립', '오늘증시', '철강', '엔씨소프트']},
#  {'code': 'A028260', 'keywords': ['폴더블', '박스권', '이지환', '스마트폰', '리얼']},
#  {'code': 'A028260', 'keywords': ['순환출자', '효성', '합병', '현대자동차', '태광그룹']},
#  {'code': 'A028260', 'keywords': ['박스권', '특징주', '매도전략', '호텔롯데', '오늘증시']},
#  {'code': 'A028260', 'keywords': ['공정위', '삼성sdi', '합병', '삼성물산', '매각']},
#  {'code': 'A028260', 'keywords': ['공정위', '삼성sdi', '삼성물산', '합병', '매각']},
#  {'code': 'A028260', 'keywords': ['배당주펀드', '삼성전자', '포트폴리오', '고배당주', 'sk텔레콤']},
#  {'code': 'A028260', 'keywords': ['박스권', '사도', '바이오', '지주사전환', '비에이치']},
#  {'code': 'A028260', 'keywords': ['etf', '특징주', '현대중공업', '오늘증시', '현대미포조선']},
#  {'code': 'A028260', 'keywords': ['특징주', '철강', '매도전략', '오늘증시', '영업이익']},
#  {'code': 'A028260', 'keywords': ['동화약품', '사도', '인쇄회로기판', '삼성에스디에스', '서울반도체']},
#  {'code': 'A028260', 'keywords': ['컨센서스', '합병', '조정', '영업익', '펀더멘탈']},
#  {'code': 'A028260', 'keywords': ['한국콜마', '특징주', '매도전략', '유상증자', '밸류에이션']},
#  {'code': 'A028260', 'keywords': ['etf', '특징주', '인간배아', '오늘증시', '홈캐스트']},
#  {'code': 'A028260', 'keywords': ['국방비', 'lig넥스원', '특징주', '북핵', '분할매수']},
#  {'code': 'A028260', 'keywords': ['특징주', '분할매수', '철강', 'lg화학', '넷마블게임즈']},
#  {'code': 'A028260', 'keywords': ['특징주', '지엔코', '제조업체', '나노스', '스프레드']},
#  {'code': 'A028260', 'keywords': ['특징주', '카카오', '사이클', '오늘증시', '철강']},
#  {'code': 'A028260', 'keywords': ['포인트', 'etf', '오늘증시', '삼성물산', '케이블방송']},
#  {'code': 'A028260', 'keywords': ['우발채무', '손실위험', '조정']},
#  {'code': 'A028260', 'keywords': ['포인트', 'etf', '심리적지지선', '오늘증시', '삼성물산']},
#  {'code': 'A028260', 'keywords': ['지수', '운수창고', '음식료품', '도시바', '건설업']},
#  {'code': 'A028260', 'keywords': ['삼성전자', '유가증권시장', '조정', '코스피', '순매수']},
#  {'code': 'A028260', 'keywords': ['국제유가', '삼성전자', '순매수', '한국증시', 'msci']},
#  {'code': 'A028260', 'keywords': ['msci', '유출', '현대자동차', '자동차', '지수']},
#  {'code': 'A028260', 'keywords': ['중국a주', '유가', 'msci', '하락세', '지수']},
#  {'code': 'A028260',
#   'keywords': ['밴플리트상', 'sk그룹', '한국고등교육재단', '밴플리트', '코리아소사이어티']},
#  {'code': 'A028260', 'keywords': ['조정', '코스피', '하락세', '현대중공업', '교보증권']},
#  {'code': 'A028260', 'keywords': ['사도', '현대위아', '한미사이언스', 'posco', '전문가']},
#  {'code': 'A028260', 'keywords': ['사도', '케이엠더블유', '035720', '투자포인트', '텔레칩스']},
#  {'code': 'A028260', 'keywords': ['김용덕', '현대제철', 'etf', '이화공영', '동양철관']},
#  {'code': 'A028260', 'keywords': ['순환출자', '삼성물산', '삼성', '삼성전자', '삼성그룹']},
#  {'code': 'A028260', 'keywords': ['영업이익', '어닝서프라이즈', '철강업계', '삼성전자', '디스플레이']},
#  {'code': 'A028260', 'keywords': ['5g', 'sk텔레콤', 'lg유플러스', 'g20', '4차산업혁명']},
#  {'code': 'A028260', 'keywords': ['신용등급', '무디스', 'aaa', '공기업', 'moody']},
#  {'code': 'A028260', 'keywords': ['지주회사', '합병', '지배주주', 'sk', '제일모직']},
#  {'code': 'A028260', 'keywords': ['삼성전자', '삼성그룹주펀드', '수익률', '영업이익', 'etf']},
#  {'code': 'A028260', 'keywords': ['삼성그룹주펀드', '삼성전자', '수익률', '펀드매니저', '삼성그룹']},
#  {'code': 'A028260', 'keywords': ['포스코', '권오준', '구조조정', '광양제철소', 'sentiment']},
#  {'code': 'A028260', 'keywords': ['삼성그룹', '삼성전자', '인적분할', '지주회사', '현대글로비스']},
#  {'code': 'A028260', 'keywords': ['회사채', '신용등급', '채권금리', '한국신용평가', '한신평']},
#  {'code': 'A028260', 'keywords': ['회사채', '수요예측', '유효수요', '신용스프레드', '현대산업']},
#  {'code': 'A028260', 'keywords': ['회사채', '신용스프레드', '수요예측', '신용등급', '유효수요']},
#  {'code': 'A028260', 'keywords': ['포스코', '에너지원단위', '온실가스', '글로벌기업', 'dupont']},
#  {'code': 'A028260', 'keywords': ['수익률', '삼성전자', '주식형펀드', '엘리엇', '지주회사']},
#  {'code': 'A028260', 'keywords': ['공급과잉', '석유화학', '포스코', '산업부', '사회주의국가']},
#  {'code': 'A028260', 'keywords': ['회사채', '대림산업', '수요예측', '건설업', '신용등급']},
#  {'code': 'A028260', 'keywords': ['기업지배구조', '남양유업', '한국금융지주', '신일산업', '대림그룹']},
#  {'code': 'A028260', 'keywords': ['삼성물산', '삼성그룹', '삼성전자', '삼성sds', '삼성생명']},
#  {'code': 'A028260', 'keywords': ['베트남', '호치민', '동화기업', '인프라공사', '중소기업중앙회']},
#  {'code': 'A028260', 'keywords': ['vietnam', '공사수주', '삼성물산', '유지하']},
#  {'code': 'A028260',
#   'keywords': ['삼성전자', '삼성그룹주펀드', '수익률', '글로벌금융위기', '삼성물산']},
#  {'code': 'A028260', 'keywords': ['삼성전자', '인적분할', '현물출자', '삼성sdi', '레버리지']},
#  {'code': 'A028260', 'keywords': ['전환사채', '임시주주총회', '미국상무부', '조정', '미국']},
#  {'code': 'A028260', 'keywords': ['코스피', '혼조세', '지에스인스트루', '신흥국', '한진해운']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락', '개인매수', '개', '순매수상위']},
#  {'code': 'A015760', 'keywords': ['정규직전환', '노동자', '갈등', '9일', '직접고용']},
#  {'code': 'A015760', 'keywords': ['코스피', '주식시장', '삼성전자', 'sk하이닉스', '미중무역전쟁']},
#  {'code': 'A015760', 'keywords': ['규제샌드박스', '전기차', '수소차', '규제', '문대통령']},
#  {'code': 'A015760', 'keywords': ['코스피', '무역분쟁', '붕괴', '지수', '시간이흐르면']},
#  {'code': 'A015760', 'keywords': ['코스피', '지수', '무역협상', '시간이흐르면', '외국인순매수']},
#  {'code': 'A015760', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '코스피', '지수']},
#  {'code': 'A015760', 'keywords': ['코스피', '미중정상회담', '하락세', '하락', '무역협상']},
#  {'code': 'A015760', 'keywords': ['코스피', '코스닥', '지수', '중국', '하락세']},
#  {'code': 'A015760', 'keywords': ['코스피', '서울', '지수', '삼성전자', '시간이흐르면']},
#  {'code': 'A015760', 'keywords': ['코스피', '무역분쟁', 'g2', '하락', '코스닥']},
#  {'code': 'A015760', 'keywords': ['하락', '코스피', '리스크', '무역협상', '증시']},
#  {'code': 'A015760', 'keywords': ['코스피', '지수', '삼성전자', '서울', '시간이흐르면']},
#  {'code': 'A015760', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A015760', 'keywords': ['무역분쟁', '코스피', '코스닥', '하락', '환율']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락', '보합세', '한국경제tv', '상장']},
#  {'code': 'A015760', 'keywords': ['개미', '개', '삼성전자', 'sk하이닉스', '행진']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A015760', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '순매도']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A015760', 'keywords': ['공기업', '위기', '정책', '한전산업개발', '7년']},
#  {'code': 'A015760', 'keywords': ['7년', '시책평가', '청렴도평가', '공공기관', '김형욱']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A015760', 'keywords': ['코스피', '순매도', '하락', '동반', '불확실성']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A015760', 'keywords': ['하락', '코스피', '무역협상', '불확실성', '한파']},
#  {'code': 'A015760', 'keywords': ['코스피', '15분', '순매도', '하락', '보이']},
#  {'code': 'A015760', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A015760', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '무역협상']},
#  {'code': 'A015760', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '무역협상', '증시']},
#  {'code': 'A015760', 'keywords': ['코스피', '무역협상', '불확실성', '하락', '순매도']},
#  {'code': 'A015760', 'keywords': ['코스피', '개장', '하락', '보이', '하락세']},
#  {'code': 'A015760', 'keywords': ['5g', '엔텔스', '하이', '매출', '사물인터넷']},
#  {'code': 'A015760', 'keywords': ['인턴', '공공기관', '잡코리아', '하반기', '집계결과']},
#  {'code': 'A015760', 'keywords': ['동서발전', '설연휴기간', '김형욱', '세종', '발전설비']},
#  {'code': 'A015760', 'keywords': ['개미핥기', '손절매', '삼성전자', 'sk하이닉스', '개미']},
#  {'code': 'A015760', 'keywords': ['인턴', '세금', '채용', 'lh', '꼼수']},
#  {'code': 'A015760', 'keywords': ['탈원전', '경쟁률', '졸업', '취업', '탈원전정책']},
#  {'code': 'A015760', 'keywords': ['코스닥', '코스피', 'it', '지수', '미국']},
#  {'code': 'A015760', 'keywords': ['삼성전자', '개미핥기', 'sk하이닉스', '개미', '국내증시']},
#  {'code': 'A015760', 'keywords': ['코스피', '턱걸이', '지수', '약보합세', '시가총액상위종목']},
#  {'code': 'A015760', 'keywords': ['코스피', '지수', '트럼프대통령', '무역협상', '코스닥']},
#  {'code': 'A015760', 'keywords': ['코스피', '지수', '국내증시', '시가총액', '혼조세']},
#  {'code': 'A015760', 'keywords': ['제넥신', '코스피', '코스닥', '하락', '모건스탠리']},
#  {'code': 'A015760', 'keywords': ['코스피', '코스닥', '무역협상', '북미정상회담', '보이']},
#  {'code': 'A015760', 'keywords': ['김동민', '취임사', '직장', '한국전력공사', 'image']},
#  {'code': 'A015760', 'keywords': ['중소기업', '전기요금', '요금제', '중기중앙회', '대기업']},
#  {'code': 'A015760', 'keywords': ['전기요금', '중소기업', '중기중앙회', '요금제', '국회']},
#  {'code': 'A015760', 'keywords': ['요금제', '중소기업', '전기요금', '조정', '중기중앙회']},
#  {'code': 'A015760', 'keywords': ['인턴', '공기업', '상반기', '채용', '잡코리아']},
#  {'code': 'A015760', 'keywords': ['코스피', '증시', '지수', '북미정상회담', '미국증시']},
#  {'code': 'A015760', 'keywords': ['중소기업', '대기업', '요금제', '전기요금', '중기중앙회']},
#  {'code': 'A015760', 'keywords': ['중소기업', '중기중앙회', '전기요금', '요금제', '한국전력']},
#  {'code': 'A015760', 'keywords': ['삼성전자', 'sk하이닉스', '국내증시', '개', '개미']},
#  {'code': 'A015760', 'keywords': ['전기요금', '요금제', '중소기업', '전력', '중기중앙회']},
#  {'code': 'A015760', 'keywords': ['중소기업', '중기중앙회', '요금제', '전기요금', '로드맵']},
#  {'code': 'A015760', 'keywords': ['전기요금', '요금제', '중기중앙회', '중소기업', '대기업']},
#  {'code': 'A015760', 'keywords': ['중소기업', '전기요금', '요금제', '중기중앙회', '조정']},
#  {'code': 'A015760', 'keywords': ['요금제', '중기중앙회', '중소기업', '전기요금', '로드맵']},
#  {'code': 'A015760', 'keywords': ['중소기업', '요금제', '전기요금', '중기중앙회', '국회']},
#  {'code': 'A015760', 'keywords': ['요금제', '전기요금', '중소기업', '중기중앙회', '조정']},
#  {'code': 'A068270', 'keywords': ['셀트리온헬스케어', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['셀트리온', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['하태민', '코스닥', '쇼핑', '미래', '순매도']},
#  {'code': 'A068270', 'keywords': ['코스닥', '반전', '하락', '보이', '보합세']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['바이오주', 'cctv관련주', '로봇', 'et', '하락세']},
#  {'code': 'A068270', 'keywords': ['포스코켐텍', '곽영훈', '정부정책', '전기차', '트렌드']},
#  {'code': 'A068270', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '순매도']},
#  {'code': 'A068270', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A068270', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '순매도', '하락', '동반', '불확실성']},
#  {'code': 'A068270', 'keywords': ['하락', '코스피', '붕괴', '순매도', '유가증권시장']},
#  {'code': 'A068270', 'keywords': ['코스닥', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['하락', '코스피', '무역협상', '불확실성', '한파']},
#  {'code': 'A068270', 'keywords': ['코스피', '15분', '순매도', '하락', '보이']},
#  {'code': 'A068270', 'keywords': ['코스피하락', '지수', '코스피', '서울', '하락']},
#  {'code': 'A068270', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A068270', 'keywords': ['셀트리온헬스케어', '알파고', '한국경제tv', '2019년', '미국']},
#  {'code': 'A068270', 'keywords': ['코스피', '코스닥', '하락', '경영권', '지수']},
#  {'code': 'A068270', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '무역협상']},
#  {'code': 'A068270', 'keywords': ['셀트리온', '500원', '순매도', '유한양행', '한미약품']},
#  {'code': 'A068270', 'keywords': ['셀트리온', '알파고', '한국경제tv', '램시마', '2019년']},
#  {'code': 'A068270', 'keywords': ['한미약품', '500원', '수익률', '셀트리온', '삼성바이오로직스']},
#  {'code': 'A068270', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '무역협상', '증시']},
#  {'code': 'A068270', 'keywords': ['코스피하락', '지수', '코스피', '서울', '하락']},
#  {'code': 'A068270', 'keywords': ['코스피', '무역협상', '불확실성', '하락', '순매도']},
#  {'code': 'A068270', 'keywords': ['하락', '코스닥', '순매도', '경남제약', '보이']},
#  {'code': 'A068270', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A068270', 'keywords': ['코스닥', '개장', '하락', '보이', '보합세']},
#  {'code': 'A068270', 'keywords': ['코스피', '개장', '하락', '보이', '하락세']},
#  {'code': 'A068270', 'keywords': ['셀트리온헬스케어', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['500원', '셀트리온', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['매출액', '영업이익', '매출', '영업손실', '조회공시']},
#  {'code': 'A068270',
#   'keywords': ['코스닥', '순매수상위', '포스코켐텍', '바이로메드', '셀트리온헬스케어']},
#  {'code': 'A068270',
#   'keywords': ['포스코켐텍', '와이지엔터테인먼트', '코스닥', '기관투자자', '순매수상위']},
#  {'code': 'A068270', 'keywords': ['리베이트', '셀트리온', '미국', '삼성', '바이오시밀러']},
#  {'code': 'A068270', 'keywords': ['코스닥', 'it', '지갑', '바이오', '지수']},
#  {'code': 'A068270', 'keywords': ['코스피', '코스닥', '북미정상회담', '달러환율', '서울']},
#  {'code': 'A068270', 'keywords': ['코스닥', '코스피', '시가총액', '한국경제tv', '종가']},
#  {'code': 'A068270', 'keywords': ['코스닥', '코스피', '지수', '서울', '종가']},
#  {'code': 'A068270', 'keywords': ['셀트리온', '자기주식', '11월', '서진욱', '저작권']},
#  {'code': 'A068270', 'keywords': ['코스피', '코스닥', '지수', '하락', '무역협상']},
#  {'code': 'A068270', 'keywords': ['코스피', '지수', '국내증시', '시가총액', '혼조세']},
#  {'code': 'A068270',
#   'keywords': ['코스닥', '셀트리온헬스케어', 'cjenm', '바이로메드', '포스코켐텍']},
#  {'code': 'A068270', 'keywords': ['제넥신', '코스피', '코스닥', '하락', '모건스탠리']},
#  {'code': 'A068270', 'keywords': ['코스피', '코스닥', '바이오주', '설연휴', '개장']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보합세', 'it', 'w', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['셀트리온헬스케어', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['500원', '셀트리온', '한국경제tv', '33']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보이', 'it', 'w', '33']},
#  {'code': 'A068270', 'keywords': ['코스피', '보이', '하락', '보합세', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['공매도', '셀트리온헬스케어', '대장주', '코스닥', '매출액']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보이', 'it', 'w', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '보이', '하락', '보합세', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['신약개발', '바이오리더스', '유산균', '앵커', '미국']},
#  {'code': 'A068270', 'keywords': ['미국', 'top', '셀트리온', 'nh투자증권', '램시마']},
#  {'code': 'A068270', 'keywords': ['nh투자증권', 'top', '미국', '제시한', '컨센서스']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보이', '33', 'it', 'w']},
#  {'code': 'A068270', 'keywords': ['코스피', '보이', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스닥', 'it', 'w', '한국경제tv', '하락']},
#  {'code': 'A068270', 'keywords': ['코스피', '보이', '하락세', '한국경제tv', '하락']},
#  {'code': 'A068270', 'keywords': ['콘텐츠', '게임', '코스닥', 'cjenm', '펄어비스']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보이', 'it', 'w', '33']},
#  {'code': 'A068270', 'keywords': ['코스피', '보이', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '개인매수', '코스닥', '보이', '하락']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보이', 'it', 'w', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '혼조세', '지수', '국내증시', '시가총액']},
#  {'code': 'A068270', 'keywords': ['바이오리더스', '신약개발', '유산균', '앵커', '미국']},
#  {'code': 'A068270', 'keywords': ['셀트리온제약', '메디톡스', '코미팜']},
#  {'code': 'A068270', 'keywords': ['코스닥', '보이', 'it', 'w', '한국경제tv']},
#  {'code': 'A005380', 'keywords': ['soc', 'j노믹스', '경제정책', '토목사업', '부산']},
#  {'code': 'A005380', 'keywords': ['공매도', '셀트리온', '증시', '삼성전기', '하락']},
#  {'code': 'A005380', 'keywords': ['셀트리온', '신차효과', '팰리세이드', '신형쏘나타', '시가총액']},
#  {'code': 'A005380',
#   'keywords': ['한기평', '현대자동차', '현대다이모스', '005380', '한국기업평가']},
#  {'code': 'A005380', 'keywords': ['ces', '삼성전자', 'it', '자율주행', '현대자동차']},
#  {'code': 'A005380', 'keywords': ['sk하이닉스', 'lng선', '반도체', '수주', '성장률']},
#  {'code': 'A005380', 'keywords': ['현대파워텍', '자동변속기', '최중기', '기업평가', '현대다이모스']},
#  {'code': 'A005380', 'keywords': ['알루미늄', '포스코', '한국철도공사', '유진테크', '특허취득']},
#  {'code': 'A005380', 'keywords': ['최저임금', '갈등', '리스크', '반도체', '일자리']},
#  {'code': 'A005380', 'keywords': ['ces', '글로벌기업', '5g', '전시회', '미래']},
#  {'code': 'A005380', 'keywords': ['수주', '공사수주', '고속도로', '동부건설', '새만금']},
#  {'code': 'A005380', 'keywords': ['최저임금', '주휴수당', '일자리안정자금', '근로자', '연착륙']},
#  {'code': 'A005380', 'keywords': ['탄력근로제', '성장률', '최저임금', 'soc', '결정구조']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '광주형일자리', '폭스바겐', '지역갈등', '갈등']},
#  {'code': 'A005380', 'keywords': ['기아자동차', '코나', '현대자동차', '제네시스g70', '북미']},
#  {'code': 'A005380', 'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '기아자동차', '신용등급', '영업이익률', '전기차']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '기아자동차', '신용등급', '현대모비스', '무디스']},
#  {'code': 'A005380', 'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미']},
#  {'code': 'A005380', 'keywords': ['롯데쇼핑', '호텔롯데', '기아자동차', '신용등급', '한기평']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '기아자동차', '신용등급', '한국신용평가', '약세기조']},
#  {'code': 'A005380',
#   'keywords': ['바이오', '삼성바이오로직스', 'nh투자증권', '바이로메드', '임상결과']},
#  {'code': 'A005380', 'keywords': ['신용등급', '기아자동차', '현대카드', '현대자동차', '현대캐피탈']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '영업이익', '신용등급', '배당수익률', '무디스']},
#  {'code': 'A005380', 'keywords': ['어닝쇼크', '영업이익', '상장사', '컨센서스', '반도체']},
#  {'code': 'A005380', 'keywords': ['신용등급', '현대자동차', '조정', '005380', '하락세']},
#  {'code': 'A005380', 'keywords': ['기아자동차', '현대자동차', '사이크', '무디스', '005380']},
#  {'code': 'A005380', 'keywords': ['신용등급', '현대자동차', '기아자동차', '삼성증권', '무디스']},
#  {'code': 'A005380', 'keywords': ['신용등급', '현대자동차', '기아자동차', '벤더', 's&p']},
#  {'code': 'A005380', 'keywords': ['컨퍼런스콜', '대북제재', '재무부', '한국정부', '최근북한']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '신용등급', '기아자동차', '조정', '현대모비스']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '신용등급', '기아자동차', '조정', '현대모비스']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '기아자동차', '현대모비스', 's&p', '신용등급']},
#  {'code': 'A005380', 'keywords': ['신용등급', 's&p', '현대자동차', '기아자동차', '적자']},
#  {'code': 'A005380',
#   'keywords': ['현대다이모스', '현대파워텍', '자동변속기', '005380', '변속기']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '생산성', '부품', '품질경영', '임금협상']},
#  {'code': 'A005380', 'keywords': ['파리모터쇼', '모델', '현대자동차', '벤츠', '전기차']},
#  {'code': 'A005380', 'keywords': ['msci', '중국a주', '지수', '의약품', '코스닥']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '설계', '소형차', '아반떼', '남양연구소']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '메르스', '대한항공', '한샘', 'sk이노베이션']},
#  {'code': 'A005380', 'keywords': ['파월', '폼페이오', '순매도', 'sk하이닉스', '지수']},
#  {'code': 'A005380', 'keywords': ['nh투자증권', '제시한', '매출액', '영업이익', '트룩시마']},
#  {'code': 'A005380', 'keywords': ['매출액', '영업이익', '셀트리온', '기업광고', '영업이익률']},
#  {'code': 'A005380', 'keywords': ['삼바', '바이오', '삼성전자', '삼성바이오로직스', '신수종']},
#  {'code': 'A005380', 'keywords': ['바이오주', '내수', '코스닥', 'stx엔진', '마켓포인트']},
#  {'code': 'A005380', 'keywords': ['북미정상회담', '지수', '코스피', '국채금리', '유가']},
#  {'code': 'A005380', 'keywords': ['이데일리신문']},
#  {'code': 'A005380', 'keywords': ['바이오', '코스피', '신흥국', '셀트리온', '중국a주']},
#  {'code': 'A005380', 'keywords': ['현대자동차', '롯데그룹', '신용등급', '조정', '롯데쇼핑']},
#  {'code': 'A005380', 'keywords': ['엘리엇', '현대모비스', '합병', '모비스', '지주회사']},
#  {'code': 'A005380', 'keywords': ['모비스', '현대모비스', '현대자동차', '제네시스', '자사주소각']},
#  {'code': 'A005380', 'keywords': ['엘리엇', '합병', '현대모비스', '삼성물산', '현대차그룹']},
#  {'code': 'A005380', 'keywords': ['택시', '쏘나타', '쏘나타뉴라이즈', '자동변속기', '변속기']},
#  {'code': 'A005380', 'keywords': ['바이오주', '수익률', '보건의료', '밸류에이션', '휠라코리아']},
#  {'code': 'A005380', 'keywords': ['삼성전자', '삼성바이오로직스', '액면분할', '순매도', '분식회계']},
#  {'code': 'A005380', 'keywords': ['부품', '컴퓨터사업', '4차산업혁명', '애프터서비스', '컴퓨터사양']},
#  {'code': 'A005380', 'keywords': ['공매도', '소액주주', '셀트리온', '삼성증권', '주총']},
#  {'code': 'A005380', 'keywords': ['영업이익', '현대자동차', '싼타페', '005380', '넥쏘']},
#  {'code': 'A005380', 'keywords': ['내수', '싼타페', '신차효과', '기저효과', '신흥국']},
#  {'code': 'A005380', 'keywords': ['행동주의', '엘리엇', '주주환원정책', '컴투스', 'kb자산운용']},
#  {'code': 'A005380',
#   'keywords': ['현대자동차', '술자리', '005380', '현대오토에버', '현대차그룹']},
#  {'code': 'A005380',
#   'keywords': ['현대글로비스', '현대모비스', '조정', '에프앤가이드', '스탠더드앤드푸어스']},
#  {'code': 'A005380',
#   'keywords': ['현대모비스', 'ebitda', 's&p', '신용등급', '현대자동차그룹']},
#  {'code': 'A005380', 'keywords': ['사도', '액면분할', '현대글로비스', '박스권', '밸류에이션']},
#  {'code': 'A005380', 'keywords': ['기아자동차', '현대자동차', '신차', '싼타페', '한국gm']},
#  {'code': 'A005380', 'keywords': ['수익률', '인덱스펀드', '코스닥', '주식형펀드', '셀트리온']},
#  {'code': 'A005380', 'keywords': ['사도', '코스피200지수', '기술적반등', '종자', '영업익']},
#  {'code': 'A005380', 'keywords': ['특징주', '삼성전자', '오늘증시', '셀트리온', '코스피200지수']},
#  {'code': 'A005380', 'keywords': ['사도', '박스권', '영업이익', '셀트리온', '120']},
#  {'code': 'A005380',
#   'keywords': ['한국항공우주', 'ebitda', '스프레드', '영업이익률', 'nh투자증권']},
#  {'code': 'A005380', 'keywords': ['특징주', '아모레퍼시픽', '오늘증시', '현대자동차', '예림당']},
#  {'code': 'A005380', 'keywords': ['바이오', '파이프라인', '부광약품', '제넥신', '오픈이노베이션']},
#  {'code': 'A005380', 'keywords': ['특징주', '에스피지', '오늘증시', '삼성전자', '셀트리온']},
#  {'code': 'A005380', 'keywords': ['특징주', '두산밥캣', '오늘증시', '셀트리온', '엔씨소프트']},
#  {'code': 'A005380', 'keywords': ['삼성전자', '순환출자', '삼성', '삼성물산', '삼성생명']},
#  {'code': 'A005380', 'keywords': ['상장법인', '셀트리온', '코스닥', '유가증권시장본부', '오알켐']},
#  {'code': 'A005380', 'keywords': ['특징주', '현대자동차', '오늘증시', '005380', '삼성전자']},
#  {'code': 'A005380', 'keywords': ['사내하청', '조선업', '일자리', '정규직', '정비업무']},
#  {'code': 'A005380', 'keywords': ['사도', '코스닥', '박스권', '파운드리', '정치적이슈']},
#  {'code': 'A005380', 'keywords': ['바이오주', '코스피', '코스닥', '지수', '경기민감주']},
#  {'code': 'A005380', 'keywords': ['임단협', '광군절', '영업이익률', '영업이익', '분석']},
#  {'code': 'A005380', 'keywords': ['순매도', '코스피200', '중국a주', '선물계약', 'msci']},
#  {'code': 'A005380', 'keywords': ['코스닥', '셀트리온', '지수', 'etf', '폭락']},
#  {'code': 'A005380', 'keywords': ['셀트리온', '임상시험', '문자폭탄', '노무라증권', '유가증권시장']},
#  {'code': 'A005380', 'keywords': ['jp모건', '헬스케어', 'sk바이오팜', '콘퍼런스', 'lg화학']},
#  {'code': 'A005380', 'keywords': ['jp모건', 'lg화학', '셀트리온', '헬스케어', '아스트라제네카']},
#  {'code': 'A005380', 'keywords': ['ces', '삼성전자', '인공지능', '5g', '4차산업혁명']},
#  {'code': 'A005380', 'keywords': ['ces', 'ai', '삼성전자', '로봇', '현대자동차']},
#  {'code': 'A005380', 'keywords': ['특징주', '오늘증시', '035420', '셀트리온', 'lg전자']},
#  {'code': 'A005380',
#   'keywords': ['다보스포럼', '신동빈', 'fractured', 'sk그룹', '세계경제포럼']},
#  {'code': 'A005380', 'keywords': ['특징주', '효성', '분식회계', '인적분할', '오늘증시']},
#  {'code': 'A005380', 'keywords': ['순환출자', '효성', '합병', '현대자동차', '태광그룹']},
#  {'code': 'A005380', 'keywords': ['공정위', '삼성sdi', '합병', '삼성물산', '매각']},
#  {'code': 'A005380', 'keywords': ['사도', '박스권', '현대미포조선', '도시재생사업', '문재인정부']},
#  {'code': 'A005380', 'keywords': ['순환출자', '대기업집단', '공정위', 'sm그룹', '건설업']},
#  {'code': 'A005380', 'keywords': ['기아자동차', '현대자동차', '통상임금', '신용등급', '사드']},
#  {'code': 'A005380', 'keywords': ['신용등급', '현대자동차', 'kai', '사드', '롯데그룹']},
#  {'code': 'A005380', 'keywords': ['헬스케어', '일동제약', '바이오시밀러', '바이오', '유나이티드제약']},
#  {'code': 'A005380', 'keywords': ['코스닥', '지수', '코스닥종목', '한국거래소', '영업이익']},
#  {'code': 'A005380', 'keywords': ['기술적반등', '사도', '인증보안', '드림시큐리티', '005380']},
#  {'code': 'A051910', 'keywords': ['sk이노베이션', '채용', '권재희', '월', '이직']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락', '개인매수', '개', '순매수상위']},
#  {'code': 'A051910', 'keywords': ['점유율', '삼성sdi', '중국', '포인트', '전기차']},
#  {'code': 'A051910', 'keywords': ['코스피', '주식시장', '삼성전자', 'sk하이닉스', '미중무역전쟁']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '미국', '일본', '중국']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '일본', '서울', '송상현']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '800만달러', '미국', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['상장사', '주총', '의결권행사', '삼성전자', '대상']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '업', '달러', '독일', '바스프']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '박상익', '미국', '영국', '2019년']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '브랜드가치순위', '매출', '반영']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '성장률', '일본', '중국']},
#  {'code': 'A051910', 'keywords': ['광화문', '종로구', '여의도', '서울여의도', '물류자회사']},
#  {'code': 'A051910', 'keywords': ['직장인', '삼성전자', '배그', 'pc', '모바일']},
#  {'code': 'A051910', 'keywords': ['코스피', '무역분쟁', '붕괴', '지수', '시간이흐르면']},
#  {'code': 'A051910', 'keywords': ['코스피', '지수', '무역협상', '시간이흐르면', '외국인순매수']},
#  {'code': 'A051910', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '코스피', '지수']},
#  {'code': 'A051910', 'keywords': ['코스피', '미중정상회담', '하락세', '하락', '무역협상']},
#  {'code': 'A051910', 'keywords': ['코스피', '코스닥', '지수', '중국', '하락세']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '세계4위', '미국', '일본', '중국']},
#  {'code': 'A051910', 'keywords': ['코스피', '서울', '지수', '삼성전자', '시간이흐르면']},
#  {'code': 'A051910', 'keywords': ['코스피', '무역분쟁', 'g2', '하락', '코스닥']},
#  {'code': 'A051910', 'keywords': ['하락', '코스피', '리스크', '무역협상', '증시']},
#  {'code': 'A051910', 'keywords': ['광주형일자리', '상반기', '서울', '아파트값', '하락']},
#  {'code': 'A051910', 'keywords': ['코스피', '지수', '삼성전자', '서울', '시간이흐르면']},
#  {'code': 'A051910', 'keywords': ['코스피', '순매도', '동반', '시가총액', '상한가']},
#  {'code': 'A051910', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A051910', 'keywords': ['무역분쟁', '코스피', '코스닥', '하락', '환율']},
#  {'code': 'A051910', 'keywords': ['달러', '영업익', '주주제안', '자산운용사', '삼성전자']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락', '보합세', '한국경제tv', '상장']},
#  {'code': 'A051910', 'keywords': ['개미', '개', '삼성전자', 'sk하이닉스', '행진']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '전기차배터리', '미국', '중국', '바스프']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['영업이익', '300', '전기차', '불황', '흑자']},
#  {'code': 'A051910', 'keywords': ['sk이노베이션', '인재쟁탈전', 'lg', 'sk', '채용']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '순매도']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '바스프', '일본', '중국']},
#  {'code': 'A051910', 'keywords': ['삼성sdi', '전기차배터리', 'catl', '한국', 'sk이노베이션']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '성장률', '바스프', '일본']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '미국', '800만달러', '300']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '미국', '매출', '중국']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['성장률', '삼성sdi', '중국', '파나소닉', 'top']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '화학', '바스프', '일본']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '미국', '바스프', '일본', '중국']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '미국', '2019년', '권재희']},
#  {'code': 'A051910', 'keywords': ['코스피', '15분', '순매도', '하락', '보이']},
#  {'code': 'A051910', 'keywords': ['코스피하락', '지수', '코스피', '서울', '하락']},
#  {'code': 'A051910', 'keywords': ['문대통령', '대기업', '달러', '배당', '주주제안']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A051910', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '무역협상']},
#  {'code': 'A051910', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '무역협상', '증시']},
#  {'code': 'A051910', 'keywords': ['코스피하락', '지수', '코스피', '서울', '하락']},
#  {'code': 'A051910', 'keywords': ['코스피', '무역협상', '불확실성', '하락', '순매도']},
#  {'code': 'A051910', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A051910', 'keywords': ['500원', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['삼성바이오로직스', '삼성전기', '순매도', '현대건설', '순매도상위']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '미국', '2019년', '일본']},
#  {'code': 'A051910', 'keywords': ['브랜드가치', '달러', '미국', '브랜드가치순위', '바스프']},
#  {'code': 'A051910', 'keywords': ['신남방정책', '인도네시아', '북미정상회담', '시가총액', '건설']},
#  {'code': 'A051910', 'keywords': ['코스피', '코스닥', '북미정상회담', '달러환율', '서울']},
#  {'code': 'A051910', 'keywords': ['코스닥', '코스피', '시가총액', '한국경제tv', '종가']},
#  {'code': 'A051910', 'keywords': ['코스닥', '코스피', '지수', '서울', '종가']},
#  {'code': 'A051910', 'keywords': ['코스피', '코스닥', '지수', '하락', '무역협상']},
#  {'code': 'A051910', 'keywords': ['코스피', '지수', '트럼프대통령', '무역협상', '코스닥']},
#  {'code': 'A051910', 'keywords': ['코스피', '지수', '국내증시', '시가총액', '혼조세']},
#  {'code': 'A051910', 'keywords': ['코스피', '코스닥', '바이오주', '설연휴', '개장']},
#  {'code': 'A051910', 'keywords': ['코스피', '코스닥', '무역협상', '북미정상회담', '보이']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['코스피', '보이', '하락', '보합세', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['코스피', '보이', '하락', '보합세', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['코스피', '증시', '지수', '북미정상회담', '미국증시']},
#  {'code': 'A051910', 'keywords': ['코스피', '보이', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['코스피', '보이', '하락세', '한국경제tv', '하락']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락', '보이', '시가총액', '혼조세']},
#  {'code': 'A051910', 'keywords': ['증시', '가뭄', '한국', '주식시장', '순유출']},
#  {'code': 'A051910', 'keywords': ['코스피', '보이', '보합세', '하락세', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['컨센서스', 'maintain', '조정', '제시한', '매출액']},
#  {'code': 'A051910', 'keywords': ['코스피', '하락', '반전', '보이', '한국경제tv']},
#  {'code': 'A051910', 'keywords': ['코스피', '무역협상', '지수', '시가총액', '협상']},
#  {'code': 'A051910', 'keywords': ['코스피', '순매도', '보이', '혼조세', '화학']},
#  {'code': 'A051910', 'keywords': ['증시', '보이는', '보이', '지수', '북미정상회담']},
#  {'code': 'A051910', 'keywords': ['유한양행', '보스턴', '진', '바이오', 'd']},
#  {'code': 'A051910', 'keywords': ['코스피', '보이', '지수', '하락', '무역협상']},
#  {'code': 'A051910', 'keywords': ['코스피', '지수', '시가총액', '서울', '스탠더드앤드푸어스']},
#  {'code': 'A051910', 'keywords': ['증시', '설연휴', '코스피', '국내증시', '국정연설']},
#  {'code': 'A051910', 'keywords': ['코스피', '코스닥', '북미정상회담', '보이', '지수']},
#  {'code': 'A051910', 'keywords': ['국민주식고충처리반', '대한민국', '증권방송', '스마트폰앱']},
#  {'code': 'A051910', 'keywords': ['코스피', '미국', 'sk하이닉스', '셀트리온', '삼성바이오로직스']},
#  {'code': 'A051910', 'keywords': ['코스피', '개장', '하락', '보이', '시가총액']},
#  {'code': 'A051910', 'keywords': ['매출', '매출액', '영업이익', '양', '컨센서스']},
#  {'code': 'A051910', 'keywords': ['매출액', '영업이익', '컨센서스', '다시한번', '어닝서프라이즈']},
#  {'code': 'A051910', 'keywords': ['삼성전자', '한화', 'sk', '지수', '한화생명']},
#  {'code': 'A051910', 'keywords': ['주식시장', '빅데이터', '코스피', '코스콤', 'm']},
#  {'code': 'A051910', 'keywords': ['매출액', '영업이익', '컨센서스', '조정', '다시한번']},
#  {'code': 'A051910', 'keywords': ['조정', '컨센서스', '김성훈', '매출액', '영업이익']},
#  {'code': 'A207940', 'keywords': ['셀트리온', '신차효과', '팰리세이드', '신형쏘나타', '시가총액']},
#  {'code': 'A207940', 'keywords': ['남북경협', '수익률', '시가총액상위종목', '남북경협주', '북한']},
#  {'code': 'A207940',
#   'keywords': ['삼성바이오로직스', '거래정지', '삼성그룹주펀드', '대우조선', '하이투자증권']},
#  {'code': 'A207940', 'keywords': ['배터리', '무선청소기', '성능', 'lg전자', '다이슨']},
#  {'code': 'A207940', 'keywords': ['lg전자', '사업본부', 'lg', 'b2b', '디스플레이']},
#  {'code': 'A207940', 'keywords': ['ai', '챌린지', '휴켐스', 'lg상사', '증권시장']},
#  {'code': 'A207940', 'keywords': ['삼성바이오로직스', '분식회계', '거래정지', '대우조선', '상장폐지']},
#  {'code': 'A207940',
#   'keywords': ['바이오', '삼성바이오로직스', 'nh투자증권', '바이로메드', '임상결과']},
#  {'code': 'A207940', 'keywords': ['면접', '삼성전자', '신입사원', '삼성', '경제활성화']},
#  {'code': 'A207940', 'keywords': ['msci', '중국a주', '지수', '의약품', '코스닥']},
#  {'code': 'A207940', 'keywords': ['bpa', '박태진', '키움증권', '에폭시수지', '금호석유화학']},
#  {'code': 'A207940', 'keywords': ['배터리', 'sk이노베이션', '전기차배터리', 'catl', 'lg화학']},
#  {'code': 'A207940', 'keywords': ['파월', '폼페이오', '순매도', 'sk하이닉스', '지수']},
#  {'code': 'A207940', 'keywords': ['취약계층', 'lg전자', '인터내셔날', '인도네시아', '자카르타']},
#  {'code': 'A207940', 'keywords': ['lg전자', 'zkw', '자동차', '사업본부', '전장사업']},
#  {'code': 'A207940', 'keywords': ['수익률', '주식형펀드', '기술주', '아시아증시', '무역전쟁']},
#  {'code': 'A207940', 'keywords': ['삼바', '바이오', '삼성전자', '삼성바이오로직스', '신수종']},
#  {'code': 'A207940', 'keywords': ['권영수', '적자', 'lg그룹', '구광모', '사업본부']},
#  {'code': 'A207940', 'keywords': ['lg그룹', '권영수', '적자', '구광모', '사업본부']},
#  {'code': 'A207940', 'keywords': ['삼바', '상장폐지', '분식회계', '금융감독원', '연기금']},
#  {'code': 'A207940', 'keywords': ['삼바', '회계처리', '금융감독원', '분식회계', '참여연대']},
#  {'code': 'A207940', 'keywords': ['lg', '사업본부', 'lg전자', '구광모', '지주회사']},
#  {'code': 'A207940',
#   'keywords': ['전환사채', '리드아웃', '뉴프라이드', '한국맥널티', '도화엔지니어링']},
#  {'code': 'A207940', 'keywords': ['북미정상회담', '지수', '코스피', '국채금리', '유가']},
#  {'code': 'A207940', 'keywords': ['삼성바이오', '분식회계', '회계처리', '바이오시밀러', '간담회']},
#  {'code': 'A207940', 'keywords': ['이데일리신문']},
#  {'code': 'A207940', 'keywords': ['lg전자', '구본무', '강남성모병원', '차석용', 'lg']},
#  {'code': 'A207940', 'keywords': ['지주회사', 'lg', 'gs홀딩스', '서비스업', 'lg건설']},
#  {'code': 'A207940', 'keywords': ['바이오', '코스피', '신흥국', '셀트리온', '중국a주']},
#  {'code': 'A207940', 'keywords': ['금융위', '삼성바이오', '참여연대', '교수', '금융감독원']},
#  {'code': 'A207940', 'keywords': ['중국a주', 'msci', '관망심리', '뉴욕증권거래소', '철강금속']},
#  {'code': 'A207940',
#   'keywords': ['삼성바이오로직스', '수익률', '삼성그룹주펀드', '남북경협', '평균수익률']},
#  {'code': 'A207940', 'keywords': ['삼성전자', '삼성바이오로직스', '액면분할', '순매도', '분식회계']},
#  {'code': 'A207940', 'keywords': ['김정유', '종목뉴스']},
#  {'code': 'A207940', 'keywords': ['김정유', '종목뉴스']},
#  {'code': 'A207940',
#   'keywords': ['삼성바이오로직스', 'etf', '바이오주', '미래에셋자산운용', '상장지수펀드']},
#  {'code': 'A207940',
#   'keywords': ['사모전환사채', '영업이익', '수주', '반도체제조장비', '주주가치제고']},
#  {'code': 'A207940', 'keywords': ['삼성전자', '삼성생명', '삼성물산', '삼성', '순환출자']},
#  {'code': 'A207940', 'keywords': ['사도', '오리엔트바이오', 'lg화학', '바이오산업', '코리아나']},
#  {'code': 'A207940', 'keywords': ['화학', '분석', '호주', '말레이시아', '생산성']},
#  {'code': 'A207940', 'keywords': ['수익률', '인덱스펀드', '코스닥', '주식형펀드', '셀트리온']},
#  {'code': 'A207940', 'keywords': ['대규모투자', '전기차배터리', 'lg화학', '화학', '케이블방송']},
#  {'code': 'A207940', 'keywords': ['회사채', '금리', '수요예측', '시중금리', 'aaa']},
#  {'code': 'A207940', 'keywords': ['바이오', '사도', '박스권', '철강', '우리산업']},
#  {'code': 'A207940', 'keywords': ['특징주', '대우조선', '가상화폐', '오늘증시', '삼성전자']},
#  {'code': 'A207940', 'keywords': ['jp모건', '헬스케어', 'sk바이오팜', '콘퍼런스', 'lg화학']},
#  {'code': 'A207940', 'keywords': ['jp모건', 'lg화학', '셀트리온', '헬스케어', '아스트라제네카']},
#  {'code': 'A207940',
#   'keywords': ['lg화학', '사상최대실적', '신한금융지주', '석유화학', '기업지배구조']},
#  {'code': 'A207940', 'keywords': ['4차산업혁명', 'it', '2018년', 'opec', '부국증권']},
#  {'code': 'A207940', 'keywords': ['수익률', 'lg이노텍', '삼성그룹주펀드', 'lg전자', 'lg화학']},
#  {'code': 'A207940', 'keywords': ['특징주', 'etf', '삼성중공업', '기술적반등', '오늘증시']},
#  {'code': 'A207940', 'keywords': ['lg전자', 'oled', 'lg그룹', '성과주의', '자동차용']},
#  {'code': 'A207940', 'keywords': ['lg화학', '권순황', 'lg디스플레이', 'oled', '미래사업']},
#  {'code': 'A207940', 'keywords': ['lg전자', '사업본부', 'lg화학', '임원인사', 'lg이노텍']},
#  {'code': 'A207940', 'keywords': ['lg화학', 'lg전자', 'ifa2017', '이진규', '경쟁력제고']},
#  {'code': 'A207940', 'keywords': ['lg그룹', '임원인사', 'lg디스플레이', 'lg전자', '구본무']},
#  {'code': 'A207940', 'keywords': ['헬스케어', '일동제약', '바이오시밀러', '바이오', '유나이티드제약']},
#  {'code': 'A207940', 'keywords': ['코스닥', '지수', '코스닥종목', '한국거래소', '영업이익']},
#  {'code': 'A207940', 'keywords': ['lg전자', '코드제로', '무선청소기', '터보', '싸이클론']},
#  {'code': 'A207940', 'keywords': ['배터리', '전기차', '전기차배터리', '고급인력', '굴기']},
#  {'code': 'A207940', 'keywords': ['사도', '코미코', '주성엔지니어링', 'lg화학', '조정']},
#  {'code': 'A207940', 'keywords': ['사도', '턴어라운드', 'sk증권', '유니테스트', 'lg화학']},
#  {'code': 'A207940', 'keywords': ['특징주', '매도전략', '오늘증시', '생보사', '케이블방송']},
#  {'code': 'A207940', 'keywords': ['특징주', '철강', '매도전략', '오늘증시', '영업이익']},
#  {'code': 'A207940', 'keywords': ['셀트리온', '사도', '500원', '유진로봇', '4차산업']},
#  {'code': 'A207940', 'keywords': ['특징주', '필라이트', '분할매수', '영업익', '오늘증시']},
#  {'code': 'A207940', 'keywords': ['특징주', '한화케미칼', '매도전략', '세전이익', '오늘증시']},
#  {'code': 'A207940', 'keywords': ['특징주', '코오롱인더', '분할매수', '저유가', 'lg화학']},
#  {'code': 'A207940', 'keywords': ['영업이익', '코스맥스', 'sk하이닉스', '태영건설', '종근당']},
#  {'code': 'A207940', 'keywords': ['도요타', '닛산', '르노', '혼다', '부품']},
#  {'code': 'A207940', 'keywords': ['영업이익', '코스맥스', 'sk하이닉스', '태영건설', '종근당']},
#  {'code': 'A207940', 'keywords': ['특징주', '조정', 'lg화학', '현대자동차', '코스모신소재']},
#  {'code': 'A207940', 'keywords': ['두올산업', '시노펙스', '공장신축', '현금배당', '채무보증']},
#  {'code': 'A207940', 'keywords': ['사도', '2차전지', 'lg화학', '500원', '하반기']},
#  {'code': 'A207940', 'keywords': ['특징주', '무상증자', '파라텍', '삼성바이오로직스', '깨끗한나라']},
#  {'code': 'A207940', 'keywords': ['특징주', '영업익', 'lg화학', '제주항공', '금리인상']},
#  {'code': 'A207940', 'keywords': ['lg화학', '외국인순매수', '삼성', '15분', '대한민국']},
#  {'code': 'A207940', 'keywords': ['특징주', '분할매수', '철강', 'lg화학', '넷마블게임즈']},
#  {'code': 'A207940', 'keywords': ['특징주', '2차전지', 'lg화학', '미래에셋대우', '코오롱생명과학']},
#  {'code': 'A207940', 'keywords': ['김용덕', '삼성바이오로직스', '파트론', '일신바이오', '바이오가스']},
#  {'code': 'A207940', 'keywords': ['지수', '운수창고', '음식료품', '도시바', '건설업']},
#  {'code': 'A207940', 'keywords': ['msci', '달러환율', '유가하락', '건설업', '신한지주']},
#  {'code': 'A207940',
#   'keywords': ['무선청소기', '코드제로', 'lg전자', '무선진공청소기', '로봇청소기']},
#  {'code': 'A207940',
#   'keywords': ['무선청소기', 'lg전자', '코드제로', '무선진공청소기', '로봇청소기']},
#  {'code': 'A207940', 'keywords': ['회사채', '트럼프', '금리인상', '한국투자증권', '발행시장']},
#  {'code': 'A207940', 'keywords': ['사도', '현대상선', '엘오티베큠', '삼성바이오로직스', '반도체']},
#  {'code': 'A207940', 'keywords': ['조정', '코스피', '하락세', '현대중공업', '교보증권']},
#  {'code': 'A207940', 'keywords': ['사도', '일진디스플레이', '투자포인트', 'lg화학', '두산중공업']},
#  {'code': 'A207940',
#   'keywords': ['현대모비스', '필룩스', '현대자동차', '삼성바이오로직스', '엔씨소프트']},
#  {'code': 'A207940', 'keywords': ['lg화학', '영업이익', '석유화학', '팜한농', '지배주주']},
#  {'code': 'A207940', 'keywords': ['가격', '스프레드', '팜한농', '리튬이온', '석유화학']},
#  {'code': 'A207940', 'keywords': ['5g', 'sk텔레콤', 'lg유플러스', 'g20', '4차산업혁명']},
#  {'code': 'A207940', 'keywords': ['기업지배구조', 'jp모건', '기관투자자', '콘퍼런스', '리스크']},
#  {'code': 'A207940', 'keywords': ['회사채', '수요예측', '신용등급', '기아자동차', '김기명']},
#  {'code': 'A207940', 'keywords': ['lg전자', '영업이익', 'lg실트론', '연결영업이익', 'lg']},
#  {'code': 'A207940', 'keywords': ['무선청소기', '코드제로', 'lg전자', '청소기', '인버터']},
#  {'code': 'A207940',
#   'keywords': ['에프앤가이드', '보성파워텍', '홈캐스트', '동진쎄미켐', '용평리조트']},
#  {'code': 'A207940', 'keywords': ['lg전자', '성과주의', '실용주의', '조성진', 'lg생활건강']},
#  {'code': 'A207940', 'keywords': ['lg상사', 'lg화학', 'lg디스플레이', 'lg전자', '구본준']},
#  {'code': 'A207940', 'keywords': ['lg전자', '구본무', 'lg그룹', '조성진', '최고경영자']},
#  {'code': 'A005490', 'keywords': ['러시', 'lng선', '조선3사', '중국', '건조']},
#  {'code': 'A005490', 'keywords': ['상장', 'ipo', '기업평가', '자본확충', 'ifrs17']},
#  {'code': 'A005490', 'keywords': ['아파트', '실수요자', '분양', '경쟁률', '부동산시장']},
#  {'code': 'A005490', 'keywords': ['생산량', '공급과잉', '한국철강', '세계5위', '2018년']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '원인규명', '경찰', '고용노동부']},
#  {'code': 'A005490', 'keywords': ['포스코', '목숨', '포항제철소', '부검', '경찰']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '원인규명', '목숨', '9일']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '경찰', '고용노동부', '제기']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '원인규명', '제기', '경찰']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '원인규명', '경찰', '현장조사']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '경찰조사', '경찰', '흔적']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '경찰', '고용노동부', '목숨']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '경찰', '고용노동부', '흔적']},
#  {'code': 'A005490', 'keywords': ['설연휴', '무역분쟁', '코스닥', '지수', '증시']},
#  {'code': 'A005490', 'keywords': ['포스코', '중국', '철강', '이종락', '자동차']},
#  {'code': 'A005490', 'keywords': ['삼성전자주가', '하락', '삼성전자', '무역협상', '커들로']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '경찰', '고용노동부', '목숨']},
#  {'code': 'A005490', 'keywords': ['포스코', '포항제철소', '흔적', '경찰', '고용노동부']},
#  {'code': 'A005490', 'keywords': ['주총', '의결권행사', '반대', '대상', '2017년']},
#  {'code': 'A005490', 'keywords': ['상장사', '주총', '의결권행사', '삼성전자', '대상']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락', '무역분쟁', '불확실성', '무역협상']},
#  {'code': 'A005490', 'keywords': ['코스닥', '지수', '수익률', '파라다이스', '에스엠']},
#  {'code': 'A005490', 'keywords': ['포스코', '산재', '사망원인', '고용부', '고용노동부']},
#  {'code': 'A005490', 'keywords': ['세아제강', '미국', '영업익', '영업이익', '보호무역주의']},
#  {'code': 'A005490', 'keywords': ['조정', '증시', '숨', '만큼', '순매도']},
#  {'code': 'A005490', 'keywords': ['ipo', '신테카바이오', '하락', '지수', '공모가']},
#  {'code': 'A005490', 'keywords': ['포스코켐텍', '소규모합병', '이사회', '주식회사', '서울']},
#  {'code': 'A005490', 'keywords': ['코스피', '무역분쟁', '붕괴', '지수', '시간이흐르면']},
#  {'code': 'A005490', 'keywords': ['코스피', '지수', '무역협상', '시간이흐르면', '외국인순매수']},
#  {'code': 'A005490', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '코스피', '지수']},
#  {'code': 'A005490', 'keywords': ['코스피', '미중정상회담', '하락세', '하락', '무역협상']},
#  {'code': 'A005490', 'keywords': ['코스피', '코스닥', '지수', '중국', '하락세']},
#  {'code': 'A005490', 'keywords': ['코스피', '서울', '지수', '삼성전자', '시간이흐르면']},
#  {'code': 'A005490', 'keywords': ['하락', '코스피', '리스크', '무역협상', '증시']},
#  {'code': 'A005490', 'keywords': ['하락', '코스닥', '순매도', '방송서비스', '정밀기기']},
#  {'code': 'A005490', 'keywords': ['코스피', '지수', '삼성전자', '서울', '시간이흐르면']},
#  {'code': 'A005490', 'keywords': ['코스피', '순매도', '동반', '시가총액', '상한가']},
#  {'code': 'A005490', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A005490', 'keywords': ['코스피', '미중정상회담', '하락', '무역협상', '도널드트럼프']},
#  {'code': 'A005490', 'keywords': ['코스피', '협상', '하락', '붕괴', '지수']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락세', '코스피', 'kospi', '순매도']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락', 'it', 'w', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락', '보합세', '한국경제tv', '상장']},
#  {'code': 'A005490', 'keywords': ['포스코켐텍', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['하태민', '코스닥', '쇼핑', '미래', '순매도']},
#  {'code': 'A005490', 'keywords': ['코스닥', '반전', '하락', '보이', '보합세']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['여왕개미', '박민영', 'sns', '박제영', '수익률']},
#  {'code': 'A005490', 'keywords': ['포스코켐텍', '곽영훈', '정부정책', '전기차', '트렌드']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['포스코강판', '개인투자자', '수익률', '영흥철강', '세아특수강']},
#  {'code': 'A005490', 'keywords': ['현대백화점', '성과', '수익률', '한샘', '포스코대우']},
#  {'code': 'A005490', 'keywords': ['동국알앤에스', '상한가', '보이', '하락', '주가수익률']},
#  {'code': 'A005490', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '순매도']},
#  {'code': 'A005490', 'keywords': ['수익률', '현대제철', '컨센서스', '아연', '철강금속']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A005490', 'keywords': ['동국알앤에스', '한국내화', '북한', '특징주', '박형수']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['무역분쟁', '코스피급락', '코스피', '지수', '삼성전자']},
#  {'code': 'A005490', 'keywords': ['코스피', '순매도', '하락', '동반', '불확실성']},
#  {'code': 'A005490', 'keywords': ['하락', '코스피', '붕괴', '순매도', '유가증권시장']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락세', '하락', '보이', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['하락', '코스피', '무역협상', '불확실성', '한파']},
#  {'code': 'A005490', 'keywords': ['코스피', '동반', '붕괴', '지수', '하락']},
#  {'code': 'A005490', 'keywords': ['아파트', '미세먼지', '깨끗한환경', '우수', '포스코건설']},
#  {'code': 'A005490', 'keywords': ['코스피', '15분', '순매도', '하락', '보이']},
#  {'code': 'A005490', 'keywords': ['포스코', '산재', '제기', '포항제철소', '경찰']},
#  {'code': 'A005490', 'keywords': ['코스피하락', '지수', '코스피', '서울', '하락']},
#  {'code': 'A005490', 'keywords': ['코스닥', '하락세', '하락', '보이', 'it']},
#  {'code': 'A005490', 'keywords': ['코스피', '하락세', '하락', '보이', '보합세']},
#  {'code': 'A005490', 'keywords': ['2차전지', '파우치', '케이피엠테크', '국산화', '일본']},
#  {'code': 'A005490', 'keywords': ['코스피', '코스닥', '하락', '경영권', '지수']},
#  {'code': 'A005490', 'keywords': ['코스피', '미중정상회담', '지수', '하락', '무역협상']},
#  {'code': 'A005490', 'keywords': ['포스코켐텍', '알파고', '한국경제tv', '2019년', '종가']},
#  {'code': 'A005490', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '무역협상', '증시']},
#  {'code': 'A005490', 'keywords': ['영업이익률', '아연', '매출액', '2013년', '영업이익']},
#  {'code': 'A005490', 'keywords': ['코스피하락', '지수', '코스피', '서울', '하락']},
#  {'code': 'A005490', 'keywords': ['코스피', '무역협상', '불확실성', '하락', '순매도']},
#  {'code': 'A005490', 'keywords': ['하락', '코스닥', '순매도', '경남제약', '보이']},
#  {'code': 'A005490', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A005490', 'keywords': ['코스닥', '개장', '하락', '보이', '보합세']},
#  {'code': 'A005490', 'keywords': ['코스피', '개장', '하락', '보이', '하락세']},
#  {'code': 'A005490', 'keywords': ['포스코켐텍', '한국경제tv']},
#  {'code': 'A005490', 'keywords': ['최정우', '포스코', '이종락', '연고주의', '포스코회장']},
#  {'code': 'A005490', 'keywords': ['청년취업', '영어', '외국어', '필리핀클락', '취업']},
#  {'code': 'A005490',
#   'keywords': ['sk하이닉스', '삼성전자', '삼성sdi', '순매수상위', 'tiger']},
#  {'code': 'A005490',
#   'keywords': ['코스닥', '순매수상위', '포스코켐텍', '바이로메드', '셀트리온헬스케어']},
#  {'code': 'A005490',
#   'keywords': ['포스코켐텍', '와이지엔터테인먼트', '코스닥', '기관투자자', '순매수상위']},
#  {'code': 'A005490', 'keywords': ['해외건설수주', '기대치', '수주', '해외수주', '달러']},
#  {'code': 'A005490', 'keywords': ['스마트공장', '제조업', '수출', '트렌드', '산업통상자원부']},
#  {'code': 'A005490', 'keywords': ['철강업계', '미래먹거리', '위기', '보호무역주의', '포스코']},
#  {'code': 'A005490', 'keywords': ['제조업', '산업정책', '성윤모', '우리산업', '리스크']},
#  {'code': 'A005490', 'keywords': ['보일러', '경동나비엔', '기술연구소', '연구소', '계열사']},
#  {'code': 'A005490', 'keywords': ['성윤모', '산업부', '수출', '한국', '제조업']},
#  {'code': 'A005490', 'keywords': ['코스닥', '코스피', 'it', '지수', '미국']},
#  {'code': 'A005490', 'keywords': ['lng', '포스코', '해외직구', '포스코에너지', '포스코대우']},
#  {'code': 'A028260', 'keywords': ['삼성', '강남', '에스원', '삼성그룹', '삼성생명']},
#  {'code': 'A028260', 'keywords': ['남북경협', '수익률', '시가총액상위종목', '남북경협주', '북한']},
#  {'code': 'A028260', 'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미']},
#  {'code': 'A028260', 'keywords': ['매수신호', '이동평균선', '분출', 'sk머티리얼즈', '삼성전자']},
#  {'code': 'A028260', 'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미']},
#  {'code': 'A028260', 'keywords': ['ai', '챌린지', '휴켐스', 'lg상사', '증권시장']},
#  {'code': 'A028260', 'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미']},
#  {'code': 'A028260', 'keywords': ['면접', '삼성전자', '신입사원', '삼성', '경제활성화']},
#  {'code': 'A028260', 'keywords': ['컨퍼런스콜', '대북제재', '재무부', '한국정부', '최근북한']},
#  {'code': 'A028260', 'keywords': ['사외이사', '삼성물산', 'sk', '하나금융지주', '현대정보기술']},
#  {'code': 'A028260', 'keywords': ['매수신호', '이동평균선', '분출', '아카데미', '장영한']},
# ...
#  {'code': 'A000660', 'keywords': ['삼성전자', '반도체', '인포테인먼트시스템', '아우디', 'npu']},
#  {'code': 'A000660', 'keywords': ['최저임금', '갈등', '리스크', '반도체', '일자리']},
#  {'code': 'A000660', 'keywords': ['ces', '글로벌기업', '5g', '전시회', '미래']},
#  {'code': 'A000660',
#   'keywords': ['삼성전자', 'lg전자', 'ces2019', 'lg디스플레이', '박사장']},
#  {'code': 'A000660', 'keywords': ['매수신호', '이동평균선', '분출', '앵커', '아카데미']},
#  {'code': 'A000660',
#   'keywords': ['매수신호', 'sk하이닉스', 'sk머티리얼즈', '이동평균선', '삼성전기']},
#  {'code': 'A000660', 'keywords': ['반도체', '삼성전자', '스마트폰', '최저등급', '차등지급']},
#  {'code': 'A000660', 'keywords': ['탄력근로제', '성장률', '최저임금', 'soc', '결정구조']},
#  {'code': 'A000660', 'keywords': ['매수신호', '이동평균선', '분출', 'sk머티리얼즈', '삼성전자']},
#  {'code': 'A000660', 'keywords': ['sk하이닉스', '실종', '치매', '기억장애', '지적장애인']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '고동진', '임원인사', '삼성전기', '대표이사']},
#  {'code': 'A000660', 'keywords': ['포트폴리오', '국제유가', '삼성전자', '하락', '삼성전자주식']},
#  {'code': 'A000660', 'keywords': ['영업이익', '삼성전자', '반도체', 'sk하이닉스', 'd램']},
#  {'code': 'A000660', 'keywords': ['배당수익률', '보통주', '우선주', '괴리율', '삼성전자']},
#  {'code': 'A000660', 'keywords': ['사모전환사채', 'sk하이닉스', '사외이사', '특허취득', '키움증권']},
#  {'code': 'A000660', 'keywords': ['sk하이닉스', '사외이사', '특허취득', '폴란드', 'cj']},
#  {'code': 'A000660', 'keywords': ['면접', '삼성전자', '신입사원', '삼성', '경제활성화']},
#  {'code': 'A000660', 'keywords': ['컨퍼런스콜', '대북제재', '재무부', '한국정부', '최근북한']},
#  {'code': 'A000660', 'keywords': ['연기금', '미·중무역전쟁', '무역전쟁', '하나', '금리인상']},
#  {'code': 'A000660', 'keywords': ['sk하이닉스', '반도체', '생태계', '재생에너지', '반도체산업']},
#  {'code': 'A000660', 'keywords': ['애플', '스마트폰', '아이폰xs', '아이폰xr', '아이폰xs맥스']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '스타트업', '로봇', '송금서비스', 'mwc']},
#  {'code': 'A000660', 'keywords': ['대덕전자', '합병', '인쇄회로기판', '대덕gds', '5g']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '자동차', '이미지센서', '반도체', '자율주행차']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '자동차', '반도체', '자동차용', '이미지센서']},
#  {'code': 'A000660', 'keywords': ['52시간', '주52시간', '야근', '시간', '퇴근']},
#  {'code': 'A000660', 'keywords': ['ai', 'lg전자', '오픈이노베이션', '구글', '인공지능']},
#  {'code': 'A000660', 'keywords': ['msci', '중국a주', '지수', '의약품', '코스닥']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '기흥사업장', '압수수색', '협력업체', '이산화탄소']},
#  {'code': 'A000660', 'keywords': ['ai', 'lg전자', '삼성전자', '로봇', 'ifa']},
#  {'code': 'A000660', 'keywords': ['lg전자', '삼성전자', '감자', '식재료', '김치']},
#  {'code': 'A000660', 'keywords': ['파월', '폼페이오', '순매도', 'sk하이닉스', '지수']},
#  {'code': 'A000660', 'keywords': ['한국콜마', '하나금융투자', '영업이익', '5g', 'lg유플러스']},
#  {'code': 'A000660', 'keywords': ['한국콜마', '국내증시', '하나금융투자', '현대미포조선', 'sk증권']},
#  {'code': 'A000660', 'keywords': ['msci', '중국a주', '지수', 'lg유플러스', '삼성중공업']},
#  {'code': 'A000660', 'keywords': ['lg전자', '씽큐', '스포츠웨어', '일본', 'lg']},
#  {'code': 'A000660', 'keywords': ['무역분쟁', '지수', '코스닥', '경제지표', '신용융자']},
#  {'code': 'A000660', 'keywords': ['삼바', '바이오', '삼성전자', '삼성바이오로직스', '신수종']},
#  {'code': 'A000660', 'keywords': ['에어컨', '삼성전자', 'lg전자', '매출액', '영업이익']},
#  {'code': 'A000660', 'keywords': ['폴더블', '안전진단', 'lg디스플레이', '렌터카', 'i30']},
#  {'code': 'A000660', 'keywords': ['공정위', '기아자동차', '특별검사팀', 'sk하이닉스', '서울사무소']},
#  {'code': 'A000660', 'keywords': ['제시한', '삼성증권', 'sk하이닉스', '이경호', '메리츠종금증권']},
#  {'code': 'A000660', 'keywords': ['lg전자', '세탁기', '영업이익', '삼성전자', '철강가격']},
#  {'code': 'A000660', 'keywords': ['웨스턴디지털', '루빈', '낸드플래시', 'd램', '삼성전자']},
#  {'code': 'A000660',
#   'keywords': ['남북경협', '삼성그룹주펀드', '평균수익률', 'lg그룹', '삼성바이오로직스']},
#  {'code': 'A000660', 'keywords': ['msci', '중국a주', '관세', '사우디', '북미정상회담']},
#  {'code': 'A000660', 'keywords': ['ai', '삼성전자', '스타트업', '머신러닝', '실리콘밸리']},
#  {'code': 'A000660', 'keywords': ['수익률', '주식형펀드', '지수', '벤치마크', '유출']},
#  {'code': 'A000660', 'keywords': ['반도체', '국내증시', '금리인상', '중국a주', '배당수익률']},
#  {'code': 'A000660', 'keywords': ['관세', '무역전쟁', '이탈리아', '트럼프', '정상회담']},
#  {'code': 'A000660', 'keywords': []},
#  {'code': 'A000660', 'keywords': ['이탈리아', '한국증시', '오늘증시', '국채금리', '유로존']},
#  {'code': 'A000660', 'keywords': ['한국금융지주', '밸류에이션', '영원무역', '삼성전자', '호텔신라']},
#  {'code': 'A000660', 'keywords': ['주식형펀드', '수익률', '채권형펀드', '신흥국', 'sk하이닉스']},
#  {'code': 'A000660', 'keywords': ['북미정상회담', '지수', '코스피', '국채금리', '유가']},
#  {'code': 'A000660', 'keywords': ['b2b', '삼성전자', 'lg전자', '디스플레이', '시스템에어컨']},
#  {'code': 'A000660', 'keywords': ['삼성전자', 'qled', '디스플레이', '55인치', '모델']},
#  {'code': 'A000660', 'keywords': ['액면분할', '삼성전자', 'ipo', '중국a주', '공매도비율']},
#  {'code': 'A000660', 'keywords': ['sk하이닉스', '인수', 'ebitda', '도시바', '도시바메모리']},
#  {'code': 'A000660', 'keywords': ['조정', '한신평', '신용등급', '한기평', '두산중공업']},
#  {'code': 'A000660', 'keywords': ['공매도', '삼성전자', '액면분할', '영업이익', '반도체']},
#  {'code': 'A000660', 'keywords': ['바이오', '코스피', '신흥국', '셀트리온', '중국a주']},
#  {'code': 'A000660', 'keywords': ['세이프가드', 'wto', '삼성전자', 'lg전자', '세계무역기구']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '액면분할', '공매도', '순매도', '중국a주']},
#  {'code': 'A000660', 'keywords': ['중국a주', 'msci', '관망심리', '뉴욕증권거래소', '철강금속']},
#  {'code': 'A000660', 'keywords': ['바이오주', '수익률', '보건의료', '밸류에이션', '휠라코리아']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '삼성바이오로직스', '액면분할', '순매도', '분식회계']},
#  {'code': 'A000660', 'keywords': ['부품', '컴퓨터사업', '4차산업혁명', '애프터서비스', '컴퓨터사양']},
#  {'code': 'A000660',
#   'keywords': ['사모전환사채', '영업이익', '수주', '반도체제조장비', '주주가치제고']},
#  {'code': 'A000660', 'keywords': ['영업이익', '반도체제조장비', '수주', '매출액', '특허취득']},
#  {'code': 'A000660', 'keywords': []},
#  {'code': 'A000660', 'keywords': ['액면분할', '삼성전자', '미래에셋대우', '삼성전자주식', '증권업계']},
#  {'code': 'A000660', 'keywords': []},
#  {'code': 'A000660', 'keywords': ['sk하이닉스', '제시한', '데이터센터', 'kb증권', '컨센서스']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '삼성생명', '삼성물산', '삼성', '순환출자']},
#  {'code': 'A000660', 'keywords': ['국내증시', '골드만삭스', '신흥국', '지수', '대신증권']},
#  {'code': 'A000660', 'keywords': ['비콘', '주휴수당', '급여계산', '관리자', '김진용']},
#  {'code': 'A000660', 'keywords': ['한신평', '영업이익률', '분석', '이지환', '가격']},
#  {'code': 'A000660', 'keywords': ['영업이익', 'lg전자', '깜짝실적', '사업본부', '영업이익률']},
#  {'code': 'A000660', 'keywords': ['사도', '액면분할', '현대글로비스', '박스권', '밸류에이션']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '모바일ap', '딥러닝', '성능', '갤럭시a']},
#  {'code': 'A000660', 'keywords': ['msci', '중국a주', '리밸런싱', '국내증시', '로엔엔터테인먼트']},
#  {'code': 'A000660', 'keywords': ['사도', 'sk하이닉스', '가치주', '대장주', '지수']},
#  {'code': 'A000660', 'keywords': ['유연근무제', '퇴근', '근무시간', '전자업계', '시차출퇴근제']},
#  {'code': 'A000660', 'keywords': ['2차전지', '반도체', '사도', 'sk하이닉스', '신고가기록']},
#  {'code': 'A000660', 'keywords': ['특징주', 'sk하이닉스', '오늘증시', '넥센테크', '삼성엔지니어링']},
#  {'code': 'A000660', 'keywords': ['삼성전자', '기술주', 'sk하이닉스', '오늘증시', '영업이익']},
#  {'code': 'A000660', 'keywords': ['저가항공', '분석', '디스플레이', '메리트', '이재웅']},
#  {'code': 'A000660', 'keywords': ['수익률', '인덱스펀드', '코스닥', '주식형펀드', '셀트리온']},
#  {'code': 'A005935', 'keywords': ['공매도', '셀트리온', '증시', '삼성전기', '하락']},
#  {'code': 'A005935', 'keywords': ['ces', '삼성전자', 'it', '자율주행', '현대자동차']},
#  {'code': 'A005935', 'keywords': ['sk하이닉스', 'lng선', '반도체', '수주', '성장률']},
#  {'code': 'A005935', 'keywords': ['최저임금', '갈등', '리스크', '반도체', '일자리']},
#  {'code': 'A005935', 'keywords': ['ces', '글로벌기업', '5g', '전시회', '미래']},
#  {'code': 'A005935', 'keywords': ['매수신호', '이동평균선', '분출', 'sk머티리얼즈', '삼성전자']},
#  {'code': 'A005935', 'keywords': ['영업이익', '삼성전자', '반도체', 'sk하이닉스', 'd램']},
#  {'code': 'A005935', 'keywords': ['배당수익률', '보통주', '우선주', '괴리율', '삼성전자']},
#  {'code': 'A005935', 'keywords': ['사모전환사채', 'sk하이닉스', '사외이사', '특허취득', '키움증권']},
#  {'code': 'A005935', 'keywords': ['sk하이닉스', '사외이사', '특허취득', '폴란드', 'cj']},
#  {'code': 'A005935', 'keywords': ['연기금', '미·중무역전쟁', '무역전쟁', '하나', '금리인상']},
#  {'code': 'A005935', 'keywords': ['msci', '중국a주', '지수', '의약품', '코스닥']},
#  {'code': 'A005935', 'keywords': ['파월', '폼페이오', '순매도', 'sk하이닉스', '지수']},
#  {'code': 'A005935', 'keywords': ['msci', '중국a주', '지수', 'lg유플러스', '삼성중공업']},
#  {'code': 'A005935', 'keywords': ['웨스턴디지털', '루빈', '낸드플래시', 'd램', '삼성전자']},
#  {'code': 'A005935', 'keywords': ['수익률', '주식형펀드', '지수', '벤치마크', '유출']},
#  {'code': 'A005935', 'keywords': ['주식형펀드', '수익률', '채권형펀드', '신흥국', 'sk하이닉스']},
#  {'code': 'A005935', 'keywords': ['북미정상회담', '지수', '코스피', '국채금리', '유가']},
#  {'code': 'A005935', 'keywords': ['중국a주', 'msci', '관망심리', '뉴욕증권거래소', '철강금속']},
#  {'code': 'A005935', 'keywords': ['삼성전자', '삼성바이오로직스', '액면분할', '순매도', '분식회계']},
#  {'code': 'A005935', 'keywords': ['국내증시', '골드만삭스', '신흥국', '지수', '대신증권']},
#  {'code': 'A005935', 'keywords': ['유연근무제', '퇴근', '근무시간', '전자업계', '시차출퇴근제']},
#  {'code': 'A005935', 'keywords': ['ces', 'ai', '삼성전자', '로봇', '현대자동차']},
#  {'code': 'A005935', 'keywords': ['수익률', '주식형펀드', '채권형펀드', '삼성전자', 'sk하이닉스']},
#  {'code': 'A005935',
#   'keywords': ['영업이익', '유기발광다이오드', 'oledtv', 'oled', '밸류에이션']},
#  {'code': 'A005935', 'keywords': ['수익률', '삼성전자', '화장품', '인덱스펀드', '사드']},
#  {'code': 'A005935', 'keywords': ['코스닥', '지수', '코스닥종목', '한국거래소', '영업이익']},
#  {'code': 'A005935', 'keywords': ['배당주펀드', '삼성전자', '포트폴리오', '고배당주', 'sk텔레콤']},
#  {'code': 'A005935', 'keywords': ['코스피', 'it', '한국투자증권', '삼성전자', '헬스케어']},
#  {'code': 'A005935',
#   'keywords': ['지수', '코스닥', '다우존스산업평균지수', 'sk하이닉스', 'lg화학']},
#  {'code': 'A005935', 'keywords': ['코스닥', '유럽증시', '핵전쟁', '순매도', '삼성전자우']},
#  {'code': 'A005935', 'keywords': ['금리인상', '연준', 's&p', '삼성전자', '지수']},
#  {'code': 'A005935', 'keywords': ['금리인상', '연준', 's&p', '삼성전자', '지수']},
#  {'code': 'A005935', 'keywords': ['잭슨홀', '삼성전자', '한미약품', '제약주', '조정']},
#  {'code': 'A005935', 'keywords': ['세계경제', '한국은행', 'gdp', '리스크', '반도체']},
#  {'code': 'A005935', 'keywords': ['지수', '조정', 'it', '삼성전자', 'sk하이닉스']},
#  {'code': 'A005935', 'keywords': ['sk하이닉스', '디스플레이', '반도체', '삼성전자', '생태계']},
#  {'code': 'A005935', 'keywords': ['지수', '음식료품', '도시바', '전기전자', '건설업']},
#  {'code': 'A005935', 'keywords': ['wti', '지수', '도시바', '코노코필립스', '우선협상대상자']},
#  {'code': 'A005935', 'keywords': ['삼성전자', '유가증권시장', '조정', '코스피', '순매수']},
#  {'code': 'A005935', 'keywords': ['중국a주', '유가', 'msci', '하락세', '지수']},
#  {'code': 'A005935', 'keywords': ['sk하이닉스', '삼성전자', '셀트리온', '영업이익', '순매수']},
#  {'code': 'A005935', 'keywords': ['msci지수', '유가증권시장', '코스피', '철강', '비차익']},
#  {'code': 'A005935', 'keywords': ['조정', '코스피', '하락세', '현대중공업', '교보증권']},
#  {'code': 'A005935', 'keywords': ['삼성전자', '수익률', 'sk하이닉스', 'lg전자', '주가상승률']},
#  {'code': 'A005935', 'keywords': ['opec', '국제유가', '인텔', '나스닥지수', '감산합의']},
#  {'code': 'A005935', 'keywords': ['현대중공업', '지주회사', '순환출자', '파운드리', 'sk하이닉스']},
#  {'code': 'A005935', 'keywords': ['삼성전자', 'lg전자', '영업이익', '눈길', '순매도상위종목']},
#  {'code': 'A005935', 'keywords': ['수익률', 'etf', 'it', '인도', '주식형펀드']},
#  {'code': 'A005935', 'keywords': ['영업이익', '삼성전자', 'sk하이닉스', 'lg전자', 'g6']},
#  {'code': 'A005935', 'keywords': ['신용등급', '무디스', 'aaa', '공기업', 'moody']},
#  {'code': 'A005935', 'keywords': ['코스피', '수익률', '삼성전자', '브렉시트', '실물자산펀드']},
#  {'code': 'A005935', 'keywords': ['환율', '영업이익', '사드', '호텔', '디스플레이']},
#  {'code': 'A005935', 'keywords': ['수출', '환율', '원달러환율', '가격경쟁력', '자동차산업']},
#  {'code': 'A005935', 'keywords': ['코스피', '혼조세', '지에스인스트루', '신흥국', '한진해운']},
#  {'code': 'A005935', 'keywords': ['리밸런싱', 'nh투자증권', '이벤트', '브렉시트', '디아이']},
#  {'code': 'A005935', 'keywords': ['중국', '반도체산업', '반도체', '조선업계', '고용']},
#  {'code': 'A005935', 'keywords': ['수익률', '평균수익률', '삼성전자', '한미약품', 'sk하이닉스']},
#  {'code': 'A005935', 'keywords': ['코스피', '무역흑자', '경제지표', '신용등급', '미국']},
#  {'code': 'A005935', 'keywords': ['코스피', '중국', '삼성물산']},
#  {'code': 'A005935', 'keywords': ['코스피', '외국인순매수', '현대상사']},
#  {'code': 'A005935', 'keywords': ['제일모직', '경제지표', '코스피']},
#  {'code': 'A005935', 'keywords': []},
#  {'code': 'A005935', 'keywords': []},
#  {'code': 'A005935', 'keywords': ['이미지센서']},
#  {'code': 'A005935', 'keywords': ['한국투자증권']},
#  {'code': 'A005935', 'keywords': ['당기순이익', '아이서플라이', '반도체 산업']},
#  {'code': 'A005935', 'keywords': ['아이서플라이', '비메모리 반도체']},
#  {'code': 'A005935',
#   'keywords': ['페이스북', '증권거래위원회', '나스닥', '비즈니스 모델', '기업공개', '주식형 펀드']},
#  {'code': 'A005935', 'keywords': ['아메리칸 인터내셔널 그룹', '페이스북', '강보합세']},
#  {'code': 'A005935', 'keywords': ['주식형펀드', '대체에너지']},
#  {'code': 'A005935', 'keywords': ['페이스북']},
#  {'code': 'A005935', 'keywords': ['크로스 라이선스', '샌디스크', '마이크로소프트']},
#  {'code': 'A005935', 'keywords': ['페이스북', '밸류에이션']},
#  {'code': 'A005935', 'keywords': ['부타디엔', '페이스북']},
#  {'code': 'A005935', 'keywords': ['리더스 클럽']},
#  {'code': 'A005935',
#   'keywords': ['강보합세',
#    '포스코',
#    '기아차',
#    '현대차',
#    '뱅크오브아메리카',
#    '한솔제지',
#    '현대모비스',
#    '한국전력',
#    '신한지주',
#    '삼성전자']},
#  {'code': 'A005935',
#   'keywords': ['아이패드 미니',
#    '한국가스공사',
#    '현대중공업',
#    '현대차',
#    '뉴욕증시',
#    '기아차',
#    '포스코',
#    '한국전력',
#    '신한지주',
#    '현대모비스']},
#  {'code': 'A005935',
#   'keywords': ['포스코', '삼성전자', '대우조선', '현대제철', '윈도8', '규모의 경제', '애널리스트']},
#  {'code': 'A005935',
#   'keywords': ['국가신용등급',
#    '스페인',
#    '현대차',
#    '삼성전자',
#    '한국 신용등급',
#    '기준금리',
#    '현대중공업',
#    '신한지주',
#    '유럽중앙은행',
#    '프로그램 매매']},
#  {'code': 'A005935',
#   'keywords': ['엔화 강세', '005380', '김유정', '기아차', '현대차', '삼성전자']},
#  {'code': 'A005935',
#   'keywords': ['코스피지수',
#    '경기 부양책',
#    '오퍼레이션 트위스트',
#    '공개시장위원회',
#    '하이닉스반도체',
#    '엔씨소프트',
#    '한국투자증권',
#    '유럽연합']},
#  {'code': 'A005935', 'keywords': ['현대산업', '연방공개시장위원회', '경기부양책']},
#  {'code': 'A005935', 'keywords': ['하이닉스반도체', '씨티그룹', '코스피지수']},
#  {'code': 'A005935', 'keywords': ['코스피지수', '하이닉스반도체', '주식형 펀드', '현대중공업']},
#  {'code': 'A005935',
#   'keywords': ['한국거래소',
#    '035720',
#    '케이피케미칼',
#    '한국외환은행',
#    '에스에프에이',
#    'CJ오쇼핑',
#    '자기자본비율',
#    '하나금융지주',
#    '하이닉스반도체',
#    '우리금융']},
#  {'code': 'A005935', 'keywords': ['자산운용사', '하이닉스', '현대중공업']},
#  {'code': 'A005935',
#   'keywords': ['005380', '금호석유', '유진투자증권', '하이닉스반도체', '현대자동차']},
#  {'code': 'A005935',
#   'keywords': ['코스피 지수', '005380', '스탠더드 앤드 푸어스', '하이닉스', '현대중공업', '뉴욕증시']},
#  {'code': 'A005935', 'keywords': ['헬스케어', '김종갑', '하이닉스반도체']},
#  {'code': 'A005935',
#   'keywords': ['코스피지수', '혼조세', '벤 버냉키', '미국 연방준비제도이사회', '하이닉스반도체']},
#  {'code': 'A005935',
#   'keywords': ['하이닉스',
#    '하극상',
#    '서부텍사스중질유(wti)',
#    '액정표시장치',
#    '스마트폰',
#    '유상 증자',
#    '국제 유가']},
#  {'code': 'A005935', 'keywords': ['코스피지수', '법정관리', '하이닉스반도체', '신한지주']},
#  {'code': 'A005935',
#   'keywords': ['태블릿 pc',
#    '하이닉스반도체',
#    '이머징시장',
#    '가처분소득',
#    '약보합세',
#    '액정표시장치',
#    '나스닥 지수',
#    '이코노미스트',
#    '아이패드']},
#  {'code': 'A005935',
#   'keywords': ['네 마녀의 날',
#    '선물 만기일',
#    '오클라호마주',
#    '이트레이드증권',
#    '브렌트유',
#    '코스피200지수',
#    '무아마르 카다피']},
#  {'code': 'A005935', 'keywords': ['코스피지수', '하이닉스반도체', '아이패드', '현대자동차']},
#  {'code': 'A005935', 'keywords': ['우리금융', '현대상선', '헤지펀드', '미래에셋증권', '하이닉스']},
#  {'code': 'A005935', 'keywords': ['하이패스']},
#  {'code': 'A005935', 'keywords': ['하이닉스']},
#  {'code': 'A005935', 'keywords': ['피에스케이', '실적 모멘텀', '하이닉스']},
#  {'code': 'A068270', 'keywords': ['삼성전자', 'sk하이닉스', '코스피', '지수', '전기전자']},
#  {'code': 'A068270', 'keywords': ['기관투자자', '코스닥', '증시', '조정', '순매수상위']},
#  {'code': 'A068270', 'keywords': ['지수', 'sk하이닉스', '전기전자', '코스피', '삼성전자']},
#  {'code': 'A068270', 'keywords': ['이범수', '엄복동', '셀트리온', 'm', '일제강점기']},
#  {'code': 'A068270', 'keywords': ['설연휴', '무역분쟁', '코스닥', '지수', '증시']},
#  {'code': 'A068270', 'keywords': ['대기업', '한국', '수수료', '창의성', '미국']},
#  {'code': 'A068270', 'keywords': ['코스닥', '지수', '수익률', '파라다이스', '에스엠']},
#  {'code': 'A068270', 'keywords': ['코스피', '무역분쟁', '붕괴', '지수', '시간이흐르면']},
#  {'code': 'A068270', 'keywords': ['코스피', '지수', '무역협상', '시간이흐르면', '외국인순매수']},
#  {'code': 'A068270', 'keywords': ['미중정상회담', '코스피하락', '붕괴', '코스피', '지수']},
#  {'code': 'A068270', 'keywords': ['코스피', '미중정상회담', '하락세', '하락', '무역협상']},
#  {'code': 'A068270', 'keywords': ['코스피', '코스닥', '지수', '중국', '하락세']},
#  {'code': 'A068270', 'keywords': ['코스피', '서울', '지수', '삼성전자', '시간이흐르면']},
#  {'code': 'A068270', 'keywords': ['코스피', '무역분쟁', 'g2', '하락', '코스닥']},
#  {'code': 'A068270', 'keywords': ['하락', '코스피', '리스크', '무역협상', '증시']},
#  {'code': 'A068270', 'keywords': ['하락', '코스닥', '순매도', '방송서비스', '정밀기기']},
#  {'code': 'A068270', 'keywords': ['코스피', '지수', '삼성전자', '서울', '시간이흐르면']},
#  {'code': 'A068270', 'keywords': ['코스피', '순매도', '동반', '시가총액', '상한가']},
#  {'code': 'A068270', 'keywords': ['무역협상', '코스피', '불확실성', '붕괴', '하락']},
#  {'code': 'A068270', 'keywords': ['코스피', '미중정상회담', '하락', '무역협상', '도널드트럼프']},
#  {'code': 'A068270', 'keywords': ['무역분쟁', '코스피', '코스닥', '하락', '환율']},
#  {'code': 'A068270', 'keywords': ['코스닥', '하락', 'it', 'w', '한국경제tv']},
#  {'code': 'A068270', 'keywords': ['코스피', '하락', '보합세', '한국경제tv', '상장']}]

# %% [markdown]
# ## Q3-3
# 불러온 quotes에 대하여 상위 30개 종목 별 keyword 리스트의 갯수를 구하세요.
# 그리고, 키워드 별 출현 갯수를 카운트하여 dictionary에 저장하여 보여주세요
#
# hint:
#
# ```python
# len_count = {}
# for i in map(len, a_words):
# 	if i in len_count:
# 		len_count[i] += 1
# 	else:
# 		len_count[i] = 1
# ```

# %%
#Q3-3
result = {}

for i in range(len(query_result)):
    result[query_result[i]['code']] = result.get(query_result[i]['code'], 0) + len(query_result[i]['keywords'])
    
result
# Out:
# {'A015760': 500,
#  'A051910': 492,
#  'A028260': 487,
#  'A068270': 483,
#  'A005380': 496,
#  'A207940': 490,
#  'A005490': 494,
#  'A005930': 499,
#  'A000660': 485,
#  'A005935': 465}
